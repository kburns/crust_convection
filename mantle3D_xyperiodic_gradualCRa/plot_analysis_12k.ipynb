# %%
import pathlib
import subprocess
import h5py
import numpy as np
import matplotlib.pyplot as plt
import re
import glob
import h5py
import matplotlib.animation as animation

import scipy.special as spl
import scipy.integrate
import mpmath as mpm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.colors as mcolors
import matplotlib.cm as cm

fontsize_title = 22
fontsize_axis = 18
fontsize_tick = 18
fontsize_legend = 16
fontsize_cbar = 18

plt.rcParams.update({
    "font.size": fontsize_tick,
    "axes.titlesize": fontsize_title,
    "axes.labelsize": fontsize_axis,
    "xtick.labelsize": fontsize_tick,
    "ytick.labelsize": fontsize_tick,
    "legend.fontsize": fontsize_legend,
    "figure.titlesize": fontsize_title,
})

# %%
import os

os.getcwd()
# Out:
# '/net/fs06/d0/dabdulah/GFD_PROJECT/crust_convection/mantle3D_xyperiodic_gradualCRa'

# %%
### GET DATA SIZES ###

with h5py.File("snapshots/snapshots_s6.h5", mode='r') as file:
    # Load datasets
    
    print('loading...')
    T_load = file['tasks']['T']
    T = np.asarray(T_load)
    print('T done')
    C = np.asarray(file['tasks']['C'])
    print('C done')
    w = np.asarray(file['tasks']['w'])
    print('w done')
    vorticity_x = np.asarray(file['tasks']['vorticity_x'])
    print('vorticity_x done')
    vorticity_y = np.asarray(file['tasks']['vorticity_y'])
    print('vorticity_y done')
    vorticity_z = np.asarray(file['tasks']['vorticity_z'])
    print('vorticity_z done')
    chf = np.asarray(file['tasks']['convective_heat_flux'])
    print('convective_heat_flux done')
    
    t = np.asarray(T_load.dims[0]['sim_time'])
    print('t done')
    
print('The data shapes are (t, nx, ny, nz)')
print(np.shape(T))
# Out:
# loading...
# T done
# C done
# w done
# vorticity_x done
# vorticity_y done
# vorticity_z done
# convective_heat_flux done
# t done
# The data shapes are (t, nx, ny, nz)
# (10, 128, 128, 64)

# %%
print(t)
# Out:
# [1.12425788 1.13954642 1.15360423 1.16690348 1.17958096 1.19169083
#  1.20346471 1.21496371 1.2264627  1.2379617 ]

# %%
def make_stacked_cube_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="stacked_T_C_w_cubes.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    z_indices=(64-3, 64-3, 64-3),   # one xy slice per field/cube
    y_index=1,                      # xz slice
    x_index=1,                      # yz slice

    fps=4,
    dpi=150,
    figsize=(8, 12),
    elev=25,
    azim=45,

    cmaps=("RdBu_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),
    scale_from_last_half=True,

    alpha=0.95,
    frame_cutoff=None,
):
    """
    Makes 3 separate cube plots stacked vertically:
        top    = tasks[0], e.g. T
        middle = tasks[1], e.g. C
        bottom = tasks[2], e.g. w

    Each cube has:
        xy slice at z_indices[i]
        xz slice at y_index
        yz slice at x_index

    No contours.
    """

    def get_coord(dset, dim_index):
        keys = list(dset.dims[dim_index].keys())
        if len(keys) == 0:
            raise ValueError(f"No coordinate scale found for dimension {dim_index}")
        return np.asarray(dset.dims[dim_index][keys[0]])

    def find_snapshot_files(snapshot_dir="snapshots", file_prefix="snapshots_s"):
        files = []
        i = 1
        while True:
            fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
            if os.path.exists(fname):
                files.append(fname)
                i += 1
            else:
                break

        if len(files) == 0:
            raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

        return files

    # ----------------------------
    # Colormaps
    # ----------------------------
    cmap_list = []

    for task, cmap in zip(tasks, cmaps):
        if cmap is None and task == "C":
            cmap_obj = mcolors.LinearSegmentedColormap.from_list(
                "brown_to_red",
                [
                    (0.00, "black"),
                    (0.25, "saddlebrown"),
                    (1.00, "lightcoral"),
                ]
            )
        elif cmap is None:
            cmap_obj = cm.get_cmap("RdBu_r")
        else:
            cmap_obj = cm.get_cmap(cmap)

        cmap_list.append(cmap_obj)

    # ----------------------------
    # Find files and collect frames
    # ----------------------------
    files = find_snapshot_files(snapshot_dir, file_prefix)
    print(f"Found {len(files)} snapshot files.")

    frames = []

    for fname in files:
        print(f"Scanning {fname}")
        with h5py.File(fname, mode="r") as file:
            dset = file["tasks"][tasks[0]]
            t = np.asarray(dset.dims[0]["sim_time"])
            nt = dset.shape[0]

            for it in range(nt):
                frames.append((fname, it, t[it]))

    frames = sorted(frames, key=lambda item: item[2])

    # ----------------------------
    # Coordinates
    # ----------------------------
    first_fname, first_it, first_time = frames[0]

    with h5py.File(first_fname, mode="r") as file:
        dset = file["tasks"][tasks[0]]
        x = get_coord(dset, 1)
        y = get_coord(dset, 2)
        z = get_coord(dset, 3)

    x0, x1 = x.min(), x.max()
    y0, y1 = y.min(), y.max()
    z0, z1 = z.min(), z.max()

    xs = x[x_index]
    ys = y[y_index]

    Xxy, Yxy = np.meshgrid(x, y, indexing="ij")
    Xxz, Zxz = np.meshgrid(x, z, indexing="ij")
    Yyz, Zyz = np.meshgrid(y, z, indexing="ij")

    Yxz = np.full_like(Xxz, ys)
    Xyz = np.full_like(Yyz, xs)

    print("x min/max:", x0, x1)
    print("y min/max:", y0, y1)
    print("z min/max:", z0, z1)
    print("xz slice y =", ys)
    print("yz slice x =", xs)

    for task, zi in zip(tasks, z_indices):
        print(f"{task}: xy slice z_index = {zi}, z = {z[zi]}")

    # ----------------------------
    # Color limits
    # ----------------------------
    def scan_task_limits(task, zi, user_vmin, user_vmax):
        if user_vmin is not None and user_vmax is not None:
            return user_vmin, user_vmax

        vals = []
        scan_frames = frames[len(frames)//2:] if scale_from_last_half else frames

        print(f"Scanning color limits for {task}...")

        for fname, it, sim_time in scan_frames:
            with h5py.File(fname, mode="r") as file:
                vals.append(np.nanmin(file["tasks"][task][it, :, :, zi]))
                vals.append(np.nanmax(file["tasks"][task][it, :, :, zi]))

                vals.append(np.nanmin(file["tasks"][task][it, :, y_index, :]))
                vals.append(np.nanmax(file["tasks"][task][it, :, y_index, :]))

                vals.append(np.nanmin(file["tasks"][task][it, x_index, :, :]))
                vals.append(np.nanmax(file["tasks"][task][it, x_index, :, :]))

        data_min = np.nanmin(vals)
        data_max = np.nanmax(vals)

        if user_vmin is None:
            user_vmin = data_min
        if user_vmax is None:
            user_vmax = data_max

        return user_vmin, user_vmax

    norms = []
    for task, zi, vmin, vmax in zip(tasks, z_indices, vmins, vmaxs):
        vmin, vmax = scan_task_limits(task, zi, vmin, vmax)
        if task == 'w':
            vmin = -vmax
        print(f"{task} vmin/vmax:", vmin, vmax)
        norms.append(mcolors.Normalize(vmin=vmin, vmax=vmax))

    # ----------------------------
    # Figure setup: THREE SEPARATE AXES
    # ----------------------------
    fig = plt.figure(figsize=figsize)

    axes = []
    axes.append(fig.add_subplot(3, 1, 1, projection="3d"))
    axes.append(fig.add_subplot(3, 1, 2, projection="3d"))
    axes.append(fig.add_subplot(3, 1, 3, projection="3d"))

    fig.subplots_adjust(
        left=0.02,
        right=0.84,
        bottom=0.03,
        top=0.95,
        hspace=-0.10,
    )

    def draw_cube(ax, file, task, cmap, norm, it, zi):
        ax.clear()

        zs = z[zi]
        Zxy = np.full_like(Xxy, zs)

        Fxy = np.asarray(file["tasks"][task][it, :, :, zi])
        Fxz = np.asarray(file["tasks"][task][it, :, y_index, :])
        Fyz = np.asarray(file["tasks"][task][it, x_index, :, :])

        ax.plot_surface(
            Xxy, Yxy, Zxy,
            facecolors=cmap(norm(Fxy)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=alpha,
        )

        ax.plot_surface(
            Xxz, Yxz, Zxz,
            facecolors=cmap(norm(Fxz)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=alpha,
        )

        ax.plot_surface(
            Xyz, Yyz, Zyz,
            facecolors=cmap(norm(Fyz)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=alpha,
        )

        epsx = 0.02 * (x1 - x0)
        epsy = 0.02 * (y1 - y0)
        epsz = 0.02 * (z1 - z0)

        ax.set_xlim(x0 - epsx, x1 + epsx)
        ax.set_ylim(y0 - epsy, y1 + epsy)
        ax.set_zlim(z0 - epsz, z1 + epsz)

        ax.set_xlabel("x", labelpad=6)
        ax.set_ylabel("y", labelpad=6)
        ax.set_zlabel("z", labelpad=6)

        ax.view_init(elev=elev, azim=azim)
        ax.set_box_aspect((x1 - x0, y1 - y0, z1 - z0))

    def draw_frame(fname, it, sim_time):
        with h5py.File(fname, mode="r") as file:
            for ax, task, cmap, norm, zi in zip(axes, tasks, cmap_list, norms, z_indices):
                draw_cube(ax, file, task, cmap, norm, it, zi)

        axes[0].set_title(f"time = {sim_time:.2f}", pad=2)

        return sum([ax.collections for ax in axes], [])

    draw_frame(first_fname, first_it, first_time)

    # ----------------------------
    # Colorbars, one per cube
    # ----------------------------
    cbar_positions = [
        [0.87, 0.69, 0.025, 0.20],
        [0.87, 0.40, 0.025, 0.20],
        [0.87, 0.11, 0.025, 0.20],
    ]

    for pos, task, cmap, norm in zip(cbar_positions, tasks, cmap_list, norms):
        cax = fig.add_axes(pos)
        sm = cm.ScalarMappable(norm=norm, cmap=cmap)
        sm.set_array([])
        cb = fig.colorbar(sm, cax=cax)
        cb.set_label(task)

    # ----------------------------
    # Animation update
    # ----------------------------
    def update(frame_number):
        fname, it, sim_time = frames[frame_number]
        draw_frame(fname, it, sim_time)

        print(
            f"Frame {frame_number + 1}/{len(frames)}: "
            f"{fname}, index {it}, time {sim_time:.2f}"
        )

        return sum([ax.collections for ax in axes], [])

    if frame_cutoff is None:
        frame_cutoff = len(frames)
    ani = animation.FuncAnimation(
        fig,
        update,
        frames=frame_cutoff,
        interval=1000 / fps,
        blit=False,
    )

    ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)
    print(f"Saved animation to {output_name}")

# %%
make_stacked_cube_animation(
    snapshot_dir="snapshots_12k",
    file_prefix="snapshots_12k_s",
    output_name="stacked_12k_T_C_w_cubes.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    z_indices=(64-3, 64-3, 64-10),
    y_index=1,
    x_index=1,

    fps=4,
    dpi=150,
    figsize=(8, 12),
    elev=25,
    azim=-130,

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, -15),
    vmaxs=(None, None, 15),

    alpha=0.95,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-5fe68926f234>:81: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 19 snapshot files.
# Scanning snapshots_12k/snapshots_12k_s1.h5
# Scanning snapshots_12k/snapshots_12k_s2.h5
# Scanning snapshots_12k/snapshots_12k_s3.h5
# Scanning snapshots_12k/snapshots_12k_s4.h5
# Scanning snapshots_12k/snapshots_12k_s5.h5
# Scanning snapshots_12k/snapshots_12k_s6.h5
# Scanning snapshots_12k/snapshots_12k_s7.h5
# Scanning snapshots_12k/snapshots_12k_s8.h5
# Scanning snapshots_12k/snapshots_12k_s9.h5
# Scanning snapshots_12k/snapshots_12k_s10.h5
# Scanning snapshots_12k/snapshots_12k_s11.h5
# Scanning snapshots_12k/snapshots_12k_s12.h5
# Scanning snapshots_12k/snapshots_12k_s13.h5
# Scanning snapshots_12k/snapshots_12k_s14.h5
# Scanning snapshots_12k/snapshots_12k_s15.h5
# Scanning snapshots_12k/snapshots_12k_s16.h5
# Scanning snapshots_12k/snapshots_12k_s17.h5
# Scanning snapshots_12k/snapshots_12k_s18.h5
# Scanning snapshots_12k/snapshots_12k_s19.h5
# x min/max: 0.0 3.96875
# y min/max: 0.0 3.96875
# z min/max: 0.00015059065189787502 0.9998494093481021
# xz slice y = 0.03125
# yz slice x = 0.03125
# T: xy slice z_index = 61, z = 0.996239767299355
# C: xy slice z_index = 61, z = 0.996239767299355
# w: xy slice z_index = 54, z = 0.9466121505977576
# Scanning color limits for T...
# T vmin/vmax: 9.430134178912667e-05 0.9999879942518395
# Scanning color limits for C...
# C vmin/vmax: 2.4340385106488014e-05 1.053538543326262
# w vmin/vmax: -15 15
# Frame 1/189: snapshots_12k/snapshots_12k_s1.h5, index 0, time 0.00
# Frame 1/189: snapshots_12k/snapshots_12k_s1.h5, index 0, time 0.00
# Frame 2/189: snapshots_12k/snapshots_12k_s1.h5, index 1, time 0.10
# Frame 3/189: snapshots_12k/snapshots_12k_s1.h5, index 2, time 0.10
# Frame 4/189: snapshots_12k/snapshots_12k_s1.h5, index 3, time 0.10
# Frame 5/189: snapshots_12k/snapshots_12k_s1.h5, index 4, time 0.10
# Frame 6/189: snapshots_12k/snapshots_12k_s1.h5, index 5, time 0.10
# Frame 7/189: snapshots_12k/snapshots_12k_s1.h5, index 6, time 0.10
# Frame 8/189: snapshots_12k/snapshots_12k_s1.h5, index 7, time 0.10
# Frame 9/189: snapshots_12k/snapshots_12k_s1.h5, index 8, time 0.11
# Frame 10/189: snapshots_12k/snapshots_12k_s1.h5, index 9, time 0.11
# Frame 11/189: snapshots_12k/snapshots_12k_s2.h5, index 0, time 0.11
# Frame 12/189: snapshots_12k/snapshots_12k_s2.h5, index 1, time 0.11
# Frame 13/189: snapshots_12k/snapshots_12k_s2.h5, index 2, time 0.12
# Frame 14/189: snapshots_12k/snapshots_12k_s2.h5, index 3, time 0.13
# Frame 15/189: snapshots_12k/snapshots_12k_s2.h5, index 4, time 0.14
# Frame 16/189: snapshots_12k/snapshots_12k_s2.h5, index 5, time 0.16
# Frame 17/189: snapshots_12k/snapshots_12k_s2.h5, index 6, time 0.17
# Frame 18/189: snapshots_12k/snapshots_12k_s2.h5, index 7, time 0.19
# Frame 19/189: snapshots_12k/snapshots_12k_s2.h5, index 8, time 0.21
# Frame 20/189: snapshots_12k/snapshots_12k_s2.h5, index 9, time 0.23
# Frame 21/189: snapshots_12k/snapshots_12k_s3.h5, index 0, time 0.27
# Frame 22/189: snapshots_12k/snapshots_12k_s3.h5, index 1, time 0.31
# Frame 23/189: snapshots_12k/snapshots_12k_s3.h5, index 2, time 0.35
# Frame 24/189: snapshots_12k/snapshots_12k_s3.h5, index 3, time 0.42
# Frame 25/189: snapshots_12k/snapshots_12k_s3.h5, index 4, time 0.48
# Frame 26/189: snapshots_12k/snapshots_12k_s3.h5, index 5, time 0.54
# Frame 27/189: snapshots_12k/snapshots_12k_s3.h5, index 6, time 0.61
# Frame 28/189: snapshots_12k/snapshots_12k_s3.h5, index 7, time 0.68
# Frame 29/189: snapshots_12k/snapshots_12k_s3.h5, index 8, time 0.74
# Frame 30/189: snapshots_12k/snapshots_12k_s3.h5, index 9, time 0.80
# Frame 31/189: snapshots_12k/snapshots_12k_s4.h5, index 0, time 0.84
# Frame 32/189: snapshots_12k/snapshots_12k_s4.h5, index 1, time 0.86
# Frame 33/189: snapshots_12k/snapshots_12k_s4.h5, index 2, time 0.88
# Frame 34/189: snapshots_12k/snapshots_12k_s4.h5, index 3, time 0.89
# Frame 35/189: snapshots_12k/snapshots_12k_s4.h5, index 4, time 0.91
# Frame 36/189: snapshots_12k/snapshots_12k_s4.h5, index 5, time 0.92
# Frame 37/189: snapshots_12k/snapshots_12k_s4.h5, index 6, time 0.94
# Frame 38/189: snapshots_12k/snapshots_12k_s4.h5, index 7, time 0.95
# Frame 39/189: snapshots_12k/snapshots_12k_s4.h5, index 8, time 0.96
# Frame 40/189: snapshots_12k/snapshots_12k_s4.h5, index 9, time 0.98
# Frame 41/189: snapshots_12k/snapshots_12k_s5.h5, index 0, time 0.99
# Frame 42/189: snapshots_12k/snapshots_12k_s5.h5, index 1, time 1.00
# Frame 43/189: snapshots_12k/snapshots_12k_s5.h5, index 2, time 1.01
# Frame 44/189: snapshots_12k/snapshots_12k_s5.h5, index 3, time 1.02
# Frame 45/189: snapshots_12k/snapshots_12k_s5.h5, index 4, time 1.04
# Frame 46/189: snapshots_12k/snapshots_12k_s5.h5, index 5, time 1.05
# Frame 47/189: snapshots_12k/snapshots_12k_s5.h5, index 6, time 1.07
# Frame 48/189: snapshots_12k/snapshots_12k_s5.h5, index 7, time 1.08
# Frame 49/189: snapshots_12k/snapshots_12k_s5.h5, index 8, time 1.10
# Frame 50/189: snapshots_12k/snapshots_12k_s5.h5, index 9, time 1.11
# Frame 51/189: snapshots_12k/snapshots_12k_s6.h5, index 0, time 1.13
# Frame 52/189: snapshots_12k/snapshots_12k_s6.h5, index 1, time 1.14
# Frame 53/189: snapshots_12k/snapshots_12k_s6.h5, index 2, time 1.16
# Frame 54/189: snapshots_12k/snapshots_12k_s6.h5, index 3, time 1.17
# Frame 55/189: snapshots_12k/snapshots_12k_s6.h5, index 4, time 1.18
# Frame 56/189: snapshots_12k/snapshots_12k_s6.h5, index 5, time 1.19
# Frame 57/189: snapshots_12k/snapshots_12k_s6.h5, index 6, time 1.21
# Frame 58/189: snapshots_12k/snapshots_12k_s6.h5, index 7, time 1.22
# Frame 59/189: snapshots_12k/snapshots_12k_s6.h5, index 8, time 1.23
# Frame 60/189: snapshots_12k/snapshots_12k_s6.h5, index 9, time 1.24
# Frame 61/189: snapshots_12k/snapshots_12k_s7.h5, index 0, time 1.25
# Frame 62/189: snapshots_12k/snapshots_12k_s7.h5, index 1, time 1.26
# Frame 63/189: snapshots_12k/snapshots_12k_s7.h5, index 2, time 1.27
# Frame 64/189: snapshots_12k/snapshots_12k_s7.h5, index 3, time 1.28
# Frame 65/189: snapshots_12k/snapshots_12k_s7.h5, index 4, time 1.29
# Frame 66/189: snapshots_12k/snapshots_12k_s7.h5, index 5, time 1.31
# Frame 67/189: snapshots_12k/snapshots_12k_s7.h5, index 6, time 1.32
# Frame 68/189: snapshots_12k/snapshots_12k_s7.h5, index 7, time 1.33
# Frame 69/189: snapshots_12k/snapshots_12k_s7.h5, index 8, time 1.34
# Frame 70/189: snapshots_12k/snapshots_12k_s7.h5, index 9, time 1.35
# Frame 71/189: snapshots_12k/snapshots_12k_s8.h5, index 0, time 1.36
# Frame 72/189: snapshots_12k/snapshots_12k_s8.h5, index 1, time 1.37
# Frame 73/189: snapshots_12k/snapshots_12k_s8.h5, index 2, time 1.38
# Frame 74/189: snapshots_12k/snapshots_12k_s8.h5, index 3, time 1.40
# Frame 75/189: snapshots_12k/snapshots_12k_s8.h5, index 4, time 1.41
# Frame 76/189: snapshots_12k/snapshots_12k_s8.h5, index 5, time 1.42
# Frame 77/189: snapshots_12k/snapshots_12k_s8.h5, index 6, time 1.43
# Frame 78/189: snapshots_12k/snapshots_12k_s8.h5, index 7, time 1.45
# Frame 79/189: snapshots_12k/snapshots_12k_s8.h5, index 8, time 1.46
# Frame 80/189: snapshots_12k/snapshots_12k_s8.h5, index 9, time 1.48
# Frame 81/189: snapshots_12k/snapshots_12k_s9.h5, index 0, time 1.49
# Frame 82/189: snapshots_12k/snapshots_12k_s9.h5, index 1, time 1.50
# Frame 83/189: snapshots_12k/snapshots_12k_s9.h5, index 2, time 1.52
# Frame 84/189: snapshots_12k/snapshots_12k_s9.h5, index 3, time 1.54
# Frame 85/189: snapshots_12k/snapshots_12k_s9.h5, index 4, time 1.56
# Frame 86/189: snapshots_12k/snapshots_12k_s9.h5, index 5, time 1.58
# Frame 87/189: snapshots_12k/snapshots_12k_s9.h5, index 6, time 1.59
# Frame 88/189: snapshots_12k/snapshots_12k_s9.h5, index 7, time 1.61
# Frame 89/189: snapshots_12k/snapshots_12k_s9.h5, index 8, time 1.62
# Frame 90/189: snapshots_12k/snapshots_12k_s9.h5, index 9, time 1.63
# Frame 91/189: snapshots_12k/snapshots_12k_s10.h5, index 0, time 1.64
# Frame 92/189: snapshots_12k/snapshots_12k_s10.h5, index 1, time 1.65
# Frame 93/189: snapshots_12k/snapshots_12k_s10.h5, index 2, time 1.66
# Frame 94/189: snapshots_12k/snapshots_12k_s10.h5, index 3, time 1.68
# Frame 95/189: snapshots_12k/snapshots_12k_s10.h5, index 4, time 1.69
# Frame 96/189: snapshots_12k/snapshots_12k_s10.h5, index 5, time 1.70
# Frame 97/189: snapshots_12k/snapshots_12k_s10.h5, index 6, time 1.72
# Frame 98/189: snapshots_12k/snapshots_12k_s10.h5, index 7, time 1.73
# Frame 99/189: snapshots_12k/snapshots_12k_s10.h5, index 8, time 1.74
# Frame 100/189: snapshots_12k/snapshots_12k_s10.h5, index 9, time 1.76
# Frame 101/189: snapshots_12k/snapshots_12k_s11.h5, index 0, time 1.77
# Frame 102/189: snapshots_12k/snapshots_12k_s11.h5, index 1, time 1.78
# Frame 103/189: snapshots_12k/snapshots_12k_s11.h5, index 2, time 1.79
# Frame 104/189: snapshots_12k/snapshots_12k_s11.h5, index 3, time 1.80
# Frame 105/189: snapshots_12k/snapshots_12k_s11.h5, index 4, time 1.81
# Frame 106/189: snapshots_12k/snapshots_12k_s11.h5, index 5, time 1.82
# Frame 107/189: snapshots_12k/snapshots_12k_s11.h5, index 6, time 1.84
# Frame 108/189: snapshots_12k/snapshots_12k_s11.h5, index 7, time 1.85
# Frame 109/189: snapshots_12k/snapshots_12k_s11.h5, index 8, time 1.86
# Frame 110/189: snapshots_12k/snapshots_12k_s11.h5, index 9, time 1.88
# Frame 111/189: snapshots_12k/snapshots_12k_s12.h5, index 0, time 1.89
# Frame 112/189: snapshots_12k/snapshots_12k_s12.h5, index 1, time 1.90
# Frame 113/189: snapshots_12k/snapshots_12k_s12.h5, index 2, time 1.91
# Frame 114/189: snapshots_12k/snapshots_12k_s12.h5, index 3, time 1.92
# Frame 115/189: snapshots_12k/snapshots_12k_s12.h5, index 4, time 1.93
# Frame 116/189: snapshots_12k/snapshots_12k_s12.h5, index 5, time 1.95
# Frame 117/189: snapshots_12k/snapshots_12k_s12.h5, index 6, time 1.96
# Frame 118/189: snapshots_12k/snapshots_12k_s12.h5, index 7, time 1.97
# Frame 119/189: snapshots_12k/snapshots_12k_s12.h5, index 8, time 1.98
# Frame 120/189: snapshots_12k/snapshots_12k_s12.h5, index 9, time 2.00
# Frame 121/189: snapshots_12k/snapshots_12k_s13.h5, index 0, time 2.01
# Frame 122/189: snapshots_12k/snapshots_12k_s13.h5, index 1, time 2.02
# Frame 123/189: snapshots_12k/snapshots_12k_s13.h5, index 2, time 2.03
# Frame 124/189: snapshots_12k/snapshots_12k_s13.h5, index 3, time 2.04
# Frame 125/189: snapshots_12k/snapshots_12k_s13.h5, index 4, time 2.05
# Frame 126/189: snapshots_12k/snapshots_12k_s13.h5, index 5, time 2.06
# Frame 127/189: snapshots_12k/snapshots_12k_s13.h5, index 6, time 2.07
# Frame 128/189: snapshots_12k/snapshots_12k_s13.h5, index 7, time 2.09
# Frame 129/189: snapshots_12k/snapshots_12k_s13.h5, index 8, time 2.10
# Frame 130/189: snapshots_12k/snapshots_12k_s13.h5, index 9, time 2.11
# Frame 131/189: snapshots_12k/snapshots_12k_s14.h5, index 0, time 2.12
# Frame 132/189: snapshots_12k/snapshots_12k_s14.h5, index 1, time 2.13
# Frame 133/189: snapshots_12k/snapshots_12k_s14.h5, index 2, time 2.14
# Frame 134/189: snapshots_12k/snapshots_12k_s14.h5, index 3, time 2.15
# Frame 135/189: snapshots_12k/snapshots_12k_s14.h5, index 4, time 2.16
# Frame 136/189: snapshots_12k/snapshots_12k_s14.h5, index 5, time 2.17
# Frame 137/189: snapshots_12k/snapshots_12k_s14.h5, index 6, time 2.19
# Frame 138/189: snapshots_12k/snapshots_12k_s14.h5, index 7, time 2.20
# Frame 139/189: snapshots_12k/snapshots_12k_s14.h5, index 8, time 2.21
# Frame 140/189: snapshots_12k/snapshots_12k_s14.h5, index 9, time 2.22
# Frame 141/189: snapshots_12k/snapshots_12k_s15.h5, index 0, time 2.23
# Frame 142/189: snapshots_12k/snapshots_12k_s15.h5, index 1, time 2.24
# Frame 143/189: snapshots_12k/snapshots_12k_s15.h5, index 2, time 2.25
# Frame 144/189: snapshots_12k/snapshots_12k_s15.h5, index 3, time 2.27
# Frame 145/189: snapshots_12k/snapshots_12k_s15.h5, index 4, time 2.28
# Frame 146/189: snapshots_12k/snapshots_12k_s15.h5, index 5, time 2.29
# Frame 147/189: snapshots_12k/snapshots_12k_s15.h5, index 6, time 2.30
# Frame 148/189: snapshots_12k/snapshots_12k_s15.h5, index 7, time 2.31
# Frame 149/189: snapshots_12k/snapshots_12k_s15.h5, index 8, time 2.32
# Frame 150/189: snapshots_12k/snapshots_12k_s15.h5, index 9, time 2.33
# Frame 151/189: snapshots_12k/snapshots_12k_s16.h5, index 0, time 2.34
# Frame 152/189: snapshots_12k/snapshots_12k_s16.h5, index 1, time 2.35
# Frame 153/189: snapshots_12k/snapshots_12k_s16.h5, index 2, time 2.37
# Frame 154/189: snapshots_12k/snapshots_12k_s16.h5, index 3, time 2.38
# Frame 155/189: snapshots_12k/snapshots_12k_s16.h5, index 4, time 2.39
# Frame 156/189: snapshots_12k/snapshots_12k_s16.h5, index 5, time 2.41
# Frame 157/189: snapshots_12k/snapshots_12k_s16.h5, index 6, time 2.42
# Frame 158/189: snapshots_12k/snapshots_12k_s16.h5, index 7, time 2.43
# Frame 159/189: snapshots_12k/snapshots_12k_s16.h5, index 8, time 2.44
# Frame 160/189: snapshots_12k/snapshots_12k_s16.h5, index 9, time 2.45
# Frame 161/189: snapshots_12k/snapshots_12k_s17.h5, index 0, time 2.46
# Frame 162/189: snapshots_12k/snapshots_12k_s17.h5, index 1, time 2.47
# Frame 163/189: snapshots_12k/snapshots_12k_s17.h5, index 2, time 2.48
# Frame 164/189: snapshots_12k/snapshots_12k_s17.h5, index 3, time 2.50
# Frame 165/189: snapshots_12k/snapshots_12k_s17.h5, index 4, time 2.51
# Frame 166/189: snapshots_12k/snapshots_12k_s17.h5, index 5, time 2.52
# Frame 167/189: snapshots_12k/snapshots_12k_s17.h5, index 6, time 2.53
# Frame 168/189: snapshots_12k/snapshots_12k_s17.h5, index 7, time 2.55
# Frame 169/189: snapshots_12k/snapshots_12k_s17.h5, index 8, time 2.56
# Frame 170/189: snapshots_12k/snapshots_12k_s17.h5, index 9, time 2.57
# Frame 171/189: snapshots_12k/snapshots_12k_s18.h5, index 0, time 2.58
# Frame 172/189: snapshots_12k/snapshots_12k_s18.h5, index 1, time 2.59
# Frame 173/189: snapshots_12k/snapshots_12k_s18.h5, index 2, time 2.61
# Frame 174/189: snapshots_12k/snapshots_12k_s18.h5, index 3, time 2.62
# Frame 175/189: snapshots_12k/snapshots_12k_s18.h5, index 4, time 2.63
# Frame 176/189: snapshots_12k/snapshots_12k_s18.h5, index 5, time 2.65
# Frame 177/189: snapshots_12k/snapshots_12k_s18.h5, index 6, time 2.67
# Frame 178/189: snapshots_12k/snapshots_12k_s18.h5, index 7, time 2.68
# Frame 179/189: snapshots_12k/snapshots_12k_s18.h5, index 8, time 2.69
# Frame 180/189: snapshots_12k/snapshots_12k_s18.h5, index 9, time 2.70
# Frame 181/189: snapshots_12k/snapshots_12k_s19.h5, index 0, time 2.71
# Frame 182/189: snapshots_12k/snapshots_12k_s19.h5, index 1, time 2.72
# Frame 183/189: snapshots_12k/snapshots_12k_s19.h5, index 2, time 2.73
# Frame 184/189: snapshots_12k/snapshots_12k_s19.h5, index 3, time 2.75
# Frame 185/189: snapshots_12k/snapshots_12k_s19.h5, index 4, time 2.76
# Frame 186/189: snapshots_12k/snapshots_12k_s19.h5, index 5, time 2.77
# Frame 187/189: snapshots_12k/snapshots_12k_s19.h5, index 6, time 2.79
# Frame 188/189: snapshots_12k/snapshots_12k_s19.h5, index 7, time 2.80
# Frame 189/189: snapshots_12k/snapshots_12k_s19.h5, index 8, time 2.82
# Saved animation to stacked_12k_T_C_w_cubes.gif

# %%
### MAKE 3D ANIMATION ###

import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import matplotlib.colors as mcolors
import matplotlib.cm as cm

# ============================================================
# Helper functions
# ============================================================

def plot_contours_on_plane(ax, A, B, F, levels, colors, plane, const, zorder=10, linewidth=0.5):
    """
    Make 2D contours of F(A,B), then draw them as 3D lines.

    plane = "xy": A=x, B=y, const=z
    plane = "xz": A=x, B=z, const=y
    plane = "yz": A=y, B=z, const=x
    """
    fig_tmp, ax_tmp = plt.subplots()
    cs = ax_tmp.contour(A, B, F, levels=levels)
    plt.close(fig_tmp)

    for ilev, segs in enumerate(cs.allsegs):
        color = colors[ilev]

        for seg in segs:
            if seg.shape[0] < 2:
                continue

            a = seg[:, 0]
            b = seg[:, 1]

            if plane == "xy":
                ax.plot(a, b, const*np.ones_like(a),
                        color=color, linewidth=linewidth,zorder=zorder)

            elif plane == "xz":
                ax.plot(a, const*np.ones_like(a), b,
                        color=color, linewidth=linewidth,zorder=zorder)

            elif plane == "yz":
                ax.plot(const*np.ones_like(a), a, b,
                        color=color, linewidth=linewidth,zorder=zorder)

def get_coord(dset, dim_index):
    keys = list(dset.dims[dim_index].keys())
    if len(keys) == 0:
        raise ValueError(f"No coordinate scale found for dimension {dim_index}")
    return np.asarray(dset.dims[dim_index][keys[0]])


def find_snapshot_files(snapshot_dir="snapshots", file_prefix="snapshots_s"):
    files = []
    i = 1
    while True:
        fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
        if os.path.exists(fname):
            files.append(fname)
            i += 1
        else:
            break

    if len(files) == 0:
        raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

    return files


def make_cube_slice_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="cube_slices.gif",

    C_task="C",
    C_vmin=None,
    C_vmax=None,
    C_cmap=None,
    Cscale_factor=0.8,

    z_index=-5,      # xy slice
    y_index=64,      # xz slice
    x_index=64,      # yz slice

    Vtask_xy="vorticity_z",
    Vtask_xz="vorticity_y",
    Vtask_yz="vorticity_x",
    V_levels_base=None,
    Vscale_factor=0.8,
    Vcolor_clip_fraction=0.1,
    V_cmap_name="RdBu",

    fps=4,
    framecutoff=None,
    dpi=150,
    figsize=(9, 7),
    elev=22,
    azim=-55,
):
    """
    Make a 3D cube-style animation showing:
      - xy slice at fixed z_index
      - xz slice at fixed y_index
      - yz slice at fixed x_index

    C_task is plotted as colored surfaces.
    Vtask_* are contoured on their corresponding planes.
    """

    if C_cmap is None:
        C_cmap = mcolors.LinearSegmentedColormap.from_list(
            "brown_to_red",
            [
                (0.00, "black"),
                (0.15, "saddlebrown"),
                (1.00, "lightcoral"),
            ]
        )
    else:
        C_cmap = cm.get_cmap(C_cmap)

    if V_levels_base is None:
        V_levels_base = np.asarray([
            -0.25, -0.2, -0.15, -0.1, -0.05,
             0.05,  0.1,  0.15,  0.2,  0.25
        ])

    contour_cmap = cm.get_cmap(V_cmap_name)

    files = find_snapshot_files(snapshot_dir, file_prefix)
    print(f"Found {len(files)} snapshot files.")

    # --------------------------------------------------------
    # Collect frames and vorticity scale
    # --------------------------------------------------------
    frames = []
    Vmax_frames = []
    Vmax_frames2 = []
    Cmax_frames = []

    for fname in files:
        print(f"Scanning {fname}")
        with h5py.File(fname, mode="r") as file:
            C_dset = file["tasks"][C_task]
            t = np.asarray(C_dset.dims[0]["sim_time"])
            nt = C_dset.shape[0]

            for it in range(nt):
                frames.append((fname, it, t[it]))

                Vxy = np.asarray(file["tasks"][Vtask_xy][it, :, :, z_index])
                Vxz = np.asarray(file["tasks"][Vtask_xz][it, :, y_index, :])
                Vyz = np.asarray(file["tasks"][Vtask_yz][it, x_index, :, :])

                Vmax_frames.append(max(
                    np.nanmax(np.abs(Vxz)),
                    np.nanmax(np.abs(Vyz)),
                ))
                
                Vmax_frames2.append(
                    np.nanmax(np.abs(Vxy)),
                )
                
                Cmax_frames.append(np.nanmax(np.abs(file["tasks"][C_task][it, :, :, :])))

    frames = sorted(frames, key=lambda item: item[2])

    Vmax_frames = np.asarray(Vmax_frames)
    Vscale = np.nanmax(Vmax_frames[len(Vmax_frames)//2:])
    V_levels = Vscale_factor * Vscale * V_levels_base
    
    Vmax_frames2 = np.asarray(Vmax_frames) ### REMEMBER THIS
    Vscale2 = np.nanmax(Vmax_frames2[len(Vmax_frames2)//2:])
    V_levels2 = Vscale_factor * Vscale2 * V_levels_base

    contour_norm = mcolors.Normalize(
        vmin=-Vcolor_clip_fraction * Vscale,
        vmax= Vcolor_clip_fraction * Vscale,
        clip=True,
    )
    contour_norm2 = mcolors.Normalize(
        vmin=-Vcolor_clip_fraction * Vscale2,
        vmax= Vcolor_clip_fraction * Vscale2,
        clip=True,
    )
    V_colors = [contour_cmap(contour_norm(level)) for level in V_levels]
    V_colors2 = [contour_cmap(contour_norm2(level)) for level in V_levels2]
    
    Cmax_frames = np.asarray(Cmax_frames)
    Cscale = np.nanmax(Cmax_frames[len(Cmax_frames)//2:])
    
    if C_vmin is None:
        C_vmin = -Cscale * Cscale_factor
    if C_vmax is None:
        C_vmax = Cscale * Cscale_factor
    
    C_norm = mcolors.Normalize(vmin=C_vmin, vmax=C_vmax)

    print(f"Total animation frames: {len(frames)}")
    print(f"Vscale = {Vscale:.6e}")
    print(f"Vscale2 = {Vscale2:.6e}")

    # --------------------------------------------------------
    # Load coordinates
    # --------------------------------------------------------
    first_fname, first_it, first_time = frames[0]

    with h5py.File(first_fname, mode="r") as file:
        C_dset = file["tasks"][C_task]
        x = get_coord(C_dset, 1)
        y = get_coord(C_dset, 2)
        z = get_coord(C_dset, 3)

    x0, x1 = x.min(), x.max()
    y0, y1 = y.min(), y.max()
    z0, z1 = z.min(), z.max()

    xs = x[x_index]
    ys = y[y_index]
    zs = z[z_index]

    epsx = 0.002 * (x1 - x0)
    epsy = 0.002 * (y1 - y0)
    epsz = 0.002 * (z1 - z0)
    
    x_contour = xs - epsx if x_index < len(x)//2 else xs + epsx
    y_contour = ys - epsy if y_index < len(y)//2 else ys + epsy
    z_contour = zs - epsz if z_index < len(z)//2 else zs + epsz

    # Meshes for planes
    Xxy, Yxy = np.meshgrid(x, y, indexing="ij")
    Xxz, Zxz = np.meshgrid(x, z, indexing="ij")
    Yyz, Zyz = np.meshgrid(y, z, indexing="ij")

    Zxy = np.full_like(Xxy, zs)
    Yxz = np.full_like(Xxz, ys)
    Xyz = np.full_like(Yyz, xs)

    # --------------------------------------------------------
    # Figure setup
    # --------------------------------------------------------
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111, projection="3d")

    def draw_frame(fname, it, sim_time):
        ax.clear()

        with h5py.File(fname, mode="r") as file:
            Cxy = np.asarray(file["tasks"][C_task][it, :, :, z_index])
            Cxz = np.asarray(file["tasks"][C_task][it, :, y_index, :])
            Cyz = np.asarray(file["tasks"][C_task][it, x_index, :, :])

            Vxy = np.asarray(file["tasks"][Vtask_xy][it, :, :, z_index-10]) #REMEMBER THIS
            Vxz = np.asarray(file["tasks"][Vtask_xz][it, :, y_index, :])
            Vyz = np.asarray(file["tasks"][Vtask_yz][it, x_index, :, :])

        # Colored C surfaces
        ax.plot_surface(
            Xxy, Yxy, Zxy,
            facecolors=C_cmap(C_norm(Cxy)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=0.90,
            zorder=0,
        )

        ax.plot_surface(
            Xxz, Yxz, Zxz,
            facecolors=C_cmap(C_norm(Cxz)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=0.90,
            zorder=0,
        )

        ax.plot_surface(
            Xyz, Yyz, Zyz,
            facecolors=C_cmap(C_norm(Cyz)),
            rstride=1, cstride=1,
            shade=False,
            linewidth=0,
            antialiased=False,
            alpha=0.90,
            zorder=0,
        )

        # Vorticity contours drawn manually as 3D lines
        plot_contours_on_plane(
            ax, Xxy, Yxy, Vxy,
            levels=V_levels2,
            colors=V_colors2,
            plane="xy",
            const=z_contour,
            linewidth=0.7,
            zorder=10,
        )
        
        plot_contours_on_plane(
            ax, Xxz, Zxz, Vxz,
            levels=V_levels,
            colors=V_colors,
            plane="xz",
            const=y_contour,
            linewidth=0.7,
            zorder=10,
        )
        
        plot_contours_on_plane(
            ax, Yyz, Zyz, Vyz,
            levels=V_levels,
            colors=V_colors,
            plane="yz",
            const=x_contour,
            linewidth=0.7,
            zorder=10,
        )

        ax.set_xlim(x0 - epsx, x1 + epsx)
        ax.set_ylim(y0 - epsy, y1 + epsy)
        ax.set_zlim(z0 - epsz, z1 + epsz)

        ax.set_xlabel("x", labelpad=14)
        ax.set_ylabel("y", labelpad=14)
        ax.set_zlabel("z", labelpad=18)

        ax.set_title(f"time = {sim_time:.2f}")

        ax.view_init(elev=elev, azim=azim)
        ax.set_box_aspect((x1 - x0, y1 - y0, z1 - z0))

        return ax.collections

    draw_frame(first_fname, first_it, first_time)

    mappable_C = cm.ScalarMappable(norm=C_norm, cmap=C_cmap)
    mappable_C.set_array([])
    cbar = fig.colorbar(mappable_C, ax=ax, shrink=0.65, pad=0.1)
    cbar.set_label(C_task)

    #plt.tight_layout()

    def update(frame_number):
        fname, it, sim_time = frames[frame_number]
        draw_frame(fname, it, sim_time)

        print(
            f"Frame {frame_number + 1}/{len(frames)}: "
            f"{fname}, index {it}, time {sim_time:.2f}"
        )

        return ax.collections

    if framecutoff:
        framenum = framecutoff
    else:
        framenum = len(frames)
    
    ani = animation.FuncAnimation(
        fig,
        update,
        frames=framenum,
        interval=1000 / fps,
        blit=False,
    )

    ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)
    print(f"Saved animation to {output_name}")

# %%
# ============================================================
# Run it here: all changes go here
# ============================================================

make_cube_slice_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="mantle3D_cube_Cvort.gif",

    C_task="C",
    C_vmin=0,
    C_vmax=1,

    z_index = 64-8,
    y_index = 0,
    x_index = 0,

    Vtask_xy="vorticity_z",
    Vtask_xz="vorticity_y",
    Vtask_yz="vorticity_x",

    V_levels_base=np.asarray([
        -0.25, -0.2, -0.15, -0.1, -0.05,
         0.05,  0.1,  0.15,  0.2,  0.25
    ]),

    Vscale_factor=0.8,
    Vcolor_clip_fraction=0.1,
    V_cmap_name="PRGn",

    fps=4,
#    framecutoff=2,
    dpi=150,
    figsize=(9, 7),
    elev=22, #higher means more top down view
    azim=-130, #angle of view (where 0 means looking down y axis toward negative y at xz plane)
)
# Out:
# <ipython-input-8-4f165a0afb3c>:131: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   contour_cmap = cm.get_cmap(V_cmap_name)
# Found 17 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# Scanning snapshots/snapshots_s10.h5
# Scanning snapshots/snapshots_s11.h5
# Scanning snapshots/snapshots_s12.h5
# Scanning snapshots/snapshots_s13.h5
# Scanning snapshots/snapshots_s14.h5
# Scanning snapshots/snapshots_s15.h5
# Scanning snapshots/snapshots_s16.h5
# Scanning snapshots/snapshots_s17.h5
# Total animation frames: 170
# Vscale = 3.197977e+02
# Vscale2 = 3.197977e+02
# Frame 1/170: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/170: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/170: snapshots/snapshots_s1.h5, index 1, time 0.10
# Frame 3/170: snapshots/snapshots_s1.h5, index 2, time 0.10
# Frame 4/170: snapshots/snapshots_s1.h5, index 3, time 0.10
# Frame 5/170: snapshots/snapshots_s1.h5, index 4, time 0.10
# Frame 6/170: snapshots/snapshots_s1.h5, index 5, time 0.10
# Frame 7/170: snapshots/snapshots_s1.h5, index 6, time 0.10
# Frame 8/170: snapshots/snapshots_s1.h5, index 7, time 0.10
# Frame 9/170: snapshots/snapshots_s1.h5, index 8, time 0.11
# Frame 10/170: snapshots/snapshots_s1.h5, index 9, time 0.11
# Frame 11/170: snapshots/snapshots_s2.h5, index 0, time 0.11
# Frame 12/170: snapshots/snapshots_s2.h5, index 1, time 0.11
# Frame 13/170: snapshots/snapshots_s2.h5, index 2, time 0.12
# Frame 14/170: snapshots/snapshots_s2.h5, index 3, time 0.13
# Frame 15/170: snapshots/snapshots_s2.h5, index 4, time 0.14
# Frame 16/170: snapshots/snapshots_s2.h5, index 5, time 0.16
# Frame 17/170: snapshots/snapshots_s2.h5, index 6, time 0.17
# Frame 18/170: snapshots/snapshots_s2.h5, index 7, time 0.19
# Frame 19/170: snapshots/snapshots_s2.h5, index 8, time 0.21
# Frame 20/170: snapshots/snapshots_s2.h5, index 9, time 0.23
# Frame 21/170: snapshots/snapshots_s3.h5, index 0, time 0.27
# Frame 22/170: snapshots/snapshots_s3.h5, index 1, time 0.30
# Frame 23/170: snapshots/snapshots_s3.h5, index 2, time 0.35
# Frame 24/170: snapshots/snapshots_s3.h5, index 3, time 0.41
# Frame 25/170: snapshots/snapshots_s3.h5, index 4, time 0.48
# Frame 26/170: snapshots/snapshots_s3.h5, index 5, time 0.54
# Frame 27/170: snapshots/snapshots_s3.h5, index 6, time 0.61
# Frame 28/170: snapshots/snapshots_s3.h5, index 7, time 0.68
# Frame 29/170: snapshots/snapshots_s3.h5, index 8, time 0.74
# Frame 30/170: snapshots/snapshots_s3.h5, index 9, time 0.79
# Frame 31/170: snapshots/snapshots_s4.h5, index 0, time 0.83
# Frame 32/170: snapshots/snapshots_s4.h5, index 1, time 0.86
# Frame 33/170: snapshots/snapshots_s4.h5, index 2, time 0.88
# Frame 34/170: snapshots/snapshots_s4.h5, index 3, time 0.89
# Frame 35/170: snapshots/snapshots_s4.h5, index 4, time 0.91
# Frame 36/170: snapshots/snapshots_s4.h5, index 5, time 0.92
# Frame 37/170: snapshots/snapshots_s4.h5, index 6, time 0.94
# Frame 38/170: snapshots/snapshots_s4.h5, index 7, time 0.95
# Frame 39/170: snapshots/snapshots_s4.h5, index 8, time 0.96
# Frame 40/170: snapshots/snapshots_s4.h5, index 9, time 0.98
# Frame 41/170: snapshots/snapshots_s5.h5, index 0, time 0.99
# Frame 42/170: snapshots/snapshots_s5.h5, index 1, time 1.00
# Frame 43/170: snapshots/snapshots_s5.h5, index 2, time 1.01
# Frame 44/170: snapshots/snapshots_s5.h5, index 3, time 1.02
# Frame 45/170: snapshots/snapshots_s5.h5, index 4, time 1.04
# Frame 46/170: snapshots/snapshots_s5.h5, index 5, time 1.05
# Frame 47/170: snapshots/snapshots_s5.h5, index 6, time 1.07
# Frame 48/170: snapshots/snapshots_s5.h5, index 7, time 1.08
# Frame 49/170: snapshots/snapshots_s5.h5, index 8, time 1.10
# Frame 50/170: snapshots/snapshots_s5.h5, index 9, time 1.11
# Frame 51/170: snapshots/snapshots_s6.h5, index 0, time 1.12
# Frame 52/170: snapshots/snapshots_s6.h5, index 1, time 1.14
# Frame 53/170: snapshots/snapshots_s6.h5, index 2, time 1.15
# Frame 54/170: snapshots/snapshots_s6.h5, index 3, time 1.17
# Frame 55/170: snapshots/snapshots_s6.h5, index 4, time 1.18
# Frame 56/170: snapshots/snapshots_s6.h5, index 5, time 1.19
# Frame 57/170: snapshots/snapshots_s6.h5, index 6, time 1.20
# Frame 58/170: snapshots/snapshots_s6.h5, index 7, time 1.21
# Frame 59/170: snapshots/snapshots_s6.h5, index 8, time 1.23
# Frame 60/170: snapshots/snapshots_s6.h5, index 9, time 1.24
# Frame 61/170: snapshots/snapshots_s7.h5, index 0, time 1.25
# Frame 62/170: snapshots/snapshots_s7.h5, index 1, time 1.26
# Frame 63/170: snapshots/snapshots_s7.h5, index 2, time 1.27
# Frame 64/170: snapshots/snapshots_s7.h5, index 3, time 1.28
# Frame 65/170: snapshots/snapshots_s7.h5, index 4, time 1.29
# Frame 66/170: snapshots/snapshots_s7.h5, index 5, time 1.30
# Frame 67/170: snapshots/snapshots_s7.h5, index 6, time 1.31
# Frame 68/170: snapshots/snapshots_s7.h5, index 7, time 1.32
# Frame 69/170: snapshots/snapshots_s7.h5, index 8, time 1.34
# Frame 70/170: snapshots/snapshots_s7.h5, index 9, time 1.35
# Frame 71/170: snapshots/snapshots_s8.h5, index 0, time 1.36
# Frame 72/170: snapshots/snapshots_s8.h5, index 1, time 1.37
# Frame 73/170: snapshots/snapshots_s8.h5, index 2, time 1.38
# Frame 74/170: snapshots/snapshots_s8.h5, index 3, time 1.39
# Frame 75/170: snapshots/snapshots_s8.h5, index 4, time 1.41
# Frame 76/170: snapshots/snapshots_s8.h5, index 5, time 1.42
# Frame 77/170: snapshots/snapshots_s8.h5, index 6, time 1.43
# Frame 78/170: snapshots/snapshots_s8.h5, index 7, time 1.44
# Frame 79/170: snapshots/snapshots_s8.h5, index 8, time 1.45
# Frame 80/170: snapshots/snapshots_s8.h5, index 9, time 1.46
# Frame 81/170: snapshots/snapshots_s9.h5, index 0, time 1.48
# Frame 82/170: snapshots/snapshots_s9.h5, index 1, time 1.49
# Frame 83/170: snapshots/snapshots_s9.h5, index 2, time 1.51
# Frame 84/170: snapshots/snapshots_s9.h5, index 3, time 1.53
# Frame 85/170: snapshots/snapshots_s9.h5, index 4, time 1.54
# Frame 86/170: snapshots/snapshots_s9.h5, index 5, time 1.56
# Frame 87/170: snapshots/snapshots_s9.h5, index 6, time 1.57
# Frame 88/170: snapshots/snapshots_s9.h5, index 7, time 1.58
# Frame 89/170: snapshots/snapshots_s9.h5, index 8, time 1.59
# Frame 90/170: snapshots/snapshots_s9.h5, index 9, time 1.61
# Frame 91/170: snapshots/snapshots_s10.h5, index 0, time 1.62
# Frame 92/170: snapshots/snapshots_s10.h5, index 1, time 1.63
# Frame 93/170: snapshots/snapshots_s10.h5, index 2, time 1.64
# Frame 94/170: snapshots/snapshots_s10.h5, index 3, time 1.65
# Frame 95/170: snapshots/snapshots_s10.h5, index 4, time 1.66
# Frame 96/170: snapshots/snapshots_s10.h5, index 5, time 1.68
# Frame 97/170: snapshots/snapshots_s10.h5, index 6, time 1.69
# Frame 98/170: snapshots/snapshots_s10.h5, index 7, time 1.70
# Frame 99/170: snapshots/snapshots_s10.h5, index 8, time 1.72
# Frame 100/170: snapshots/snapshots_s10.h5, index 9, time 1.73
# Frame 101/170: snapshots/snapshots_s11.h5, index 0, time 1.74
# Frame 102/170: snapshots/snapshots_s11.h5, index 1, time 1.75
# Frame 103/170: snapshots/snapshots_s11.h5, index 2, time 1.76
# Frame 104/170: snapshots/snapshots_s11.h5, index 3, time 1.77
# Frame 105/170: snapshots/snapshots_s11.h5, index 4, time 1.78
# Frame 106/170: snapshots/snapshots_s11.h5, index 5, time 1.80
# Frame 107/170: snapshots/snapshots_s11.h5, index 6, time 1.81
# Frame 108/170: snapshots/snapshots_s11.h5, index 7, time 1.82
# Frame 109/170: snapshots/snapshots_s11.h5, index 8, time 1.84
# Frame 110/170: snapshots/snapshots_s11.h5, index 9, time 1.85
# Frame 111/170: snapshots/snapshots_s12.h5, index 0, time 1.86
# Frame 112/170: snapshots/snapshots_s12.h5, index 1, time 1.87
# Frame 113/170: snapshots/snapshots_s12.h5, index 2, time 1.88
# Frame 114/170: snapshots/snapshots_s12.h5, index 3, time 1.90
# Frame 115/170: snapshots/snapshots_s12.h5, index 4, time 1.91
# Frame 116/170: snapshots/snapshots_s12.h5, index 5, time 1.92
# Frame 117/170: snapshots/snapshots_s12.h5, index 6, time 1.94
# Frame 118/170: snapshots/snapshots_s12.h5, index 7, time 1.95
# Frame 119/170: snapshots/snapshots_s12.h5, index 8, time 1.96
# Frame 120/170: snapshots/snapshots_s12.h5, index 9, time 1.97
# Frame 121/170: snapshots/snapshots_s13.h5, index 0, time 1.98
# Frame 122/170: snapshots/snapshots_s13.h5, index 1, time 1.99
# Frame 123/170: snapshots/snapshots_s13.h5, index 2, time 2.00
# Frame 124/170: snapshots/snapshots_s13.h5, index 3, time 2.01
# Frame 125/170: snapshots/snapshots_s13.h5, index 4, time 2.03
# Frame 126/170: snapshots/snapshots_s13.h5, index 5, time 2.04
# Frame 127/170: snapshots/snapshots_s13.h5, index 6, time 2.06
# Frame 128/170: snapshots/snapshots_s13.h5, index 7, time 2.07
# Frame 129/170: snapshots/snapshots_s13.h5, index 8, time 2.08
# Frame 130/170: snapshots/snapshots_s13.h5, index 9, time 2.09
# Frame 131/170: snapshots/snapshots_s14.h5, index 0, time 2.11
# Frame 132/170: snapshots/snapshots_s14.h5, index 1, time 2.12
# Frame 133/170: snapshots/snapshots_s14.h5, index 2, time 2.13
# Frame 134/170: snapshots/snapshots_s14.h5, index 3, time 2.14
# Frame 135/170: snapshots/snapshots_s14.h5, index 4, time 2.16
# Frame 136/170: snapshots/snapshots_s14.h5, index 5, time 2.17
# Frame 137/170: snapshots/snapshots_s14.h5, index 6, time 2.18
# Frame 138/170: snapshots/snapshots_s14.h5, index 7, time 2.19
# Frame 139/170: snapshots/snapshots_s14.h5, index 8, time 2.20
# Frame 140/170: snapshots/snapshots_s14.h5, index 9, time 2.21
# Frame 141/170: snapshots/snapshots_s15.h5, index 0, time 2.23
# Frame 142/170: snapshots/snapshots_s15.h5, index 1, time 2.24
# Frame 143/170: snapshots/snapshots_s15.h5, index 2, time 2.25
# Frame 144/170: snapshots/snapshots_s15.h5, index 3, time 2.27
# Frame 145/170: snapshots/snapshots_s15.h5, index 4, time 2.28
# Frame 146/170: snapshots/snapshots_s15.h5, index 5, time 2.29
# Frame 147/170: snapshots/snapshots_s15.h5, index 6, time 2.30
# Frame 148/170: snapshots/snapshots_s15.h5, index 7, time 2.30
# Frame 149/170: snapshots/snapshots_s15.h5, index 8, time 2.31
# Frame 150/170: snapshots/snapshots_s15.h5, index 9, time 2.32
# Frame 151/170: snapshots/snapshots_s16.h5, index 0, time 2.33
# Frame 152/170: snapshots/snapshots_s16.h5, index 1, time 2.34
# Frame 153/170: snapshots/snapshots_s16.h5, index 2, time 2.36
# Frame 154/170: snapshots/snapshots_s16.h5, index 3, time 2.37
# Frame 155/170: snapshots/snapshots_s16.h5, index 4, time 2.38
# Frame 156/170: snapshots/snapshots_s16.h5, index 5, time 2.39
# Frame 157/170: snapshots/snapshots_s16.h5, index 6, time 2.40
# Frame 158/170: snapshots/snapshots_s16.h5, index 7, time 2.41
# Frame 159/170: snapshots/snapshots_s16.h5, index 8, time 2.42
# Frame 160/170: snapshots/snapshots_s16.h5, index 9, time 2.43
# Frame 161/170: snapshots/snapshots_s17.h5, index 0, time 2.44
# Frame 162/170: snapshots/snapshots_s17.h5, index 1, time 2.45
# Frame 163/170: snapshots/snapshots_s17.h5, index 2, time 2.46
# Frame 164/170: snapshots/snapshots_s17.h5, index 3, time 2.47
# Frame 165/170: snapshots/snapshots_s17.h5, index 4, time 2.48
# Frame 166/170: snapshots/snapshots_s17.h5, index 5, time 2.49
# Frame 167/170: snapshots/snapshots_s17.h5, index 6, time 2.50
# Frame 168/170: snapshots/snapshots_s17.h5, index 7, time 2.52
# Frame 169/170: snapshots/snapshots_s17.h5, index 8, time 2.53
# Frame 170/170: snapshots/snapshots_s17.h5, index 9, time 2.54
# Saved animation to mantle3D_cube_Cvort.gif

# %%
# ============================================================
# Run it here: all changes go here
# ============================================================

make_cube_slice_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="mantle3D_cube_wC.gif",

    C_task="w",
    C_cmap="RdBu_r",

    z_index = -10,
    y_index = 1,
    x_index = 1,

    Vtask_xy="C",
    Vtask_xz="C",
    Vtask_yz="C",

    V_levels_base=np.asarray([
        0.02, 0.04, 0.06, 0.08, 0.1,0.5,0.9
    ]),

    Vscale_factor=1.0,
    Vcolor_clip_fraction=1.0,
    V_cmap_name="copper",

    fps=4,
#    framecutoff=2,
    dpi=150,
    figsize=(9, 7),
    elev=22, #higher means more top down view
    azim=-130, #angle of view (where 0 means looking down y axis toward negative y at xz plane)
)
# Out:
# <ipython-input-6-66f0432fa375>:123: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   C_cmap = cm.get_cmap(C_cmap)
# <ipython-input-6-66f0432fa375>:131: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   contour_cmap = cm.get_cmap(V_cmap_name)
# Found 16 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# Scanning snapshots/snapshots_s10.h5
# Scanning snapshots/snapshots_s11.h5
# Scanning snapshots/snapshots_s12.h5
# Scanning snapshots/snapshots_s13.h5
# Scanning snapshots/snapshots_s14.h5
# Scanning snapshots/snapshots_s15.h5
# Scanning snapshots/snapshots_s16.h5
# Total animation frames: 156
# Vscale = 1.093126e+00
# Vscale2 = 1.093126e+00
# Frame 1/156: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/156: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/156: snapshots/snapshots_s1.h5, index 1, time 0.10
# Frame 3/156: snapshots/snapshots_s1.h5, index 2, time 0.10
# Frame 4/156: snapshots/snapshots_s1.h5, index 3, time 0.10
# Frame 5/156: snapshots/snapshots_s1.h5, index 4, time 0.10
# Frame 6/156: snapshots/snapshots_s1.h5, index 5, time 0.10
# Frame 7/156: snapshots/snapshots_s1.h5, index 6, time 0.10
# Frame 8/156: snapshots/snapshots_s1.h5, index 7, time 0.10
# Frame 9/156: snapshots/snapshots_s1.h5, index 8, time 0.11
# Frame 10/156: snapshots/snapshots_s1.h5, index 9, time 0.11
# Frame 11/156: snapshots/snapshots_s2.h5, index 0, time 0.11
# Frame 12/156: snapshots/snapshots_s2.h5, index 1, time 0.11
# Frame 13/156: snapshots/snapshots_s2.h5, index 2, time 0.12
# Frame 14/156: snapshots/snapshots_s2.h5, index 3, time 0.13
# Frame 15/156: snapshots/snapshots_s2.h5, index 4, time 0.14
# Frame 16/156: snapshots/snapshots_s2.h5, index 5, time 0.16
# Frame 17/156: snapshots/snapshots_s2.h5, index 6, time 0.17
# Frame 18/156: snapshots/snapshots_s2.h5, index 7, time 0.19
# Frame 19/156: snapshots/snapshots_s2.h5, index 8, time 0.21
# Frame 20/156: snapshots/snapshots_s2.h5, index 9, time 0.23
# Frame 21/156: snapshots/snapshots_s3.h5, index 0, time 0.27
# Frame 22/156: snapshots/snapshots_s3.h5, index 1, time 0.30
# Frame 23/156: snapshots/snapshots_s3.h5, index 2, time 0.35
# Frame 24/156: snapshots/snapshots_s3.h5, index 3, time 0.41
# Frame 25/156: snapshots/snapshots_s3.h5, index 4, time 0.48
# Frame 26/156: snapshots/snapshots_s3.h5, index 5, time 0.54
# Frame 27/156: snapshots/snapshots_s3.h5, index 6, time 0.61
# Frame 28/156: snapshots/snapshots_s3.h5, index 7, time 0.68
# Frame 29/156: snapshots/snapshots_s3.h5, index 8, time 0.74
# Frame 30/156: snapshots/snapshots_s3.h5, index 9, time 0.79
# Frame 31/156: snapshots/snapshots_s4.h5, index 0, time 0.83
# Frame 32/156: snapshots/snapshots_s4.h5, index 1, time 0.86
# Frame 33/156: snapshots/snapshots_s4.h5, index 2, time 0.88
# Frame 34/156: snapshots/snapshots_s4.h5, index 3, time 0.89
# Frame 35/156: snapshots/snapshots_s4.h5, index 4, time 0.91
# Frame 36/156: snapshots/snapshots_s4.h5, index 5, time 0.92
# Frame 37/156: snapshots/snapshots_s4.h5, index 6, time 0.94
# Frame 38/156: snapshots/snapshots_s4.h5, index 7, time 0.95
# Frame 39/156: snapshots/snapshots_s4.h5, index 8, time 0.96
# Frame 40/156: snapshots/snapshots_s4.h5, index 9, time 0.98
# Frame 41/156: snapshots/snapshots_s5.h5, index 0, time 0.99
# Frame 42/156: snapshots/snapshots_s5.h5, index 1, time 1.00
# Frame 43/156: snapshots/snapshots_s5.h5, index 2, time 1.01
# Frame 44/156: snapshots/snapshots_s5.h5, index 3, time 1.02
# Frame 45/156: snapshots/snapshots_s5.h5, index 4, time 1.04
# Frame 46/156: snapshots/snapshots_s5.h5, index 5, time 1.05
# Frame 47/156: snapshots/snapshots_s5.h5, index 6, time 1.07
# Frame 48/156: snapshots/snapshots_s5.h5, index 7, time 1.08
# Frame 49/156: snapshots/snapshots_s5.h5, index 8, time 1.10
# Frame 50/156: snapshots/snapshots_s5.h5, index 9, time 1.11
# Frame 51/156: snapshots/snapshots_s6.h5, index 0, time 1.12
# Frame 52/156: snapshots/snapshots_s6.h5, index 1, time 1.14
# Frame 53/156: snapshots/snapshots_s6.h5, index 2, time 1.15
# Frame 54/156: snapshots/snapshots_s6.h5, index 3, time 1.17
# Frame 55/156: snapshots/snapshots_s6.h5, index 4, time 1.18
# Frame 56/156: snapshots/snapshots_s6.h5, index 5, time 1.19
# Frame 57/156: snapshots/snapshots_s6.h5, index 6, time 1.20
# Frame 58/156: snapshots/snapshots_s6.h5, index 7, time 1.21
# Frame 59/156: snapshots/snapshots_s6.h5, index 8, time 1.23
# Frame 60/156: snapshots/snapshots_s6.h5, index 9, time 1.24
# Frame 61/156: snapshots/snapshots_s7.h5, index 0, time 1.25
# Frame 62/156: snapshots/snapshots_s7.h5, index 1, time 1.26
# Frame 63/156: snapshots/snapshots_s7.h5, index 2, time 1.27
# Frame 64/156: snapshots/snapshots_s7.h5, index 3, time 1.28
# Frame 65/156: snapshots/snapshots_s7.h5, index 4, time 1.29
# Frame 66/156: snapshots/snapshots_s7.h5, index 5, time 1.30
# Frame 67/156: snapshots/snapshots_s7.h5, index 6, time 1.31
# Frame 68/156: snapshots/snapshots_s7.h5, index 7, time 1.32
# Frame 69/156: snapshots/snapshots_s7.h5, index 8, time 1.34
# Frame 70/156: snapshots/snapshots_s7.h5, index 9, time 1.35
# Frame 71/156: snapshots/snapshots_s8.h5, index 0, time 1.36
# Frame 72/156: snapshots/snapshots_s8.h5, index 1, time 1.37
# Frame 73/156: snapshots/snapshots_s8.h5, index 2, time 1.38
# Frame 74/156: snapshots/snapshots_s8.h5, index 3, time 1.39
# Frame 75/156: snapshots/snapshots_s8.h5, index 4, time 1.41
# Frame 76/156: snapshots/snapshots_s8.h5, index 5, time 1.42
# Frame 77/156: snapshots/snapshots_s8.h5, index 6, time 1.43
# Frame 78/156: snapshots/snapshots_s8.h5, index 7, time 1.44
# Frame 79/156: snapshots/snapshots_s8.h5, index 8, time 1.45
# Frame 80/156: snapshots/snapshots_s8.h5, index 9, time 1.46
# Frame 81/156: snapshots/snapshots_s9.h5, index 0, time 1.48
# Frame 82/156: snapshots/snapshots_s9.h5, index 1, time 1.49
# Frame 83/156: snapshots/snapshots_s9.h5, index 2, time 1.51
# Frame 84/156: snapshots/snapshots_s9.h5, index 3, time 1.53
# Frame 85/156: snapshots/snapshots_s9.h5, index 4, time 1.54
# Frame 86/156: snapshots/snapshots_s9.h5, index 5, time 1.56
# Frame 87/156: snapshots/snapshots_s9.h5, index 6, time 1.57
# Frame 88/156: snapshots/snapshots_s9.h5, index 7, time 1.58
# Frame 89/156: snapshots/snapshots_s9.h5, index 8, time 1.59
# Frame 90/156: snapshots/snapshots_s9.h5, index 9, time 1.61
# Frame 91/156: snapshots/snapshots_s10.h5, index 0, time 1.62
# Frame 92/156: snapshots/snapshots_s10.h5, index 1, time 1.63
# Frame 93/156: snapshots/snapshots_s10.h5, index 2, time 1.64
# Frame 94/156: snapshots/snapshots_s10.h5, index 3, time 1.65
# Frame 95/156: snapshots/snapshots_s10.h5, index 4, time 1.66
# Frame 96/156: snapshots/snapshots_s10.h5, index 5, time 1.68
# Frame 97/156: snapshots/snapshots_s10.h5, index 6, time 1.69
# Frame 98/156: snapshots/snapshots_s10.h5, index 7, time 1.70
# Frame 99/156: snapshots/snapshots_s10.h5, index 8, time 1.72
# Frame 100/156: snapshots/snapshots_s10.h5, index 9, time 1.73
# Frame 101/156: snapshots/snapshots_s11.h5, index 0, time 1.74
# Frame 102/156: snapshots/snapshots_s11.h5, index 1, time 1.75
# Frame 103/156: snapshots/snapshots_s11.h5, index 2, time 1.76
# Frame 104/156: snapshots/snapshots_s11.h5, index 3, time 1.77
# Frame 105/156: snapshots/snapshots_s11.h5, index 4, time 1.78
# Frame 106/156: snapshots/snapshots_s11.h5, index 5, time 1.80
# Frame 107/156: snapshots/snapshots_s11.h5, index 6, time 1.81
# Frame 108/156: snapshots/snapshots_s11.h5, index 7, time 1.82
# Frame 109/156: snapshots/snapshots_s11.h5, index 8, time 1.84
# Frame 110/156: snapshots/snapshots_s11.h5, index 9, time 1.85
# Frame 111/156: snapshots/snapshots_s12.h5, index 0, time 1.86
# Frame 112/156: snapshots/snapshots_s12.h5, index 1, time 1.87
# Frame 113/156: snapshots/snapshots_s12.h5, index 2, time 1.88
# Frame 114/156: snapshots/snapshots_s12.h5, index 3, time 1.90
# Frame 115/156: snapshots/snapshots_s12.h5, index 4, time 1.91
# Frame 116/156: snapshots/snapshots_s12.h5, index 5, time 1.92
# Frame 117/156: snapshots/snapshots_s12.h5, index 6, time 1.94
# Frame 118/156: snapshots/snapshots_s12.h5, index 7, time 1.95
# Frame 119/156: snapshots/snapshots_s12.h5, index 8, time 1.96
# Frame 120/156: snapshots/snapshots_s12.h5, index 9, time 1.97
# Frame 121/156: snapshots/snapshots_s13.h5, index 0, time 1.98
# Frame 122/156: snapshots/snapshots_s13.h5, index 1, time 1.99
# Frame 123/156: snapshots/snapshots_s13.h5, index 2, time 2.00
# Frame 124/156: snapshots/snapshots_s13.h5, index 3, time 2.01
# Frame 125/156: snapshots/snapshots_s13.h5, index 4, time 2.03
# Frame 126/156: snapshots/snapshots_s13.h5, index 5, time 2.04
# Frame 127/156: snapshots/snapshots_s13.h5, index 6, time 2.06
# Frame 128/156: snapshots/snapshots_s13.h5, index 7, time 2.07
# Frame 129/156: snapshots/snapshots_s13.h5, index 8, time 2.08
# Frame 130/156: snapshots/snapshots_s13.h5, index 9, time 2.09
# Frame 131/156: snapshots/snapshots_s14.h5, index 0, time 2.11
# Frame 132/156: snapshots/snapshots_s14.h5, index 1, time 2.12
# Frame 133/156: snapshots/snapshots_s14.h5, index 2, time 2.13
# Frame 134/156: snapshots/snapshots_s14.h5, index 3, time 2.14
# Frame 135/156: snapshots/snapshots_s14.h5, index 4, time 2.16
# Frame 136/156: snapshots/snapshots_s14.h5, index 5, time 2.17
# Frame 137/156: snapshots/snapshots_s14.h5, index 6, time 2.18
# Frame 138/156: snapshots/snapshots_s14.h5, index 7, time 2.19
# Frame 139/156: snapshots/snapshots_s14.h5, index 8, time 2.20
# Frame 140/156: snapshots/snapshots_s14.h5, index 9, time 2.21
# Frame 141/156: snapshots/snapshots_s15.h5, index 0, time 2.23
# Frame 142/156: snapshots/snapshots_s15.h5, index 1, time 2.24
# Frame 143/156: snapshots/snapshots_s15.h5, index 2, time 2.25
# Frame 144/156: snapshots/snapshots_s15.h5, index 3, time 2.27
# Frame 145/156: snapshots/snapshots_s15.h5, index 4, time 2.28
# Frame 146/156: snapshots/snapshots_s15.h5, index 5, time 2.29
# Frame 147/156: snapshots/snapshots_s15.h5, index 6, time 2.30
# Frame 148/156: snapshots/snapshots_s15.h5, index 7, time 2.30
# Frame 149/156: snapshots/snapshots_s15.h5, index 8, time 2.31
# Frame 150/156: snapshots/snapshots_s15.h5, index 9, time 2.32
# Frame 151/156: snapshots/snapshots_s16.h5, index 0, time 2.33
# Frame 152/156: snapshots/snapshots_s16.h5, index 1, time 2.34
# Frame 153/156: snapshots/snapshots_s16.h5, index 2, time 2.36
# Frame 154/156: snapshots/snapshots_s16.h5, index 3, time 2.37
# Frame 155/156: snapshots/snapshots_s16.h5, index 4, time 2.38
# Frame 156/156: snapshots/snapshots_s16.h5, index 5, time 2.39
# Saved animation to mantle3D_cube_wC.gif

# %%
### MAKE ANIMATION OF LATERAL X-Y SLICE ###

# ----------------------------
# User settings
# ----------------------------
snapshot_dir = "snapshots"
file_prefix = "snapshots_s"
output_name = "mantle3D_xyperiodic_z-top_wC.gif"

z_index = -5          # fixed z-index for x-y slice
fps = 4
dpi = 150

C_levels = [0.25, 0.5, 0.75]  

# Brown -> olive -> green colormap
C_cmap = mcolors.LinearSegmentedColormap.from_list(
    "brown_to_green",
    ["saddlebrown", "olive", "forestgreen"]
)

C_colors = [C_cmap(i) for i in np.linspace(0, 1, len(C_levels))]

# Optional: set color limits manually, or leave as None
w_vmin = None
w_vmax = None

# ----------------------------
# Helper: get coordinate arrays from Dedalus HDF5 output
# ----------------------------
def get_coord(dset, dim_index):
    """
    Get coordinate scale from an HDF5 dataset dimension.
    For data shaped (t, nx, ny, nz):
        dim 0 = time
        dim 1 = x
        dim 2 = y
        dim 3 = z
    """
    keys = list(dset.dims[dim_index].keys())

    if len(keys) == 0:
        raise ValueError(f"No coordinate scale found for dimension {dim_index}")

    # Usually Dedalus stores the coordinate as the first/only scale.
    return np.asarray(dset.dims[dim_index][keys[0]])

# ----------------------------
# Find files in order
# ----------------------------
files = []
i = 1
while True:
    fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
    if os.path.exists(fname):
        files.append(fname)
        i += 1
    else:
        break

if len(files) == 0:
    raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

print(f"Found {len(files)} snapshot files.")

# ----------------------------
# First pass: collect frame metadata and global w limits
# ----------------------------
frames = []

if w_vmin is None or w_vmax is None:
    global_min = np.inf
    global_max = -np.inf

for fname in files:
    print(f"Scanning {fname}")
    with h5py.File(fname, mode="r") as file:
        w_dset = file["tasks"]["w"]
        T_dset = file["tasks"]["T"]
        t = np.asarray(T_dset.dims[0]["sim_time"])

        nt = w_dset.shape[0]

        for it in range(nt):
            frames.append((fname, it, t[it]))

        if w_vmin is None or w_vmax is None:
            w_slice_all = np.asarray(w_dset[int(nt/2):, :, :, z_index])

            w_rms = np.sqrt(np.nanmean(w_slice_all**2))
            w_lim = 1.5 * w_rms

            global_min = min(global_min, -w_lim)
            global_max = max(global_max,  w_lim)

if w_vmin is None:
    w_vmin = global_min
if w_vmax is None:
    w_vmax = global_max

# Symmetric color scale about zero
w_abs = max(abs(w_vmin), abs(w_vmax))
w_vmin = -w_abs
w_vmax = w_abs

print(f"Total animation frames: {len(frames)}")
print(f"w color limits: {w_vmin:.4e}, {w_vmax:.4e}")

# ----------------------------
# Load first frame and actual coordinate arrays
# ----------------------------
first_fname, first_it, first_time = frames[0]

with h5py.File(first_fname, mode="r") as file:
    w_dset = file["tasks"]["w"]

    w0 = np.asarray(file["tasks"]["w"][first_it, :, :, z_index])
    C0 = np.asarray(file["tasks"]["C"][first_it, :, :, z_index])

    x = get_coord(w_dset, 1)
    y = get_coord(w_dset, 2)
    z = get_coord(w_dset, 3)

print("x shape:", x.shape, "x min/max:", x.min(), x.max())
print("y shape:", y.shape, "y min/max:", y.min(), y.max())
print("z shape:", z.shape, "z min/max:", z.min(), z.max())
print("plotting z =", z[z_index])

nx, ny = w0.shape

if len(x) != nx:
    raise ValueError(f"x coordinate length {len(x)} does not match nx {nx}")
if len(y) != ny:
    raise ValueError(f"y coordinate length {len(y)} does not match ny {ny}")

X, Y = np.meshgrid(x, y, indexing="ij")

# ----------------------------
# Figure setup
# ----------------------------
fig, ax = plt.subplots(figsize=(6, 5))

pcm = ax.pcolormesh(
    X, Y, w0,
    shading="auto",
    vmin=w_vmin,
    vmax=w_vmax,
    cmap="RdBu"
)

cbar = fig.colorbar(pcm, ax=ax)
cbar.set_label("w")

contours = ax.contour(
    X, Y, C0,          
    levels=C_levels,
    colors=C_colors,
    linewidths=1.0,
)

ax.clabel(contours, inline=True, fontsize=8)

title = ax.set_title(f"time = {first_time:.2f}, z = {z[z_index]:.3g}")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_aspect("equal")

plt.tight_layout()

# ----------------------------
# Animation update function
# ----------------------------
def update(frame_number):
    global contours

    fname, it, sim_time = frames[frame_number]

    with h5py.File(fname, mode="r") as file:
        w_slice = np.asarray(file["tasks"]["w"][it, :, :, z_index])
        C_slice = np.asarray(file["tasks"]["C"][it, :, :, z_index])

    pcm.set_array(w_slice.ravel())

    # Remove old contours
    for coll in contours.collections:
        coll.remove()

    # Draw new contours
    contours = ax.contour(
        X, Y, C_slice,      
        levels=C_levels,
        colors=C_colors,
        linewidths=1.0,
    )

    title.set_text(f"time = {sim_time:.2f}, z = {z[z_index]:.3g}")

    print(
        f"Frame {frame_number + 1}/{len(frames)}: "
        f"{fname}, index {it}, time {sim_time:.2f}"
    )

    return [pcm, title] + contours.collections

# ----------------------------
# Save animation
# ----------------------------
ani = animation.FuncAnimation(
    fig,
    update,
    frames=len(frames),
    interval=1000 / fps,
    blit=False,
)

ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)

print(f"Saved animation to {output_name}")
# Out:
# Found 9 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# Total animation frames: 85
# w color limits: -4.9256e+00, 4.9256e+00
# x shape: (128,) x min/max: 0.0 3.96875
# y shape: (128,) y min/max: 0.0 3.96875
# z shape: (64,) z min/max: 0.00015059065189787502 0.9998494093481021
# plotting z = 0.9878510650192642
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/85: snapshots/snapshots_s1.h5, index 1, time 0.10
# Frame 3/85: snapshots/snapshots_s1.h5, index 2, time 0.10
# Frame 4/85: snapshots/snapshots_s1.h5, index 3, time 0.10
# Frame 5/85: snapshots/snapshots_s1.h5, index 4, time 0.10
# Frame 6/85: snapshots/snapshots_s1.h5, index 5, time 0.10
# Frame 7/85: snapshots/snapshots_s1.h5, index 6, time 0.10
# Frame 8/85: snapshots/snapshots_s1.h5, index 7, time 0.10
# Frame 9/85: snapshots/snapshots_s1.h5, index 8, time 0.11
# Frame 10/85: snapshots/snapshots_s1.h5, index 9, time 0.11
# Frame 11/85: snapshots/snapshots_s2.h5, index 0, time 0.11
# Frame 12/85: snapshots/snapshots_s2.h5, index 1, time 0.11
# Frame 13/85: snapshots/snapshots_s2.h5, index 2, time 0.12
# Frame 14/85: snapshots/snapshots_s2.h5, index 3, time 0.13
# Frame 15/85: snapshots/snapshots_s2.h5, index 4, time 0.14
# Frame 16/85: snapshots/snapshots_s2.h5, index 5, time 0.16
# Frame 17/85: snapshots/snapshots_s2.h5, index 6, time 0.17
# Frame 18/85: snapshots/snapshots_s2.h5, index 7, time 0.19
# Frame 19/85: snapshots/snapshots_s2.h5, index 8, time 0.21
# Frame 20/85: snapshots/snapshots_s2.h5, index 9, time 0.23
# Frame 21/85: snapshots/snapshots_s3.h5, index 0, time 0.27
# Frame 22/85: snapshots/snapshots_s3.h5, index 1, time 0.30
# Frame 23/85: snapshots/snapshots_s3.h5, index 2, time 0.35
# Frame 24/85: snapshots/snapshots_s3.h5, index 3, time 0.41
# Frame 25/85: snapshots/snapshots_s3.h5, index 4, time 0.48
# Frame 26/85: snapshots/snapshots_s3.h5, index 5, time 0.54
# Frame 27/85: snapshots/snapshots_s3.h5, index 6, time 0.61
# Frame 28/85: snapshots/snapshots_s3.h5, index 7, time 0.68
# Frame 29/85: snapshots/snapshots_s3.h5, index 8, time 0.74
# Frame 30/85: snapshots/snapshots_s3.h5, index 9, time 0.79
# Frame 31/85: snapshots/snapshots_s4.h5, index 0, time 0.83
# Frame 32/85: snapshots/snapshots_s4.h5, index 1, time 0.86
# Frame 33/85: snapshots/snapshots_s4.h5, index 2, time 0.88
# Frame 34/85: snapshots/snapshots_s4.h5, index 3, time 0.89
# Frame 35/85: snapshots/snapshots_s4.h5, index 4, time 0.91
# Frame 36/85: snapshots/snapshots_s4.h5, index 5, time 0.92
# Frame 37/85: snapshots/snapshots_s4.h5, index 6, time 0.94
# Frame 38/85: snapshots/snapshots_s4.h5, index 7, time 0.95
# Frame 39/85: snapshots/snapshots_s4.h5, index 8, time 0.96
# Frame 40/85: snapshots/snapshots_s4.h5, index 9, time 0.98
# Frame 41/85: snapshots/snapshots_s5.h5, index 0, time 0.99
# Frame 42/85: snapshots/snapshots_s5.h5, index 1, time 1.00
# Frame 43/85: snapshots/snapshots_s5.h5, index 2, time 1.01
# Frame 44/85: snapshots/snapshots_s5.h5, index 3, time 1.02
# Frame 45/85: snapshots/snapshots_s5.h5, index 4, time 1.04
# Frame 46/85: snapshots/snapshots_s5.h5, index 5, time 1.05
# Frame 47/85: snapshots/snapshots_s5.h5, index 6, time 1.07
# Frame 48/85: snapshots/snapshots_s5.h5, index 7, time 1.08
# Frame 49/85: snapshots/snapshots_s5.h5, index 8, time 1.10
# Frame 50/85: snapshots/snapshots_s5.h5, index 9, time 1.11
# Frame 51/85: snapshots/snapshots_s6.h5, index 0, time 1.12
# Frame 52/85: snapshots/snapshots_s6.h5, index 1, time 1.14
# Frame 53/85: snapshots/snapshots_s6.h5, index 2, time 1.15
# Frame 54/85: snapshots/snapshots_s6.h5, index 3, time 1.17
# Frame 55/85: snapshots/snapshots_s6.h5, index 4, time 1.18
# Frame 56/85: snapshots/snapshots_s6.h5, index 5, time 1.19
# Frame 57/85: snapshots/snapshots_s6.h5, index 6, time 1.20
# Frame 58/85: snapshots/snapshots_s6.h5, index 7, time 1.21
# Frame 59/85: snapshots/snapshots_s6.h5, index 8, time 1.23
# Frame 60/85: snapshots/snapshots_s6.h5, index 9, time 1.24
# Frame 61/85: snapshots/snapshots_s7.h5, index 0, time 1.25
# Frame 62/85: snapshots/snapshots_s7.h5, index 1, time 1.26
# Frame 63/85: snapshots/snapshots_s7.h5, index 2, time 1.27
# Frame 64/85: snapshots/snapshots_s7.h5, index 3, time 1.28
# Frame 65/85: snapshots/snapshots_s7.h5, index 4, time 1.29
# Frame 66/85: snapshots/snapshots_s7.h5, index 5, time 1.30
# Frame 67/85: snapshots/snapshots_s7.h5, index 6, time 1.31
# Frame 68/85: snapshots/snapshots_s7.h5, index 7, time 1.32
# Frame 69/85: snapshots/snapshots_s7.h5, index 8, time 1.34
# Frame 70/85: snapshots/snapshots_s7.h5, index 9, time 1.35
# Frame 71/85: snapshots/snapshots_s8.h5, index 0, time 1.36
# Frame 72/85: snapshots/snapshots_s8.h5, index 1, time 1.37
# Frame 73/85: snapshots/snapshots_s8.h5, index 2, time 1.38
# Frame 74/85: snapshots/snapshots_s8.h5, index 3, time 1.39
# Frame 75/85: snapshots/snapshots_s8.h5, index 4, time 1.41
# Frame 76/85: snapshots/snapshots_s8.h5, index 5, time 1.42
# Frame 77/85: snapshots/snapshots_s8.h5, index 6, time 1.43
# Frame 78/85: snapshots/snapshots_s8.h5, index 7, time 1.44
# Frame 79/85: snapshots/snapshots_s8.h5, index 8, time 1.45
# Frame 80/85: snapshots/snapshots_s8.h5, index 9, time 1.46
# Frame 81/85: snapshots/snapshots_s9.h5, index 0, time 1.48
# Frame 82/85: snapshots/snapshots_s9.h5, index 1, time 1.49
# Frame 83/85: snapshots/snapshots_s9.h5, index 2, time 1.51
# Frame 84/85: snapshots/snapshots_s9.h5, index 3, time 1.53
# Frame 85/85: snapshots/snapshots_s9.h5, index 4, time 1.54
# Saved animation to mantle3D_xyperiodic_z-top_wC.gif
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00

# %%
### MAKE ANIMATION OF VERTICAL X-Z SLICE ###

# ----------------------------
# User settings
# ----------------------------
snapshot_dir = "snapshots"
file_prefix = "snapshots_s"
output_name = "mantle3D_xyperiodic_y-64_wC.gif"

y_index = 64          # fixed y-index for x-z slice
fps = 4
dpi = 150

C_levels = [0.1, 0.3, 0.5, 0.7]  

# Brown -> olive -> green colormap
C_cmap = mcolors.LinearSegmentedColormap.from_list(
    "brown_to_green",
    ["saddlebrown", "olive", "forestgreen"]
)

C_colors = [C_cmap(i) for i in np.linspace(0, 1, len(C_levels))]

# Optional: set color limits manually, or leave as None
w_vmin = None
w_vmax = None

# ----------------------------
# Helper: get coordinate arrays from Dedalus HDF5 output
# ----------------------------
def get_coord(dset, dim_index):
    """
    Get coordinate scale from an HDF5 dataset dimension.
    For data shaped (t, nx, ny, nz):
        dim 0 = time
        dim 1 = x
        dim 2 = y
        dim 3 = z
    """
    keys = list(dset.dims[dim_index].keys())

    if len(keys) == 0:
        raise ValueError(f"No coordinate scale found for dimension {dim_index}")

    return np.asarray(dset.dims[dim_index][keys[0]])

# ----------------------------
# Find files in order
# ----------------------------
files = []
i = 1
while True:
    fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
    if os.path.exists(fname):
        files.append(fname)
        i += 1
    else:
        break

if len(files) == 0:
    raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

print(f"Found {len(files)} snapshot files.")

# ----------------------------
# First pass: collect frame metadata and global w limits
# ----------------------------
frames = []

if w_vmin is None or w_vmax is None:
    global_min = np.inf
    global_max = -np.inf

for fname in files:
    print(f"Scanning {fname}")
    with h5py.File(fname, mode="r") as file:
        w_dset = file["tasks"]["w"]
        T_dset = file["tasks"]["T"]
        t = np.asarray(T_dset.dims[0]["sim_time"])

        nt = w_dset.shape[0]

        for it in range(nt):
            frames.append((fname, it, t[it]))

        if w_vmin is None or w_vmax is None:
            w_slice_all = np.asarray(w_dset[int(nt/2):, :, :, z_index])

            w_rms = np.sqrt(np.nanmean(w_slice_all**2))
            w_lim = 2.0 * w_rms

            global_min = min(global_min, -w_lim)
            global_max = max(global_max,  w_lim)

if w_vmin is None:
    w_vmin = global_min
if w_vmax is None:
    w_vmax = global_max

# Symmetric color scale about zero
w_abs = max(abs(w_vmin), abs(w_vmax))
w_vmin = -w_abs
w_vmax = w_abs

print(f"Total animation frames: {len(frames)}")
print(f"w color limits: {w_vmin:.4e}, {w_vmax:.4e}")

# ----------------------------
# Load first frame and actual coordinate arrays
# ----------------------------
first_fname, first_it, first_time = frames[0]

with h5py.File(first_fname, mode="r") as file:
    w_dset = file["tasks"]["w"]

    w0 = np.asarray(file["tasks"]["w"][first_it, :, y_index, :])
    C0 = np.asarray(file["tasks"]["C"][first_it, :, y_index, :])

    x = get_coord(w_dset, 1)
    y = get_coord(w_dset, 2)
    z = get_coord(w_dset, 3)

print("x shape:", x.shape, "x min/max:", x.min(), x.max())
print("y shape:", y.shape, "y min/max:", y.min(), y.max())
print("z shape:", z.shape, "z min/max:", z.min(), z.max())
print("plotting y =", y[y_index])

nx, nz = w0.shape

if len(x) != nx:
    raise ValueError(f"x coordinate length {len(x)} does not match nx {nx}")
if len(z) != nz:
    raise ValueError(f"z coordinate length {len(z)} does not match nz {nz}")

X, Z = np.meshgrid(x, z, indexing="ij")

# ----------------------------
# Figure setup
# ----------------------------
fig, ax = plt.subplots(figsize=(7, 5))

pcm = ax.pcolormesh(
    X, Z, w0,
    shading="auto",
    vmin=w_vmin,
    vmax=w_vmax,
    cmap="RdBu"
)

cbar = fig.colorbar(pcm, ax=ax)
cbar.set_label("w")

contours = ax.contour(
    X, Z, C0,
    levels=C_levels,
    colors=C_colors,
    linewidths=0.8,
)

ax.clabel(contours, inline=True, fontsize=8)

title = ax.set_title(f"time = {first_time:.2f}, y = {y[y_index]:.3g}")
ax.set_xlabel("x")
ax.set_ylabel("z")

# If z=0 is bottom, leave this commented.
# If your plots look upside down, uncomment it.
# ax.invert_yaxis()

plt.tight_layout()

# ----------------------------
# Animation update function
# ----------------------------
def update(frame_number):
    global contours

    fname, it, sim_time = frames[frame_number]

    with h5py.File(fname, mode="r") as file:
        w_slice = np.asarray(file["tasks"]["w"][it, :, y_index, :])
        C_slice = np.asarray(file["tasks"]["C"][it, :, y_index, :])

    pcm.set_array(w_slice.ravel())

    # Remove old contours
    for coll in contours.collections:
        coll.remove()

    # Draw new contours
    contours = ax.contour(
        X, Z, C_slice,
        levels=C_levels,
        colors=C_colors,
        linewidths=0.8,
    )

    title.set_text(f"time = {sim_time:.2f}, y = {y[y_index]:.3g}")

    print(
        f"Frame {frame_number + 1}/{len(frames)}: "
        f"{fname}, index {it}, time {sim_time:.2f}"
    )

    return [pcm, title] + contours.collections

# ----------------------------
# Save animation
# ----------------------------
ani = animation.FuncAnimation(
    fig,
    update,
    frames=len(frames),
    interval=1000 / fps,
    blit=False,
)

ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)

print(f"Saved animation to {output_name}")
# Out:
# Found 9 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# Total animation frames: 85
# w color limits: -6.5675e+00, 6.5675e+00
# x shape: (128,) x min/max: 0.0 3.96875
# y shape: (128,) y min/max: 0.0 3.96875
# z shape: (64,) z min/max: 0.00015059065189787502 0.9998494093481021
# plotting y = 2.0
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/85: snapshots/snapshots_s1.h5, index 1, time 0.10
# Frame 3/85: snapshots/snapshots_s1.h5, index 2, time 0.10
# Frame 4/85: snapshots/snapshots_s1.h5, index 3, time 0.10
# Frame 5/85: snapshots/snapshots_s1.h5, index 4, time 0.10
# Frame 6/85: snapshots/snapshots_s1.h5, index 5, time 0.10
# Frame 7/85: snapshots/snapshots_s1.h5, index 6, time 0.10
# Frame 8/85: snapshots/snapshots_s1.h5, index 7, time 0.10
# Frame 9/85: snapshots/snapshots_s1.h5, index 8, time 0.11
# Frame 10/85: snapshots/snapshots_s1.h5, index 9, time 0.11
# Frame 11/85: snapshots/snapshots_s2.h5, index 0, time 0.11
# Frame 12/85: snapshots/snapshots_s2.h5, index 1, time 0.11
# Frame 13/85: snapshots/snapshots_s2.h5, index 2, time 0.12
# Frame 14/85: snapshots/snapshots_s2.h5, index 3, time 0.13
# Frame 15/85: snapshots/snapshots_s2.h5, index 4, time 0.14
# Frame 16/85: snapshots/snapshots_s2.h5, index 5, time 0.16
# Frame 17/85: snapshots/snapshots_s2.h5, index 6, time 0.17
# Frame 18/85: snapshots/snapshots_s2.h5, index 7, time 0.19
# Frame 19/85: snapshots/snapshots_s2.h5, index 8, time 0.21
# Frame 20/85: snapshots/snapshots_s2.h5, index 9, time 0.23
# Frame 21/85: snapshots/snapshots_s3.h5, index 0, time 0.27
# Frame 22/85: snapshots/snapshots_s3.h5, index 1, time 0.30
# Frame 23/85: snapshots/snapshots_s3.h5, index 2, time 0.35
# Frame 24/85: snapshots/snapshots_s3.h5, index 3, time 0.41
# Frame 25/85: snapshots/snapshots_s3.h5, index 4, time 0.48
# Frame 26/85: snapshots/snapshots_s3.h5, index 5, time 0.54
# Frame 27/85: snapshots/snapshots_s3.h5, index 6, time 0.61
# Frame 28/85: snapshots/snapshots_s3.h5, index 7, time 0.68
# Frame 29/85: snapshots/snapshots_s3.h5, index 8, time 0.74
# Frame 30/85: snapshots/snapshots_s3.h5, index 9, time 0.79
# Frame 31/85: snapshots/snapshots_s4.h5, index 0, time 0.83
# Frame 32/85: snapshots/snapshots_s4.h5, index 1, time 0.86
# Frame 33/85: snapshots/snapshots_s4.h5, index 2, time 0.88
# Frame 34/85: snapshots/snapshots_s4.h5, index 3, time 0.89
# Frame 35/85: snapshots/snapshots_s4.h5, index 4, time 0.91
# Frame 36/85: snapshots/snapshots_s4.h5, index 5, time 0.92
# Frame 37/85: snapshots/snapshots_s4.h5, index 6, time 0.94
# Frame 38/85: snapshots/snapshots_s4.h5, index 7, time 0.95
# Frame 39/85: snapshots/snapshots_s4.h5, index 8, time 0.96
# Frame 40/85: snapshots/snapshots_s4.h5, index 9, time 0.98
# Frame 41/85: snapshots/snapshots_s5.h5, index 0, time 0.99
# Frame 42/85: snapshots/snapshots_s5.h5, index 1, time 1.00
# Frame 43/85: snapshots/snapshots_s5.h5, index 2, time 1.01
# Frame 44/85: snapshots/snapshots_s5.h5, index 3, time 1.02
# Frame 45/85: snapshots/snapshots_s5.h5, index 4, time 1.04
# Frame 46/85: snapshots/snapshots_s5.h5, index 5, time 1.05
# Frame 47/85: snapshots/snapshots_s5.h5, index 6, time 1.07
# Frame 48/85: snapshots/snapshots_s5.h5, index 7, time 1.08
# Frame 49/85: snapshots/snapshots_s5.h5, index 8, time 1.10
# Frame 50/85: snapshots/snapshots_s5.h5, index 9, time 1.11
# Frame 51/85: snapshots/snapshots_s6.h5, index 0, time 1.12
# Frame 52/85: snapshots/snapshots_s6.h5, index 1, time 1.14
# Frame 53/85: snapshots/snapshots_s6.h5, index 2, time 1.15
# Frame 54/85: snapshots/snapshots_s6.h5, index 3, time 1.17
# Frame 55/85: snapshots/snapshots_s6.h5, index 4, time 1.18
# Frame 56/85: snapshots/snapshots_s6.h5, index 5, time 1.19
# Frame 57/85: snapshots/snapshots_s6.h5, index 6, time 1.20
# Frame 58/85: snapshots/snapshots_s6.h5, index 7, time 1.21
# Frame 59/85: snapshots/snapshots_s6.h5, index 8, time 1.23
# Frame 60/85: snapshots/snapshots_s6.h5, index 9, time 1.24
# Frame 61/85: snapshots/snapshots_s7.h5, index 0, time 1.25
# Frame 62/85: snapshots/snapshots_s7.h5, index 1, time 1.26
# Frame 63/85: snapshots/snapshots_s7.h5, index 2, time 1.27
# Frame 64/85: snapshots/snapshots_s7.h5, index 3, time 1.28
# Frame 65/85: snapshots/snapshots_s7.h5, index 4, time 1.29
# Frame 66/85: snapshots/snapshots_s7.h5, index 5, time 1.30
# Frame 67/85: snapshots/snapshots_s7.h5, index 6, time 1.31
# Frame 68/85: snapshots/snapshots_s7.h5, index 7, time 1.32
# Frame 69/85: snapshots/snapshots_s7.h5, index 8, time 1.34
# Frame 70/85: snapshots/snapshots_s7.h5, index 9, time 1.35
# Frame 71/85: snapshots/snapshots_s8.h5, index 0, time 1.36
# Frame 72/85: snapshots/snapshots_s8.h5, index 1, time 1.37
# Frame 73/85: snapshots/snapshots_s8.h5, index 2, time 1.38
# Frame 74/85: snapshots/snapshots_s8.h5, index 3, time 1.39
# Frame 75/85: snapshots/snapshots_s8.h5, index 4, time 1.41
# Frame 76/85: snapshots/snapshots_s8.h5, index 5, time 1.42
# Frame 77/85: snapshots/snapshots_s8.h5, index 6, time 1.43
# Frame 78/85: snapshots/snapshots_s8.h5, index 7, time 1.44
# Frame 79/85: snapshots/snapshots_s8.h5, index 8, time 1.45
# Frame 80/85: snapshots/snapshots_s8.h5, index 9, time 1.46
# Frame 81/85: snapshots/snapshots_s9.h5, index 0, time 1.48
# Frame 82/85: snapshots/snapshots_s9.h5, index 1, time 1.49
# Frame 83/85: snapshots/snapshots_s9.h5, index 2, time 1.51
# Frame 84/85: snapshots/snapshots_s9.h5, index 3, time 1.53
# Frame 85/85: snapshots/snapshots_s9.h5, index 4, time 1.54
# Saved animation to mantle3D_xyperiodic_y-64_wC.gif
# Frame 1/85: snapshots/snapshots_s1.h5, index 0, time 0.00

# %%
### MAKE ANIMATION OF VERTICAL X-Z SLICE ###

# ----------------------------
# User settings
# ----------------------------
snapshot_dir = "snapshots"
file_prefix = "snapshots_s"
output_name = "mantle3D_xyperiodic_y-64_Cvort.gif"

y_index = 64          # fixed y-index for x-z slice
fps = 4
dpi = 150

V_levels = np.asarray([-0.25,-0.2,-0.15,-0.1,-0.05,0.05,0.1,0.15,0.2,0.25])

C_cmap = mcolors.LinearSegmentedColormap.from_list(
    "brown_to_red",
    ["black", "saddlebrown", "lightcoral"]
)

C_vmin = 0
C_vmax = 1

# ----------------------------
# Helper: get coordinate arrays from Dedalus HDF5 output
# ----------------------------
def get_coord(dset, dim_index):
    """
    Get coordinate scale from an HDF5 dataset dimension.
    For data shaped (t, nx, ny, nz):
        dim 0 = time
        dim 1 = x
        dim 2 = y
        dim 3 = z
    """
    keys = list(dset.dims[dim_index].keys())

    if len(keys) == 0:
        raise ValueError(f"No coordinate scale found for dimension {dim_index}")

    return np.asarray(dset.dims[dim_index][keys[0]])

# ----------------------------
# Find files in order
# ----------------------------
files = []
i = 1
while True:
    fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
    if os.path.exists(fname):
        files.append(fname)
        i += 1
    else:
        break

if len(files) == 0:
    raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

print(f"Found {len(files)} snapshot files.")

# ----------------------------
# First pass: collect frame metadata and global V limits
# ----------------------------
frames = []
Vmax_frames = []

for fname in files:
    print(f"Scanning {fname}")
    with h5py.File(fname, mode="r") as file:
        V_dset = file["tasks"]["vorticity_y"]
        t = np.asarray(V_dset.dims[0]["sim_time"])
        nt = V_dset.shape[0]

        for it in range(nt):
            frames.append((fname, it, t[it]))
            Vmax_frames.append(np.nanmax(np.abs(V_dset[it, ...])))

Vscale = np.nanmax(Vmax_frames[len(Vmax_frames)//2:])
V_levels *= 0.8*Vscale

contour_cmap = cm.get_cmap("RdBu")
contour_norm = mcolors.Normalize(vmin=-Vscale/10, vmax=Vscale/10, clip=True)

V_colors = [contour_cmap(contour_norm(level)) for level in V_levels]

print(f"Total animation frames: {len(frames)}")

# ----------------------------
# Load first frame and actual coordinate arrays
# ----------------------------
first_fname, first_it, first_time = frames[0]

with h5py.File(first_fname, mode="r") as file:
    C_dset = file["tasks"]["C"]

    C0 = np.asarray(file["tasks"]["C"][first_it, :, y_index, :])
    V0 = np.asarray(file["tasks"]["vorticity_y"][first_it, :, y_index, :])

    x = get_coord(C_dset, 1)
    y = get_coord(C_dset, 2)
    z = get_coord(C_dset, 3)

print("x shape:", x.shape, "x min/max:", x.min(), x.max())
print("y shape:", y.shape, "y min/max:", y.min(), y.max())
print("z shape:", z.shape, "z min/max:", z.min(), z.max())
print("plotting y =", y[y_index])

nx, nz = w0.shape

if len(x) != nx:
    raise ValueError(f"x coordinate length {len(x)} does not match nx {nx}")
if len(z) != nz:
    raise ValueError(f"z coordinate length {len(z)} does not match nz {nz}")

X, Z = np.meshgrid(x, z, indexing="ij")

# ----------------------------
# Figure setup
# ----------------------------
fig, ax = plt.subplots(figsize=(7, 5))

pcm = ax.pcolormesh(
    X, Z, C0,
    shading="auto",
    vmin=C_vmin,
    vmax=C_vmax,
    cmap=C_cmap
)

cbar = fig.colorbar(pcm, ax=ax)
cbar.set_label("C")

contours = ax.contour(
    X, Z, V0,
    levels=V_levels,
    colors=V_colors,
    linewidths=0.8,
)

ax.clabel(contours, inline=True, fontsize=8)

title = ax.set_title(f"time = {first_time:.2f}, y = {y[y_index]:.3g}")
ax.set_xlabel("x")
ax.set_ylabel("z")

# If z=0 is bottom, leave this commented.
# If your plots look upside down, uncomment it.
# ax.invert_yaxis()

plt.tight_layout()

# ----------------------------
# Animation update function
# ----------------------------
def update(frame_number):
    global contours

    fname, it, sim_time = frames[frame_number]

    with h5py.File(fname, mode="r") as file:
        C_slice = np.asarray(file["tasks"]["C"][it, :, y_index, :])
        V_slice = np.asarray(file["tasks"]["vorticity_y"][it, :, y_index, :])

    pcm.set_array(C_slice.ravel())

    # Remove old contours
    for coll in contours.collections:
        coll.remove()

    # Draw new contours
    contours = ax.contour(
        X, Z, V_slice,
        levels=V_levels,
        colors=V_colors,
        linewidths=0.8,
    )

    title.set_text(f"time = {sim_time:.2f}, y = {y[y_index]:.3g}")

    print(
        f"Frame {frame_number + 1}/{len(frames)}: "
        f"{fname}, index {it}, time {sim_time:.2f}"
    )

    return [pcm, title] + contours.collections

# ----------------------------
# Save animation
# ----------------------------
ani = animation.FuncAnimation(
    fig,
    update,
    frames=len(frames),
    interval=1000 / fps,
    blit=False,
)

ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)

print(f"Saved animation to {output_name}")
# Out:
# Found 9 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# <ipython-input-32-5bb9101c5baf>:81: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   contour_cmap = cm.get_cmap("RdBu")
# Total animation frames: 89
# x shape: (128,) x min/max: 0.0 3.96875
# y shape: (128,) y min/max: 0.0 3.96875
# z shape: (64,) z min/max: 0.00015059065189787502 0.9998494093481021
# plotting y = 2.0
# Frame 1/89: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/89: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/89: snapshots/snapshots_s1.h5, index 1, time 0.10
# Frame 3/89: snapshots/snapshots_s1.h5, index 2, time 0.10
# Frame 4/89: snapshots/snapshots_s1.h5, index 3, time 0.10
# Frame 5/89: snapshots/snapshots_s1.h5, index 4, time 0.10
# Frame 6/89: snapshots/snapshots_s1.h5, index 5, time 0.10
# Frame 7/89: snapshots/snapshots_s1.h5, index 6, time 0.10
# Frame 8/89: snapshots/snapshots_s1.h5, index 7, time 0.10
# Frame 9/89: snapshots/snapshots_s1.h5, index 8, time 0.11
# Frame 10/89: snapshots/snapshots_s1.h5, index 9, time 0.11
# Frame 11/89: snapshots/snapshots_s2.h5, index 0, time 0.11
# Frame 12/89: snapshots/snapshots_s2.h5, index 1, time 0.11
# Frame 13/89: snapshots/snapshots_s2.h5, index 2, time 0.12
# Frame 14/89: snapshots/snapshots_s2.h5, index 3, time 0.13
# Frame 15/89: snapshots/snapshots_s2.h5, index 4, time 0.14
# Frame 16/89: snapshots/snapshots_s2.h5, index 5, time 0.16
# Frame 17/89: snapshots/snapshots_s2.h5, index 6, time 0.17
# Frame 18/89: snapshots/snapshots_s2.h5, index 7, time 0.19
# Frame 19/89: snapshots/snapshots_s2.h5, index 8, time 0.21
# Frame 20/89: snapshots/snapshots_s2.h5, index 9, time 0.23
# Frame 21/89: snapshots/snapshots_s3.h5, index 0, time 0.27
# Frame 22/89: snapshots/snapshots_s3.h5, index 1, time 0.30
# Frame 23/89: snapshots/snapshots_s3.h5, index 2, time 0.35
# Frame 24/89: snapshots/snapshots_s3.h5, index 3, time 0.41
# Frame 25/89: snapshots/snapshots_s3.h5, index 4, time 0.48
# Frame 26/89: snapshots/snapshots_s3.h5, index 5, time 0.54
# Frame 27/89: snapshots/snapshots_s3.h5, index 6, time 0.61
# Frame 28/89: snapshots/snapshots_s3.h5, index 7, time 0.68
# Frame 29/89: snapshots/snapshots_s3.h5, index 8, time 0.74
# Frame 30/89: snapshots/snapshots_s3.h5, index 9, time 0.79
# Frame 31/89: snapshots/snapshots_s4.h5, index 0, time 0.83
# Frame 32/89: snapshots/snapshots_s4.h5, index 1, time 0.86
# Frame 33/89: snapshots/snapshots_s4.h5, index 2, time 0.88
# Frame 34/89: snapshots/snapshots_s4.h5, index 3, time 0.89
# Frame 35/89: snapshots/snapshots_s4.h5, index 4, time 0.91
# Frame 36/89: snapshots/snapshots_s4.h5, index 5, time 0.92
# Frame 37/89: snapshots/snapshots_s4.h5, index 6, time 0.94
# Frame 38/89: snapshots/snapshots_s4.h5, index 7, time 0.95
# Frame 39/89: snapshots/snapshots_s4.h5, index 8, time 0.96
# Frame 40/89: snapshots/snapshots_s4.h5, index 9, time 0.98
# Frame 41/89: snapshots/snapshots_s5.h5, index 0, time 0.99
# Frame 42/89: snapshots/snapshots_s5.h5, index 1, time 1.00
# Frame 43/89: snapshots/snapshots_s5.h5, index 2, time 1.01
# Frame 44/89: snapshots/snapshots_s5.h5, index 3, time 1.02
# Frame 45/89: snapshots/snapshots_s5.h5, index 4, time 1.04
# Frame 46/89: snapshots/snapshots_s5.h5, index 5, time 1.05
# Frame 47/89: snapshots/snapshots_s5.h5, index 6, time 1.07
# Frame 48/89: snapshots/snapshots_s5.h5, index 7, time 1.08
# Frame 49/89: snapshots/snapshots_s5.h5, index 8, time 1.10
# Frame 50/89: snapshots/snapshots_s5.h5, index 9, time 1.11
# Frame 51/89: snapshots/snapshots_s6.h5, index 0, time 1.12
# Frame 52/89: snapshots/snapshots_s6.h5, index 1, time 1.14
# Frame 53/89: snapshots/snapshots_s6.h5, index 2, time 1.15
# Frame 54/89: snapshots/snapshots_s6.h5, index 3, time 1.17
# Frame 55/89: snapshots/snapshots_s6.h5, index 4, time 1.18
# Frame 56/89: snapshots/snapshots_s6.h5, index 5, time 1.19
# Frame 57/89: snapshots/snapshots_s6.h5, index 6, time 1.20
# Frame 58/89: snapshots/snapshots_s6.h5, index 7, time 1.21
# Frame 59/89: snapshots/snapshots_s6.h5, index 8, time 1.23
# Frame 60/89: snapshots/snapshots_s6.h5, index 9, time 1.24
# Frame 61/89: snapshots/snapshots_s7.h5, index 0, time 1.25
# Frame 62/89: snapshots/snapshots_s7.h5, index 1, time 1.26
# Frame 63/89: snapshots/snapshots_s7.h5, index 2, time 1.27
# Frame 64/89: snapshots/snapshots_s7.h5, index 3, time 1.28
# Frame 65/89: snapshots/snapshots_s7.h5, index 4, time 1.29
# Frame 66/89: snapshots/snapshots_s7.h5, index 5, time 1.30
# Frame 67/89: snapshots/snapshots_s7.h5, index 6, time 1.31
# Frame 68/89: snapshots/snapshots_s7.h5, index 7, time 1.32
# Frame 69/89: snapshots/snapshots_s7.h5, index 8, time 1.34
# Frame 70/89: snapshots/snapshots_s7.h5, index 9, time 1.35
# Frame 71/89: snapshots/snapshots_s8.h5, index 0, time 1.36
# Frame 72/89: snapshots/snapshots_s8.h5, index 1, time 1.37
# Frame 73/89: snapshots/snapshots_s8.h5, index 2, time 1.38
# Frame 74/89: snapshots/snapshots_s8.h5, index 3, time 1.39
# Frame 75/89: snapshots/snapshots_s8.h5, index 4, time 1.41
# Frame 76/89: snapshots/snapshots_s8.h5, index 5, time 1.42
# Frame 77/89: snapshots/snapshots_s8.h5, index 6, time 1.43
# Frame 78/89: snapshots/snapshots_s8.h5, index 7, time 1.44
# Frame 79/89: snapshots/snapshots_s8.h5, index 8, time 1.45
# Frame 80/89: snapshots/snapshots_s8.h5, index 9, time 1.46
# Frame 81/89: snapshots/snapshots_s9.h5, index 0, time 1.48
# Frame 82/89: snapshots/snapshots_s9.h5, index 1, time 1.49
# Frame 83/89: snapshots/snapshots_s9.h5, index 2, time 1.51
# Frame 84/89: snapshots/snapshots_s9.h5, index 3, time 1.53
# Frame 85/89: snapshots/snapshots_s9.h5, index 4, time 1.54
# Frame 86/89: snapshots/snapshots_s9.h5, index 5, time 1.56
# Frame 87/89: snapshots/snapshots_s9.h5, index 6, time 1.57
# Frame 88/89: snapshots/snapshots_s9.h5, index 7, time 1.58
# Frame 89/89: snapshots/snapshots_s9.h5, index 8, time 1.59
# Saved animation to mantle3D_xyperiodic_y-64_Cvort.gif
# Frame 1/89: snapshots/snapshots_s1.h5, index 0, time 0.00

# %%
### Nu and KE ANALYSIS ###

# ============================================================
# User settings
# ============================================================
snap_dir = "snapshots"
nonlinear_dir = "snapshots_nonlinear"

# stdout / log file containing lines with max(KE)=...
stdout_file = "stdout.531863"

output_timeseries = "KE_Nu_base.png"
output_gif = "Nu_zprof_base.gif"

fps = 6
dpi = 150

# ============================================================
# Helpers
# ============================================================
def natural_sort_key(path):
    return [int(s) if s.isdigit() else s for s in re.split(r"(\d+)", path)]

def get_h5_files(folder):
    files = sorted(glob.glob(os.path.join(folder, "*.h5")), key=natural_sort_key)
    if len(files) == 0:
        raise FileNotFoundError(f"No .h5 files found in {folder}")
    return files

def get_time_from_task(dset):
    return np.asarray(dset.dims[0]["sim_time"])

def get_coord(dset, dim_index):
    keys = list(dset.dims[dim_index].keys())
    if len(keys) == 0:
        raise ValueError(f"No coordinate scale found for dimension {dim_index}")
    return np.asarray(dset.dims[dim_index][keys[0]])

def squeeze_task(arr):
    return np.squeeze(np.asarray(arr))

def load_ke_from_stdout(stdout_file):
    """
    Extract Time and max(KE) from lines like:

    Iteration=621, Time=1.035369e-01, dt=9.722929e-06, max(KE)=114422.473896
    """
    times = []
    kes = []

    pattern = re.compile(
        r"Time=([+-]?\d+(?:\.\d*)?(?:[eE][+-]?\d+)?).*?"
        r"max\(KE\)=([+-]?\d+(?:\.\d*)?(?:[eE][+-]?\d+)?)"
    )

    with open(stdout_file, "r") as f:
        for line in f:
            match = pattern.search(line)
            if match is not None:
                times.append(float(match.group(1)))
                kes.append(float(match.group(2)))

    if len(times) == 0:
        raise ValueError(f"No KE lines found in {stdout_file}")

    times = np.asarray(times)
    kes = np.asarray(kes)

    order = np.argsort(times)
    return times[order], kes[order]

def pad_limits(vmin, vmax, frac=0.05):
    pad = frac * (vmax - vmin)
    if pad == 0 or not np.isfinite(pad):
        center = 0.5 * (vmin + vmax)
        pad = frac * abs(center)
        if pad == 0 or not np.isfinite(pad):
            pad = frac
    return vmin - pad, vmax + pad

# ============================================================
# Load KE from stdout
# ============================================================
KE_times_raw, KE_raw = load_ke_from_stdout(stdout_file)

print("Loaded KE from stdout:")
print("KE_times shape:", KE_times_raw.shape)
print("KE shape:", KE_raw.shape)
print("KE time range:", KE_times_raw.min(), KE_times_raw.max())

# ============================================================
# Load T snapshots and compute horizontally averaged T(z,t)
# ============================================================
snap_files = get_h5_files(snap_dir)

T_times = []
Tbar_profiles = []

z_T = None

print("Loading T snapshots...")

for fname in snap_files:
    print(fname)
    with h5py.File(fname, "r") as f:
        T_dset = f["tasks"]["T"]
        t = get_time_from_task(T_dset)
        T = np.asarray(T_dset)  # expected shape: (t, nx, ny, nz)

        if z_T is None:
            z_T = get_coord(T_dset, 3)

        # horizontally averaged T(z)
        Tbar = np.nanmean(T, axis=(1, 2))  # shape: (nt, nz)

        T_times.append(t)
        Tbar_profiles.append(Tbar)

T_times = np.concatenate(T_times)
Tbar_profiles = np.concatenate(Tbar_profiles, axis=0)

order = np.argsort(T_times)
T_times = T_times[order]
Tbar_profiles = Tbar_profiles[order, :]

print("T_times shape:", T_times.shape)
print("Tbar_profiles shape:", Tbar_profiles.shape)
print("z_T shape:", z_T.shape)

# ============================================================
# Load nonlinear diagnostics: convective_heat_flux_z
# ============================================================
nonlinear_files = get_h5_files(nonlinear_dir)

chf_times = []
chf_profiles = []

z_chf = None

print("Loading nonlinear diagnostics...")

for fname in nonlinear_files:
    print(fname)
    with h5py.File(fname, "r") as f:
        chf_dset = f["tasks"]["convective_heat_flux_z"]
        t_chf = get_time_from_task(chf_dset)
        chf = squeeze_task(chf_dset)

        if z_chf is None:
            z_chf = get_coord(chf_dset, 1)

        chf_times.append(t_chf)
        chf_profiles.append(chf)

chf_times = np.concatenate(chf_times)
chf_profiles = np.concatenate(chf_profiles, axis=0)

order = np.argsort(chf_times)
chf_times = chf_times[order]
chf_profiles = chf_profiles[order, :]

print("chf_times shape:", chf_times.shape)
print("chf_profiles shape:", chf_profiles.shape)
print("z_chf shape:", z_chf.shape)

# ============================================================
# Compute Nu at each T snapshot time
# ============================================================
Nu_times = []
Nu_profiles = []
Nu_global = []

for i, t0 in enumerate(T_times):
    # interval around this T sample
    if i == 0:
        t_left = -np.inf
    else:
        t_left = 0.5 * (T_times[i - 1] + T_times[i])

    if i == len(T_times) - 1:
        t_right = np.inf
    else:
        t_right = 0.5 * (T_times[i] + T_times[i + 1])

    mask = (chf_times >= t_left) & (chf_times < t_right)

    if not np.any(mask):
        # fallback: nearest convective heat flux sample
        j = np.argmin(np.abs(chf_times - t0))
        chf_mean_z = chf_profiles[j, :]
    else:
        chf_mean_z = np.nanmean(chf_profiles[mask, :], axis=0)

    Tbar_z = Tbar_profiles[i, :]

    dTdz = np.gradient(Tbar_z, z_T, edge_order=2)

    # Requested definition:
    # Nu(z) = <wT>_xy / (-d<T>_xy/dz)
    Nu_z = chf_mean_z / (-dTdz)

    Nu_times.append(t0)
    Nu_profiles.append(Nu_z)

    Nu_mean = np.trapz(Nu_z, z_T) / (z_T[-1] - z_T[0])
    Nu_global.append(Nu_mean)

Nu_times = np.asarray(Nu_times)
Nu_profiles = np.asarray(Nu_profiles)
Nu_global = np.asarray(Nu_global)

print("Nu_times shape:", Nu_times.shape)
print("Nu_profiles shape:", Nu_profiles.shape)
print("Nu_global shape:", Nu_global.shape)

# ============================================================
# Sample/interpolate KE onto Nu times
# ============================================================
# This gives KE with exactly as many points as Nu.
KE_at_Nu_times = np.interp(Nu_times, KE_times_raw, KE_raw)

if Nu_times.min() < KE_times_raw.min() or Nu_times.max() > KE_times_raw.max():
    print("WARNING: Nu time range extends outside KE stdout time range.")
    print("         np.interp used endpoint KE values outside available KE range.")

# ============================================================
# Last quarter samples for axis limits
# ============================================================
n_samples = len(Nu_times)
iq0 = int(0.5 * n_samples)

Nu_times_lq = Nu_times[iq0:]
Nu_profiles_lq = Nu_profiles[iq0:, :]
Nu_global_lq = Nu_global[iq0:]
KE_lq = KE_at_Nu_times[iq0:]

print(f"Using samples {iq0} through {n_samples - 1} for axis limits.")

# ============================================================
# Plot KE and Nu time series with two y axes
# Axis limits based only on last quarter of samples
# ============================================================
fig, ax1 = plt.subplots(figsize=(8, 5))

line1, = ax1.plot(Nu_times, KE_at_Nu_times, linewidth=2, label="max(KE)")
ax1.set_xlabel("time")
ax1.set_ylabel("max(KE)")

ax2 = ax1.twinx()
line2, = ax2.plot(Nu_times, Nu_global, linewidth=2, color='orange', label="Nu")
ax2.set_ylabel("Nu")

# Show full time range, but scale y-limits from last quarter only.
ax1.set_xlim(Nu_times.min(), Nu_times.max())

KE_ymin, KE_ymax = pad_limits(np.nanmin(KE_lq), np.nanmax(KE_lq))
Nu_ymin, Nu_ymax = pad_limits(np.nanmin(Nu_global_lq), np.nanmax(Nu_global_lq))

ax1.set_ylim(0, 1.2*KE_ymax)
ax2.set_ylim(0, 1.2*Nu_ymax)

ax1.set_title("KE and Nu over time")

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc="best")

fig.tight_layout()
fig.savefig(output_timeseries, dpi=dpi)
print(f"Saved {output_timeseries}")

# ============================================================
# GIF: Nu(z) only
# Axis limits based only on last quarter of profiles
# ============================================================
Nu_vmin = np.nanpercentile(Nu_profiles_lq, 1)
Nu_vmax = np.nanpercentile(Nu_profiles_lq, 99)
Nu_vmin, Nu_vmax = pad_limits(Nu_vmin, Nu_vmax)

fig, ax = plt.subplots(figsize=(6, 5))

line_Nu, = ax.plot(Nu_profiles[0, :], z_T, linewidth=2)

ax.axvline(1,color="gray",zorder=-1)
ax.set_xlabel("Nu")
ax.set_ylabel("z")
ax.set_xlim(Nu_vmin, Nu_vmax)
ax.set_title(f"time = {Nu_times[0]:.2f}")

# For usual Dedalus z=0 bottom, Lz top, leave this commented.
# ax.invert_yaxis()

fig.tight_layout()

def update(frame):
    line_Nu.set_xdata(Nu_profiles[frame, :])
    ax.set_title(f"time = {Nu_times[frame]:.2f}")

    print(f"GIF frame {frame + 1}/{len(Nu_times)}: time = {Nu_times[frame]:.2f}")

    return [line_Nu]

ani = animation.FuncAnimation(
    fig,
    update,
    frames=len(Nu_times),
    interval=1000 / fps,
    blit=False,
)

ani.save(output_gif, writer="pillow", fps=fps, dpi=dpi)
print(f"Saved {output_gif}")
# Out:
# Loaded KE from stdout:
# KE_times shape: (893,)
# KE shape: (893,)
# KE time range: 0.02 1.607524
# Loading T snapshots...
# snapshots/snapshots_s1.h5
# snapshots/snapshots_s2.h5
# snapshots/snapshots_s3.h5
# snapshots/snapshots_s4.h5
# snapshots/snapshots_s5.h5
# snapshots/snapshots_s6.h5
# snapshots/snapshots_s7.h5
# snapshots/snapshots_s8.h5
# snapshots/snapshots_s9.h5
# snapshots/snapshots_s10.h5
# snapshots/snapshots_s11.h5
# snapshots/snapshots_s12.h5
# snapshots/snapshots_s13.h5
# snapshots/snapshots_s14.h5
# snapshots/snapshots_s15.h5
# snapshots/snapshots_s16.h5
# snapshots/snapshots_s17.h5
# T_times shape: (168,)
# Tbar_profiles shape: (168, 64)
# z_T shape: (64,)
# Loading nonlinear diagnostics...
# snapshots_nonlinear/snapshots_nonlinear_s1.h5
# snapshots_nonlinear/snapshots_nonlinear_s2.h5
# snapshots_nonlinear/snapshots_nonlinear_s3.h5
# snapshots_nonlinear/snapshots_nonlinear_s4.h5
# snapshots_nonlinear/snapshots_nonlinear_s5.h5
# snapshots_nonlinear/snapshots_nonlinear_s6.h5
# snapshots_nonlinear/snapshots_nonlinear_s7.h5
# snapshots_nonlinear/snapshots_nonlinear_s8.h5
# snapshots_nonlinear/snapshots_nonlinear_s9.h5
# chf_times shape: (1679,)
# chf_profiles shape: (1679, 64)
# z_chf shape: (1,)
# Nu_times shape: (168,)
# Nu_profiles shape: (168, 64)
# Nu_global shape: (168,)
# WARNING: Nu time range extends outside KE stdout time range.
#          np.interp used endpoint KE values outside available KE range.
# Using samples 84 through 167 for axis limits.
# Saved KE_Nu_base.png
# GIF frame 1/168: time = 0.00
# GIF frame 1/168: time = 0.00
# GIF frame 2/168: time = 0.10
# GIF frame 3/168: time = 0.10
# GIF frame 4/168: time = 0.10
# GIF frame 5/168: time = 0.10
# GIF frame 6/168: time = 0.10
# GIF frame 7/168: time = 0.10
# GIF frame 8/168: time = 0.10
# GIF frame 9/168: time = 0.11
# GIF frame 10/168: time = 0.11
# GIF frame 11/168: time = 0.11
# GIF frame 12/168: time = 0.11
# GIF frame 13/168: time = 0.12
# GIF frame 14/168: time = 0.13
# GIF frame 15/168: time = 0.14
# GIF frame 16/168: time = 0.16
# GIF frame 17/168: time = 0.17
# GIF frame 18/168: time = 0.19
# GIF frame 19/168: time = 0.21
# GIF frame 20/168: time = 0.23
# GIF frame 21/168: time = 0.27
# GIF frame 22/168: time = 0.30
# GIF frame 23/168: time = 0.35
# GIF frame 24/168: time = 0.41
# GIF frame 25/168: time = 0.48
# GIF frame 26/168: time = 0.54
# GIF frame 27/168: time = 0.61
# GIF frame 28/168: time = 0.68
# GIF frame 29/168: time = 0.74
# GIF frame 30/168: time = 0.79
# GIF frame 31/168: time = 0.83
# GIF frame 32/168: time = 0.86
# GIF frame 33/168: time = 0.88
# GIF frame 34/168: time = 0.89
# GIF frame 35/168: time = 0.91
# GIF frame 36/168: time = 0.92
# GIF frame 37/168: time = 0.94
# GIF frame 38/168: time = 0.95
# GIF frame 39/168: time = 0.96
# GIF frame 40/168: time = 0.98
# GIF frame 41/168: time = 0.99
# GIF frame 42/168: time = 1.00
# GIF frame 43/168: time = 1.01
# GIF frame 44/168: time = 1.02
# GIF frame 45/168: time = 1.04
# GIF frame 46/168: time = 1.05
# GIF frame 47/168: time = 1.07
# GIF frame 48/168: time = 1.08
# GIF frame 49/168: time = 1.10
# GIF frame 50/168: time = 1.11
# GIF frame 51/168: time = 1.12
# GIF frame 52/168: time = 1.14
# GIF frame 53/168: time = 1.15
# GIF frame 54/168: time = 1.17
# GIF frame 55/168: time = 1.18
# GIF frame 56/168: time = 1.19
# GIF frame 57/168: time = 1.20
# GIF frame 58/168: time = 1.21
# GIF frame 59/168: time = 1.23
# GIF frame 60/168: time = 1.24
# GIF frame 61/168: time = 1.25
# GIF frame 62/168: time = 1.26
# GIF frame 63/168: time = 1.27
# GIF frame 64/168: time = 1.28
# GIF frame 65/168: time = 1.29
# GIF frame 66/168: time = 1.30
# GIF frame 67/168: time = 1.31
# GIF frame 68/168: time = 1.32
# GIF frame 69/168: time = 1.34
# GIF frame 70/168: time = 1.35
# GIF frame 71/168: time = 1.36
# GIF frame 72/168: time = 1.37
# GIF frame 73/168: time = 1.38
# GIF frame 74/168: time = 1.39
# GIF frame 75/168: time = 1.41
# GIF frame 76/168: time = 1.42
# GIF frame 77/168: time = 1.43
# GIF frame 78/168: time = 1.44
# GIF frame 79/168: time = 1.45
# GIF frame 80/168: time = 1.46
# GIF frame 81/168: time = 1.48
# GIF frame 82/168: time = 1.49
# GIF frame 83/168: time = 1.51
# GIF frame 84/168: time = 1.53
# GIF frame 85/168: time = 1.54
# GIF frame 86/168: time = 1.56
# GIF frame 87/168: time = 1.57
# GIF frame 88/168: time = 1.58
# GIF frame 89/168: time = 1.59
# GIF frame 90/168: time = 1.61
# GIF frame 91/168: time = 1.62
# GIF frame 92/168: time = 1.63
# GIF frame 93/168: time = 1.64
# GIF frame 94/168: time = 1.65
# GIF frame 95/168: time = 1.66
# GIF frame 96/168: time = 1.68
# GIF frame 97/168: time = 1.69
# GIF frame 98/168: time = 1.70
# GIF frame 99/168: time = 1.72
# GIF frame 100/168: time = 1.73
# GIF frame 101/168: time = 1.74
# GIF frame 102/168: time = 1.75
# GIF frame 103/168: time = 1.76
# GIF frame 104/168: time = 1.77
# GIF frame 105/168: time = 1.78
# GIF frame 106/168: time = 1.80
# GIF frame 107/168: time = 1.81
# GIF frame 108/168: time = 1.82
# GIF frame 109/168: time = 1.84
# GIF frame 110/168: time = 1.85
# GIF frame 111/168: time = 1.86
# GIF frame 112/168: time = 1.87
# GIF frame 113/168: time = 1.88
# GIF frame 114/168: time = 1.90
# GIF frame 115/168: time = 1.91
# GIF frame 116/168: time = 1.92
# GIF frame 117/168: time = 1.94
# GIF frame 118/168: time = 1.95
# GIF frame 119/168: time = 1.96
# GIF frame 120/168: time = 1.97
# GIF frame 121/168: time = 1.98
# GIF frame 122/168: time = 1.99
# GIF frame 123/168: time = 2.00
# GIF frame 124/168: time = 2.01
# GIF frame 125/168: time = 2.03
# GIF frame 126/168: time = 2.04
# GIF frame 127/168: time = 2.06
# GIF frame 128/168: time = 2.07
# GIF frame 129/168: time = 2.08
# GIF frame 130/168: time = 2.09
# GIF frame 131/168: time = 2.11
# GIF frame 132/168: time = 2.12
# GIF frame 133/168: time = 2.13
# GIF frame 134/168: time = 2.14
# GIF frame 135/168: time = 2.16
# GIF frame 136/168: time = 2.17
# GIF frame 137/168: time = 2.18
# GIF frame 138/168: time = 2.19
# GIF frame 139/168: time = 2.20
# GIF frame 140/168: time = 2.21
# GIF frame 141/168: time = 2.23
# GIF frame 142/168: time = 2.24
# GIF frame 143/168: time = 2.25
# GIF frame 144/168: time = 2.27
# GIF frame 145/168: time = 2.28
# GIF frame 146/168: time = 2.29
# GIF frame 147/168: time = 2.30
# GIF frame 148/168: time = 2.30
# GIF frame 149/168: time = 2.31
# GIF frame 150/168: time = 2.32
# GIF frame 151/168: time = 2.33
# GIF frame 152/168: time = 2.34
# GIF frame 153/168: time = 2.36
# GIF frame 154/168: time = 2.37
# GIF frame 155/168: time = 2.38
# GIF frame 156/168: time = 2.39
# GIF frame 157/168: time = 2.40
# GIF frame 158/168: time = 2.41
# GIF frame 159/168: time = 2.42
# GIF frame 160/168: time = 2.43
# GIF frame 161/168: time = 2.44
# GIF frame 162/168: time = 2.45
# GIF frame 163/168: time = 2.46
# GIF frame 164/168: time = 2.47
# GIF frame 165/168: time = 2.48
# GIF frame 166/168: time = 2.49
# GIF frame 167/168: time = 2.50
# GIF frame 168/168: time = 2.52
# Saved Nu_zprof_base.gif
# GIF frame 1/168: time = 0.00
