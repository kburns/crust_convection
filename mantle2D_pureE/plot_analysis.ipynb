# %%
import pathlib
import subprocess
import h5py
import numpy as np
import matplotlib.pyplot as plt
import re
import glob
import h5py
import matplotlib.animation as animation

import scipy.special as spl
import scipy.integrate
import mpmath as mpm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.colors as mcolors
import matplotlib.cm as cm

fontsize_title = 22
fontsize_axis = 18
fontsize_tick = 18
fontsize_legend = 16
fontsize_cbar = 18

plt.rcParams.update({
    "font.size": fontsize_tick,
    "axes.titlesize": fontsize_title,
    "axes.labelsize": fontsize_axis,
    "xtick.labelsize": fontsize_tick,
    "ytick.labelsize": fontsize_tick,
    "legend.fontsize": fontsize_legend,
    "figure.titlesize": fontsize_title,
})

# %%
import os

os.getcwd()
# Out:
# '/net/fs06/d0/dabdulah/GFD_PROJECT/crust_convection/mantle2D_surefireWC2'

# %%
def make_2D_three_panel_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="three_panel_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    cmaps=("RdBu_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),
    scale_from_last_half=True,

    nframes=None,        # desired number of frames; None uses all available frames
    frame_cutoff=None,   # old option; kept for compatibility
):
    """
    Makes a 3-panel 2D animation for x-z fields.

    Assumes each task has shape:
        (time, x, z)

    Panels:
        left   = tasks[0]
        middle = tasks[1]
        right  = tasks[2]

    Each panel has x,z axes and its own colorbar.

    nframes:
        If None, use all frames.
        If smaller than available frames, subsample evenly.
        If larger than available frames, use all frames.
    """

    import os
    import h5py
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.animation as animation
    import matplotlib.cm as cm
    import matplotlib.colors as mcolors

    def get_coord(dset, dim_index):
        keys = list(dset.dims[dim_index].keys())
        if len(keys) == 0:
            raise ValueError(f"No coordinate scale found for dimension {dim_index}")
        return np.asarray(dset.dims[dim_index][keys[0]])

    def find_snapshot_files(snapshot_dir="snapshots", file_prefix="snapshots_s"):
        files = []
        i = 1
        while True:
            fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
            if os.path.exists(fname):
                files.append(fname)
                i += 1
            else:
                break

        if len(files) == 0:
            raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

        return files

    # ----------------------------
    # Colormaps
    # ----------------------------
    cmap_list = []

    for task, cmap in zip(tasks, cmaps):
        if cmap is None and task == "C":
            cmap_obj = mcolors.LinearSegmentedColormap.from_list(
                "brown_to_red",
                [
                    (0.00, "black"),
                    (0.25, "saddlebrown"),
                    (1.00, "lightcoral"),
                ]
            )
        elif cmap is None:
            cmap_obj = cm.get_cmap("RdBu_r")
        else:
            cmap_obj = cm.get_cmap(cmap)

        cmap_list.append(cmap_obj)

    # ----------------------------
    # Find files and collect frames
    # ----------------------------
    files = find_snapshot_files(snapshot_dir, file_prefix)
    print(f"Found {len(files)} snapshot files.")

    frames = []

    for fname in files:
        print(f"Scanning {fname}")
        with h5py.File(fname, mode="r") as file:
            dset = file["tasks"][tasks[0]]
            t = np.asarray(dset.dims[0]["sim_time"])
            nt = dset.shape[0]

            for it in range(nt):
                frames.append((fname, it, t[it]))

    frames = sorted(frames, key=lambda item: item[2])

    # ----------------------------
    # Subsample frames if requested
    # ----------------------------
    if nframes is not None:
        nframes = int(nframes)

        if nframes <= 0:
            raise ValueError("nframes must be positive")

        if nframes < len(frames):
            inds = np.linspace(0, len(frames) - 1, nframes).astype(int)
            frames = [frames[i] for i in inds]
            print(f"Using {len(frames)} evenly subsampled frames.")
        else:
            print(f"Requested nframes={nframes}, but only {len(frames)} frames exist. Using all frames.")

    # ----------------------------
    # Coordinates
    # ----------------------------
    first_fname, first_it, first_time = frames[0]

    with h5py.File(first_fname, mode="r") as file:
        dset = file["tasks"][tasks[0]]
        x = get_coord(dset, 1)
        z = get_coord(dset, 2)

    x0, x1 = x.min(), x.max()
    z0, z1 = z.min(), z.max()

    X, Z = np.meshgrid(x, z, indexing="ij")

    print("x min/max:", x0, x1)
    print("z min/max:", z0, z1)

    # ----------------------------
    # Color limits
    # ----------------------------
    def scan_task_limits(task, user_vmin, user_vmax):
        if user_vmin is not None and user_vmax is not None:
            return user_vmin, user_vmax

        vals = []
        scan_frames = frames[len(frames)//2:] if scale_from_last_half else frames

        print(f"Scanning color limits for {task}...")

        for fname, it, sim_time in scan_frames:
            with h5py.File(fname, mode="r") as file:
                A = np.asarray(file["tasks"][task][it, :, :])
                vals.append(np.nanmin(A))
                vals.append(np.nanmax(A))

        data_min = np.nanmin(vals)
        data_max = np.nanmax(vals)

        if user_vmin is None:
            user_vmin = data_min
        if user_vmax is None:
            user_vmax = data_max

        return user_vmin, user_vmax

    norms = []
    for task, vmin, vmax in zip(tasks, vmins, vmaxs):
        vmin, vmax = scan_task_limits(task, vmin, vmax)

        if task == "w":
            vmax_abs = max(abs(vmin), abs(vmax))
            vmin = -vmax_abs
            vmax = vmax_abs

        print(f"{task} vmin/vmax:", vmin, vmax)
        norms.append(mcolors.Normalize(vmin=vmin, vmax=vmax))

    # ----------------------------
    # Figure setup
    # ----------------------------
    fig, axes = plt.subplots(1, 3, figsize=figsize)

    fig.subplots_adjust(
        left=0.06,
        right=0.92,
        bottom=0.12,
        top=0.86,
        wspace=0.35,
    )

    ims = []

    with h5py.File(first_fname, mode="r") as file:
        for ax, task, title, cmap, norm in zip(axes, tasks, titles, cmap_list, norms):
            A = np.asarray(file["tasks"][task][first_it, :, :])

            im = ax.pcolormesh(
                X, Z, A,
                shading="auto",
                cmap=cmap,
                norm=norm,
            )

            ax.set_title(title)
            ax.set_xlabel("x")
            ax.set_ylabel("z")
            ax.set_xlim(x0, x1)
            ax.set_ylim(z0, z1)

            fig.colorbar(im, ax=ax)

            ims.append(im)

    fig.suptitle(f"time = {first_time:.2f}")

    # ----------------------------
    # Animation update
    # ----------------------------
    def update(frame_number):
        fname, it, sim_time = frames[frame_number]

        with h5py.File(fname, mode="r") as file:
            for im, task in zip(ims, tasks):
                A = np.asarray(file["tasks"][task][it, :, :])
                im.set_array(A.ravel())

        fig.suptitle(f"time = {sim_time:.2f}")

        print(
            f"Frame {frame_number + 1}/{frame_cutoff if frame_cutoff is not None else len(frames)}: "
            f"{fname}, index {it}, time {sim_time:.2f}"
        )

        return ims

    if frame_cutoff is None:
        frame_cutoff = len(frames)
    else:
        frame_cutoff = min(frame_cutoff, len(frames))

    ani = animation.FuncAnimation(
        fig,
        update,
        frames=frame_cutoff,
        interval=1000 / fps,
        blit=False,
    )

    ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)
    print(f"Saved animation to {output_name}")

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="WC2_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, 0, None),
    vmaxs=(None, 1, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=150,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 24 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Scanning snapshots/snapshots_s6.h5
# Scanning snapshots/snapshots_s7.h5
# Scanning snapshots/snapshots_s8.h5
# Scanning snapshots/snapshots_s9.h5
# Scanning snapshots/snapshots_s10.h5
# Scanning snapshots/snapshots_s11.h5
# Scanning snapshots/snapshots_s12.h5
# Scanning snapshots/snapshots_s13.h5
# Scanning snapshots/snapshots_s14.h5
# Scanning snapshots/snapshots_s15.h5
# Scanning snapshots/snapshots_s16.h5
# Scanning snapshots/snapshots_s17.h5
# Scanning snapshots/snapshots_s18.h5
# Scanning snapshots/snapshots_s19.h5
# Scanning snapshots/snapshots_s20.h5
# Scanning snapshots/snapshots_s21.h5
# Scanning snapshots/snapshots_s22.h5
# Scanning snapshots/snapshots_s23.h5
# Scanning snapshots/snapshots_s24.h5
# Using 150 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00014921630085501633 1.0788789644168926
# C vmin/vmax: 0 1
# Scanning color limits for w...
# w vmin/vmax: -90.33239137478353 90.33239137478353
# Frame 1/150: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/150: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/150: snapshots/snapshots_s1.h5, index 7, time 0.11
# Frame 3/150: snapshots/snapshots_s1.h5, index 15, time 0.16
# Frame 4/150: snapshots/snapshots_s1.h5, index 23, time 0.22
# Frame 5/150: snapshots/snapshots_s1.h5, index 31, time 0.28
# Frame 6/150: snapshots/snapshots_s1.h5, index 39, time 0.33
# Frame 7/150: snapshots/snapshots_s1.h5, index 46, time 0.38
# Frame 8/150: snapshots/snapshots_s2.h5, index 4, time 0.44
# Frame 9/150: snapshots/snapshots_s2.h5, index 12, time 0.49
# Frame 10/150: snapshots/snapshots_s2.h5, index 20, time 0.53
# Frame 11/150: snapshots/snapshots_s2.h5, index 28, time 0.58
# Frame 12/150: snapshots/snapshots_s2.h5, index 36, time 0.62
# Frame 13/150: snapshots/snapshots_s2.h5, index 43, time 0.66
# Frame 14/150: snapshots/snapshots_s3.h5, index 1, time 0.70
# Frame 15/150: snapshots/snapshots_s3.h5, index 9, time 0.75
# Frame 16/150: snapshots/snapshots_s3.h5, index 17, time 0.79
# Frame 17/150: snapshots/snapshots_s3.h5, index 25, time 0.83
# Frame 18/150: snapshots/snapshots_s3.h5, index 32, time 0.87
# Frame 19/150: snapshots/snapshots_s3.h5, index 40, time 0.91
# Frame 20/150: snapshots/snapshots_s3.h5, index 48, time 0.95
# Frame 21/150: snapshots/snapshots_s4.h5, index 6, time 0.99
# Frame 22/150: snapshots/snapshots_s4.h5, index 14, time 1.03
# Frame 23/150: snapshots/snapshots_s4.h5, index 22, time 1.07
# Frame 24/150: snapshots/snapshots_s4.h5, index 29, time 1.11
# Frame 25/150: snapshots/snapshots_s4.h5, index 37, time 1.15
# Frame 26/150: snapshots/snapshots_s4.h5, index 45, time 1.19
# Frame 27/150: snapshots/snapshots_s5.h5, index 3, time 1.23
# Frame 28/150: snapshots/snapshots_s5.h5, index 11, time 1.27
# Frame 29/150: snapshots/snapshots_s5.h5, index 18, time 1.30
# Frame 30/150: snapshots/snapshots_s5.h5, index 26, time 1.35
# Frame 31/150: snapshots/snapshots_s5.h5, index 34, time 1.39
# Frame 32/150: snapshots/snapshots_s5.h5, index 42, time 1.43
# Frame 33/150: snapshots/snapshots_s6.h5, index 0, time 1.47
# Frame 34/150: snapshots/snapshots_s6.h5, index 8, time 1.51
# Frame 35/150: snapshots/snapshots_s6.h5, index 15, time 1.55
# Frame 36/150: snapshots/snapshots_s6.h5, index 23, time 1.59
# Frame 37/150: snapshots/snapshots_s6.h5, index 31, time 1.63
# Frame 38/150: snapshots/snapshots_s6.h5, index 39, time 1.67
# Frame 39/150: snapshots/snapshots_s6.h5, index 47, time 1.71
# Frame 40/150: snapshots/snapshots_s7.h5, index 4, time 1.75
# Frame 41/150: snapshots/snapshots_s7.h5, index 12, time 1.79
# Frame 42/150: snapshots/snapshots_s7.h5, index 20, time 1.83
# Frame 43/150: snapshots/snapshots_s7.h5, index 28, time 1.87
# Frame 44/150: snapshots/snapshots_s7.h5, index 36, time 1.91
# Frame 45/150: snapshots/snapshots_s7.h5, index 44, time 1.95
# Frame 46/150: snapshots/snapshots_s8.h5, index 1, time 1.99
# Frame 47/150: snapshots/snapshots_s8.h5, index 9, time 2.03
# Frame 48/150: snapshots/snapshots_s8.h5, index 17, time 2.07
# Frame 49/150: snapshots/snapshots_s8.h5, index 25, time 2.11
# Frame 50/150: snapshots/snapshots_s8.h5, index 33, time 2.15
# Frame 51/150: snapshots/snapshots_s8.h5, index 40, time 2.19
# Frame 52/150: snapshots/snapshots_s8.h5, index 48, time 2.23
# Frame 53/150: snapshots/snapshots_s9.h5, index 6, time 2.27
# Frame 54/150: snapshots/snapshots_s9.h5, index 14, time 2.31
# Frame 55/150: snapshots/snapshots_s9.h5, index 22, time 2.35
# Frame 56/150: snapshots/snapshots_s9.h5, index 30, time 2.39
# Frame 57/150: snapshots/snapshots_s9.h5, index 37, time 2.43
# Frame 58/150: snapshots/snapshots_s9.h5, index 45, time 2.47
# Frame 59/150: snapshots/snapshots_s10.h5, index 3, time 2.51
# Frame 60/150: snapshots/snapshots_s10.h5, index 11, time 2.55
# Frame 61/150: snapshots/snapshots_s10.h5, index 19, time 2.59
# Frame 62/150: snapshots/snapshots_s10.h5, index 26, time 2.63
# Frame 63/150: snapshots/snapshots_s10.h5, index 34, time 2.67
# Frame 64/150: snapshots/snapshots_s10.h5, index 42, time 2.71
# Frame 65/150: snapshots/snapshots_s11.h5, index 0, time 2.75
# Frame 66/150: snapshots/snapshots_s11.h5, index 8, time 2.80
# Frame 67/150: snapshots/snapshots_s11.h5, index 16, time 2.83
# Frame 68/150: snapshots/snapshots_s11.h5, index 23, time 2.87
# Frame 69/150: snapshots/snapshots_s11.h5, index 31, time 2.91
# Frame 70/150: snapshots/snapshots_s11.h5, index 39, time 2.95
# Frame 71/150: snapshots/snapshots_s11.h5, index 47, time 2.99
# Frame 72/150: snapshots/snapshots_s12.h5, index 5, time 3.03
# Frame 73/150: snapshots/snapshots_s12.h5, index 12, time 3.07
# Frame 74/150: snapshots/snapshots_s12.h5, index 20, time 3.11
# Frame 75/150: snapshots/snapshots_s12.h5, index 28, time 3.15
# Frame 76/150: snapshots/snapshots_s12.h5, index 36, time 3.19
# Frame 77/150: snapshots/snapshots_s12.h5, index 44, time 3.23
# Frame 78/150: snapshots/snapshots_s13.h5, index 2, time 3.27
# Frame 79/150: snapshots/snapshots_s13.h5, index 9, time 3.31
# Frame 80/150: snapshots/snapshots_s13.h5, index 17, time 3.35
# Frame 81/150: snapshots/snapshots_s13.h5, index 25, time 3.39
# Frame 82/150: snapshots/snapshots_s13.h5, index 33, time 3.44
# Frame 83/150: snapshots/snapshots_s13.h5, index 41, time 3.48
# Frame 84/150: snapshots/snapshots_s13.h5, index 48, time 3.52
# Frame 85/150: snapshots/snapshots_s14.h5, index 6, time 3.56
# Frame 86/150: snapshots/snapshots_s14.h5, index 14, time 3.60
# Frame 87/150: snapshots/snapshots_s14.h5, index 22, time 3.64
# Frame 88/150: snapshots/snapshots_s14.h5, index 30, time 3.68
# Frame 89/150: snapshots/snapshots_s14.h5, index 38, time 3.72
# Frame 90/150: snapshots/snapshots_s14.h5, index 45, time 3.76
# Frame 91/150: snapshots/snapshots_s15.h5, index 3, time 3.80
# Frame 92/150: snapshots/snapshots_s15.h5, index 11, time 3.84
# Frame 93/150: snapshots/snapshots_s15.h5, index 19, time 3.89
# Frame 94/150: snapshots/snapshots_s15.h5, index 27, time 3.93
# Frame 95/150: snapshots/snapshots_s15.h5, index 34, time 3.97
# Frame 96/150: snapshots/snapshots_s15.h5, index 42, time 4.00
# Frame 97/150: snapshots/snapshots_s16.h5, index 0, time 4.05
# Frame 98/150: snapshots/snapshots_s16.h5, index 8, time 4.09
# Frame 99/150: snapshots/snapshots_s16.h5, index 16, time 4.13
# Frame 100/150: snapshots/snapshots_s16.h5, index 24, time 4.17
# Frame 101/150: snapshots/snapshots_s16.h5, index 31, time 4.21
# Frame 102/150: snapshots/snapshots_s16.h5, index 39, time 4.26
# Frame 103/150: snapshots/snapshots_s16.h5, index 47, time 4.29
# Frame 104/150: snapshots/snapshots_s17.h5, index 5, time 4.34
# Frame 105/150: snapshots/snapshots_s17.h5, index 13, time 4.38
# Frame 106/150: snapshots/snapshots_s17.h5, index 20, time 4.42
# Frame 107/150: snapshots/snapshots_s17.h5, index 28, time 4.46
# Frame 108/150: snapshots/snapshots_s17.h5, index 36, time 4.50
# Frame 109/150: snapshots/snapshots_s17.h5, index 44, time 4.54
# Frame 110/150: snapshots/snapshots_s18.h5, index 2, time 4.58
# Frame 111/150: snapshots/snapshots_s18.h5, index 10, time 4.63
# Frame 112/150: snapshots/snapshots_s18.h5, index 17, time 4.67
# Frame 113/150: snapshots/snapshots_s18.h5, index 25, time 4.70
# Frame 114/150: snapshots/snapshots_s18.h5, index 33, time 4.75
# Frame 115/150: snapshots/snapshots_s18.h5, index 41, time 4.79
# Frame 116/150: snapshots/snapshots_s18.h5, index 49, time 4.83
# Frame 117/150: snapshots/snapshots_s19.h5, index 6, time 4.87
# Frame 118/150: snapshots/snapshots_s19.h5, index 14, time 4.91
# Frame 119/150: snapshots/snapshots_s19.h5, index 22, time 4.95
# Frame 120/150: snapshots/snapshots_s19.h5, index 30, time 4.99
# Frame 121/150: snapshots/snapshots_s19.h5, index 38, time 5.03
# Frame 122/150: snapshots/snapshots_s19.h5, index 46, time 5.07
# Frame 123/150: snapshots/snapshots_s20.h5, index 3, time 5.11
# Frame 124/150: snapshots/snapshots_s20.h5, index 11, time 5.15
# Frame 125/150: snapshots/snapshots_s20.h5, index 19, time 5.19
# Frame 126/150: snapshots/snapshots_s20.h5, index 27, time 5.24
# Frame 127/150: snapshots/snapshots_s20.h5, index 35, time 5.28
# Frame 128/150: snapshots/snapshots_s20.h5, index 42, time 5.32
# Frame 129/150: snapshots/snapshots_s21.h5, index 0, time 5.36
# Frame 130/150: snapshots/snapshots_s21.h5, index 8, time 5.40
# Frame 131/150: snapshots/snapshots_s21.h5, index 16, time 5.44
# Frame 132/150: snapshots/snapshots_s21.h5, index 24, time 5.48
# Frame 133/150: snapshots/snapshots_s21.h5, index 32, time 5.52
# Frame 134/150: snapshots/snapshots_s21.h5, index 39, time 5.55
# Frame 135/150: snapshots/snapshots_s21.h5, index 47, time 5.59
# Frame 136/150: snapshots/snapshots_s22.h5, index 5, time 5.63
# Frame 137/150: snapshots/snapshots_s22.h5, index 13, time 5.68
# Frame 138/150: snapshots/snapshots_s22.h5, index 21, time 5.72
# Frame 139/150: snapshots/snapshots_s22.h5, index 28, time 5.75
# Frame 140/150: snapshots/snapshots_s22.h5, index 36, time 5.80
# Frame 141/150: snapshots/snapshots_s22.h5, index 44, time 5.83
# Frame 142/150: snapshots/snapshots_s23.h5, index 2, time 5.87
# Frame 143/150: snapshots/snapshots_s23.h5, index 10, time 5.92
# Frame 144/150: snapshots/snapshots_s23.h5, index 18, time 5.96
# Frame 145/150: snapshots/snapshots_s23.h5, index 25, time 5.99
# Frame 146/150: snapshots/snapshots_s23.h5, index 33, time 6.03
# Frame 147/150: snapshots/snapshots_s23.h5, index 41, time 6.07
# Frame 148/150: snapshots/snapshots_s23.h5, index 49, time 6.12
# Frame 149/150: snapshots/snapshots_s24.h5, index 7, time 6.16
# Frame 150/150: snapshots/snapshots_s24.h5, index 15, time 6.20
# Saved animation to WC2_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_E6",
    file_prefix="snapshots_E6_s",
    output_name="WC2_E6_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, 0, None),
    vmaxs=(None, 1, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 28 snapshot files.
# Scanning snapshots_E6/snapshots_E6_s1.h5
# Scanning snapshots_E6/snapshots_E6_s2.h5
# Scanning snapshots_E6/snapshots_E6_s3.h5
# Scanning snapshots_E6/snapshots_E6_s4.h5
# Scanning snapshots_E6/snapshots_E6_s5.h5
# Scanning snapshots_E6/snapshots_E6_s6.h5
# Scanning snapshots_E6/snapshots_E6_s7.h5
# Scanning snapshots_E6/snapshots_E6_s8.h5
# Scanning snapshots_E6/snapshots_E6_s9.h5
# Scanning snapshots_E6/snapshots_E6_s10.h5
# Scanning snapshots_E6/snapshots_E6_s11.h5
# Scanning snapshots_E6/snapshots_E6_s12.h5
# Scanning snapshots_E6/snapshots_E6_s13.h5
# Scanning snapshots_E6/snapshots_E6_s14.h5
# Scanning snapshots_E6/snapshots_E6_s15.h5
# Scanning snapshots_E6/snapshots_E6_s16.h5
# Scanning snapshots_E6/snapshots_E6_s17.h5
# Scanning snapshots_E6/snapshots_E6_s18.h5
# Scanning snapshots_E6/snapshots_E6_s19.h5
# Scanning snapshots_E6/snapshots_E6_s20.h5
# Scanning snapshots_E6/snapshots_E6_s21.h5
# Scanning snapshots_E6/snapshots_E6_s22.h5
# Scanning snapshots_E6/snapshots_E6_s23.h5
# Scanning snapshots_E6/snapshots_E6_s24.h5
# Scanning snapshots_E6/snapshots_E6_s25.h5
# Scanning snapshots_E6/snapshots_E6_s26.h5
# Scanning snapshots_E6/snapshots_E6_s27.h5
# Scanning snapshots_E6/snapshots_E6_s28.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00018059814866578326 1.2354853851312477
# C vmin/vmax: 0 1
# Scanning color limits for w...
# w vmin/vmax: -91.07441467217205 91.07441467217205
# Frame 1/100: snapshots_E6/snapshots_E6_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_E6/snapshots_E6_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_E6/snapshots_E6_s1.h5, index 13, time 0.15
# Frame 3/100: snapshots_E6/snapshots_E6_s1.h5, index 27, time 0.24
# Frame 4/100: snapshots_E6/snapshots_E6_s1.h5, index 41, time 0.32
# Frame 5/100: snapshots_E6/snapshots_E6_s2.h5, index 5, time 0.39
# Frame 6/100: snapshots_E6/snapshots_E6_s2.h5, index 19, time 0.46
# Frame 7/100: snapshots_E6/snapshots_E6_s2.h5, index 33, time 0.53
# Frame 8/100: snapshots_E6/snapshots_E6_s2.h5, index 47, time 0.60
# Frame 9/100: snapshots_E6/snapshots_E6_s3.h5, index 11, time 0.67
# Frame 10/100: snapshots_E6/snapshots_E6_s3.h5, index 25, time 0.74
# Frame 11/100: snapshots_E6/snapshots_E6_s3.h5, index 39, time 0.81
# Frame 12/100: snapshots_E6/snapshots_E6_s4.h5, index 3, time 0.87
# Frame 13/100: snapshots_E6/snapshots_E6_s4.h5, index 17, time 0.94
# Frame 14/100: snapshots_E6/snapshots_E6_s4.h5, index 31, time 1.01
# Frame 15/100: snapshots_E6/snapshots_E6_s4.h5, index 45, time 1.08
# Frame 16/100: snapshots_E6/snapshots_E6_s5.h5, index 9, time 1.15
# Frame 17/100: snapshots_E6/snapshots_E6_s5.h5, index 23, time 1.22
# Frame 18/100: snapshots_E6/snapshots_E6_s5.h5, index 37, time 1.29
# Frame 19/100: snapshots_E6/snapshots_E6_s6.h5, index 1, time 1.36
# Frame 20/100: snapshots_E6/snapshots_E6_s6.h5, index 15, time 1.43
# Frame 21/100: snapshots_E6/snapshots_E6_s6.h5, index 28, time 1.49
# Frame 22/100: snapshots_E6/snapshots_E6_s6.h5, index 42, time 1.57
# Frame 23/100: snapshots_E6/snapshots_E6_s7.h5, index 6, time 1.64
# Frame 24/100: snapshots_E6/snapshots_E6_s7.h5, index 20, time 1.71
# Frame 25/100: snapshots_E6/snapshots_E6_s7.h5, index 34, time 1.77
# Frame 26/100: snapshots_E6/snapshots_E6_s7.h5, index 48, time 1.84
# Frame 27/100: snapshots_E6/snapshots_E6_s8.h5, index 12, time 1.91
# Frame 28/100: snapshots_E6/snapshots_E6_s8.h5, index 26, time 1.98
# Frame 29/100: snapshots_E6/snapshots_E6_s8.h5, index 40, time 2.05
# Frame 30/100: snapshots_E6/snapshots_E6_s9.h5, index 4, time 2.12
# Frame 31/100: snapshots_E6/snapshots_E6_s9.h5, index 18, time 2.19
# Frame 32/100: snapshots_E6/snapshots_E6_s9.h5, index 32, time 2.26
# Frame 33/100: snapshots_E6/snapshots_E6_s9.h5, index 46, time 2.33
# Frame 34/100: snapshots_E6/snapshots_E6_s10.h5, index 10, time 2.40
# Frame 35/100: snapshots_E6/snapshots_E6_s10.h5, index 24, time 2.47
# Frame 36/100: snapshots_E6/snapshots_E6_s10.h5, index 38, time 2.54
# Frame 37/100: snapshots_E6/snapshots_E6_s11.h5, index 2, time 2.61
# Frame 38/100: snapshots_E6/snapshots_E6_s11.h5, index 16, time 2.68
# Frame 39/100: snapshots_E6/snapshots_E6_s11.h5, index 30, time 2.75
# Frame 40/100: snapshots_E6/snapshots_E6_s11.h5, index 44, time 2.82
# Frame 41/100: snapshots_E6/snapshots_E6_s12.h5, index 7, time 2.88
# Frame 42/100: snapshots_E6/snapshots_E6_s12.h5, index 21, time 2.95
# Frame 43/100: snapshots_E6/snapshots_E6_s12.h5, index 35, time 3.03
# Frame 44/100: snapshots_E6/snapshots_E6_s12.h5, index 49, time 3.09
# Frame 45/100: snapshots_E6/snapshots_E6_s13.h5, index 13, time 3.16
# Frame 46/100: snapshots_E6/snapshots_E6_s13.h5, index 27, time 3.23
# Frame 47/100: snapshots_E6/snapshots_E6_s13.h5, index 41, time 3.30
# Frame 48/100: snapshots_E6/snapshots_E6_s14.h5, index 5, time 3.37
# Frame 49/100: snapshots_E6/snapshots_E6_s14.h5, index 19, time 3.44
# Frame 50/100: snapshots_E6/snapshots_E6_s14.h5, index 33, time 3.51
# Frame 51/100: snapshots_E6/snapshots_E6_s14.h5, index 47, time 3.58
# Frame 52/100: snapshots_E6/snapshots_E6_s15.h5, index 11, time 3.65
# Frame 53/100: snapshots_E6/snapshots_E6_s15.h5, index 25, time 3.72
# Frame 54/100: snapshots_E6/snapshots_E6_s15.h5, index 39, time 3.78
# Frame 55/100: snapshots_E6/snapshots_E6_s16.h5, index 3, time 3.85
# Frame 56/100: snapshots_E6/snapshots_E6_s16.h5, index 17, time 3.92
# Frame 57/100: snapshots_E6/snapshots_E6_s16.h5, index 31, time 3.99
# Frame 58/100: snapshots_E6/snapshots_E6_s16.h5, index 45, time 4.06
# Frame 59/100: snapshots_E6/snapshots_E6_s17.h5, index 9, time 4.13
# Frame 60/100: snapshots_E6/snapshots_E6_s17.h5, index 23, time 4.20
# Frame 61/100: snapshots_E6/snapshots_E6_s17.h5, index 36, time 4.26
# Frame 62/100: snapshots_E6/snapshots_E6_s18.h5, index 0, time 4.33
# Frame 63/100: snapshots_E6/snapshots_E6_s18.h5, index 14, time 4.40
# Frame 64/100: snapshots_E6/snapshots_E6_s18.h5, index 28, time 4.47
# Frame 65/100: snapshots_E6/snapshots_E6_s18.h5, index 42, time 4.54
# Frame 66/100: snapshots_E6/snapshots_E6_s19.h5, index 6, time 4.61
# Frame 67/100: snapshots_E6/snapshots_E6_s19.h5, index 20, time 4.68
# Frame 68/100: snapshots_E6/snapshots_E6_s19.h5, index 34, time 4.75
# Frame 69/100: snapshots_E6/snapshots_E6_s19.h5, index 48, time 4.82
# Frame 70/100: snapshots_E6/snapshots_E6_s20.h5, index 12, time 4.89
# Frame 71/100: snapshots_E6/snapshots_E6_s20.h5, index 26, time 4.96
# Frame 72/100: snapshots_E6/snapshots_E6_s20.h5, index 40, time 5.04
# Frame 73/100: snapshots_E6/snapshots_E6_s21.h5, index 4, time 5.10
# Frame 74/100: snapshots_E6/snapshots_E6_s21.h5, index 18, time 5.17
# Frame 75/100: snapshots_E6/snapshots_E6_s21.h5, index 32, time 5.24
# Frame 76/100: snapshots_E6/snapshots_E6_s21.h5, index 46, time 5.31
# Frame 77/100: snapshots_E6/snapshots_E6_s22.h5, index 10, time 5.38
# Frame 78/100: snapshots_E6/snapshots_E6_s22.h5, index 24, time 5.45
# Frame 79/100: snapshots_E6/snapshots_E6_s22.h5, index 38, time 5.51
# Frame 80/100: snapshots_E6/snapshots_E6_s23.h5, index 2, time 5.58
# Frame 81/100: snapshots_E6/snapshots_E6_s23.h5, index 15, time 5.65
# Frame 82/100: snapshots_E6/snapshots_E6_s23.h5, index 29, time 5.72
# Frame 83/100: snapshots_E6/snapshots_E6_s23.h5, index 43, time 5.79
# Frame 84/100: snapshots_E6/snapshots_E6_s24.h5, index 7, time 5.86
# Frame 85/100: snapshots_E6/snapshots_E6_s24.h5, index 21, time 5.93
# Frame 86/100: snapshots_E6/snapshots_E6_s24.h5, index 35, time 6.00
# Frame 87/100: snapshots_E6/snapshots_E6_s24.h5, index 49, time 6.07
# Frame 88/100: snapshots_E6/snapshots_E6_s25.h5, index 13, time 6.14
# Frame 89/100: snapshots_E6/snapshots_E6_s25.h5, index 27, time 6.21
# Frame 90/100: snapshots_E6/snapshots_E6_s25.h5, index 41, time 6.28
# Frame 91/100: snapshots_E6/snapshots_E6_s26.h5, index 5, time 6.35
# Frame 92/100: snapshots_E6/snapshots_E6_s26.h5, index 19, time 6.42
# Frame 93/100: snapshots_E6/snapshots_E6_s26.h5, index 33, time 6.49
# Frame 94/100: snapshots_E6/snapshots_E6_s26.h5, index 47, time 6.56
# Frame 95/100: snapshots_E6/snapshots_E6_s27.h5, index 11, time 6.63
# Frame 96/100: snapshots_E6/snapshots_E6_s27.h5, index 25, time 6.69
# Frame 97/100: snapshots_E6/snapshots_E6_s27.h5, index 39, time 6.77
# Frame 98/100: snapshots_E6/snapshots_E6_s28.h5, index 3, time 6.83
# Frame 99/100: snapshots_E6/snapshots_E6_s28.h5, index 17, time 6.91
# Frame 100/100: snapshots_E6/snapshots_E6_s28.h5, index 31, time 6.97
# Saved animation to WC2_E6_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_E8",
    file_prefix="snapshots_E8_s",
    output_name="WC2_E8_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 40 snapshot files.
# Scanning snapshots_E8/snapshots_E8_s1.h5
# Scanning snapshots_E8/snapshots_E8_s2.h5
# Scanning snapshots_E8/snapshots_E8_s3.h5
# Scanning snapshots_E8/snapshots_E8_s4.h5
# Scanning snapshots_E8/snapshots_E8_s5.h5
# Scanning snapshots_E8/snapshots_E8_s6.h5
# Scanning snapshots_E8/snapshots_E8_s7.h5
# Scanning snapshots_E8/snapshots_E8_s8.h5
# Scanning snapshots_E8/snapshots_E8_s9.h5
# Scanning snapshots_E8/snapshots_E8_s10.h5
# Scanning snapshots_E8/snapshots_E8_s11.h5
# Scanning snapshots_E8/snapshots_E8_s12.h5
# Scanning snapshots_E8/snapshots_E8_s13.h5
# Scanning snapshots_E8/snapshots_E8_s14.h5
# Scanning snapshots_E8/snapshots_E8_s15.h5
# Scanning snapshots_E8/snapshots_E8_s16.h5
# Scanning snapshots_E8/snapshots_E8_s17.h5
# Scanning snapshots_E8/snapshots_E8_s18.h5
# Scanning snapshots_E8/snapshots_E8_s19.h5
# Scanning snapshots_E8/snapshots_E8_s20.h5
# Scanning snapshots_E8/snapshots_E8_s21.h5
# Scanning snapshots_E8/snapshots_E8_s22.h5
# Scanning snapshots_E8/snapshots_E8_s23.h5
# Scanning snapshots_E8/snapshots_E8_s24.h5
# Scanning snapshots_E8/snapshots_E8_s25.h5
# Scanning snapshots_E8/snapshots_E8_s26.h5
# Scanning snapshots_E8/snapshots_E8_s27.h5
# Scanning snapshots_E8/snapshots_E8_s28.h5
# Scanning snapshots_E8/snapshots_E8_s29.h5
# Scanning snapshots_E8/snapshots_E8_s30.h5
# Scanning snapshots_E8/snapshots_E8_s31.h5
# Scanning snapshots_E8/snapshots_E8_s32.h5
# Scanning snapshots_E8/snapshots_E8_s33.h5
# Scanning snapshots_E8/snapshots_E8_s34.h5
# Scanning snapshots_E8/snapshots_E8_s35.h5
# Scanning snapshots_E8/snapshots_E8_s36.h5
# Scanning snapshots_E8/snapshots_E8_s37.h5
# Scanning snapshots_E8/snapshots_E8_s38.h5
# Scanning snapshots_E8/snapshots_E8_s39.h5
# Scanning snapshots_E8/snapshots_E8_s40.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00019782576681836347 1.3956653344879117
# Scanning color limits for C...
# C vmin/vmax: 0.0004631891971161265 1.0795343218972855
# Scanning color limits for w...
# w vmin/vmax: -104.50449642321776 104.50449642321776
# Frame 1/100: snapshots_E8/snapshots_E8_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_E8/snapshots_E8_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_E8/snapshots_E8_s1.h5, index 20, time 0.19
# Frame 3/100: snapshots_E8/snapshots_E8_s1.h5, index 40, time 0.30
# Frame 4/100: snapshots_E8/snapshots_E8_s2.h5, index 10, time 0.40
# Frame 5/100: snapshots_E8/snapshots_E8_s2.h5, index 30, time 0.52
# Frame 6/100: snapshots_E8/snapshots_E8_s3.h5, index 0, time 0.63
# Frame 7/100: snapshots_E8/snapshots_E8_s3.h5, index 20, time 0.72
# Frame 8/100: snapshots_E8/snapshots_E8_s3.h5, index 40, time 0.82
# Frame 9/100: snapshots_E8/snapshots_E8_s4.h5, index 10, time 0.95
# Frame 10/100: snapshots_E8/snapshots_E8_s4.h5, index 30, time 1.07
# Frame 11/100: snapshots_E8/snapshots_E8_s5.h5, index 0, time 1.17
# Frame 12/100: snapshots_E8/snapshots_E8_s5.h5, index 20, time 1.27
# Frame 13/100: snapshots_E8/snapshots_E8_s5.h5, index 40, time 1.37
# Frame 14/100: snapshots_E8/snapshots_E8_s6.h5, index 10, time 1.46
# Frame 15/100: snapshots_E8/snapshots_E8_s6.h5, index 30, time 1.58
# Frame 16/100: snapshots_E8/snapshots_E8_s7.h5, index 0, time 1.68
# Frame 17/100: snapshots_E8/snapshots_E8_s7.h5, index 20, time 1.78
# Frame 18/100: snapshots_E8/snapshots_E8_s7.h5, index 40, time 1.87
# Frame 19/100: snapshots_E8/snapshots_E8_s8.h5, index 10, time 1.97
# Frame 20/100: snapshots_E8/snapshots_E8_s8.h5, index 30, time 2.07
# Frame 21/100: snapshots_E8/snapshots_E8_s9.h5, index 0, time 2.18
# Frame 22/100: snapshots_E8/snapshots_E8_s9.h5, index 20, time 2.29
# Frame 23/100: snapshots_E8/snapshots_E8_s9.h5, index 40, time 2.39
# Frame 24/100: snapshots_E8/snapshots_E8_s10.h5, index 10, time 2.49
# Frame 25/100: snapshots_E8/snapshots_E8_s10.h5, index 30, time 2.58
# Frame 26/100: snapshots_E8/snapshots_E8_s11.h5, index 1, time 2.70
# Frame 27/100: snapshots_E8/snapshots_E8_s11.h5, index 21, time 2.80
# Frame 28/100: snapshots_E8/snapshots_E8_s11.h5, index 41, time 2.90
# Frame 29/100: snapshots_E8/snapshots_E8_s12.h5, index 11, time 2.99
# Frame 30/100: snapshots_E8/snapshots_E8_s12.h5, index 31, time 3.09
# Frame 31/100: snapshots_E8/snapshots_E8_s13.h5, index 1, time 3.19
# Frame 32/100: snapshots_E8/snapshots_E8_s13.h5, index 21, time 3.29
# Frame 33/100: snapshots_E8/snapshots_E8_s13.h5, index 41, time 3.39
# Frame 34/100: snapshots_E8/snapshots_E8_s14.h5, index 11, time 3.49
# Frame 35/100: snapshots_E8/snapshots_E8_s14.h5, index 31, time 3.58
# Frame 36/100: snapshots_E8/snapshots_E8_s15.h5, index 1, time 3.68
# Frame 37/100: snapshots_E8/snapshots_E8_s15.h5, index 21, time 3.78
# Frame 38/100: snapshots_E8/snapshots_E8_s15.h5, index 41, time 3.88
# Frame 39/100: snapshots_E8/snapshots_E8_s16.h5, index 11, time 3.98
# Frame 40/100: snapshots_E8/snapshots_E8_s16.h5, index 31, time 4.08
# Frame 41/100: snapshots_E8/snapshots_E8_s17.h5, index 1, time 4.17
# Frame 42/100: snapshots_E8/snapshots_E8_s17.h5, index 21, time 4.27
# Frame 43/100: snapshots_E8/snapshots_E8_s17.h5, index 41, time 4.37
# Frame 44/100: snapshots_E8/snapshots_E8_s18.h5, index 11, time 4.47
# Frame 45/100: snapshots_E8/snapshots_E8_s18.h5, index 31, time 4.57
# Frame 46/100: snapshots_E8/snapshots_E8_s19.h5, index 1, time 4.66
# Frame 47/100: snapshots_E8/snapshots_E8_s19.h5, index 21, time 4.78
# Frame 48/100: snapshots_E8/snapshots_E8_s19.h5, index 41, time 4.90
# Frame 49/100: snapshots_E8/snapshots_E8_s20.h5, index 11, time 5.00
# Frame 50/100: snapshots_E8/snapshots_E8_s20.h5, index 31, time 5.10
# Frame 51/100: snapshots_E8/snapshots_E8_s21.h5, index 2, time 5.20
# Frame 52/100: snapshots_E8/snapshots_E8_s21.h5, index 22, time 5.29
# Frame 53/100: snapshots_E8/snapshots_E8_s21.h5, index 42, time 5.39
# Frame 54/100: snapshots_E8/snapshots_E8_s22.h5, index 12, time 5.50
# Frame 55/100: snapshots_E8/snapshots_E8_s22.h5, index 32, time 5.60
# Frame 56/100: snapshots_E8/snapshots_E8_s23.h5, index 2, time 5.69
# Frame 57/100: snapshots_E8/snapshots_E8_s23.h5, index 22, time 5.79
# Frame 58/100: snapshots_E8/snapshots_E8_s23.h5, index 42, time 5.89
# Frame 59/100: snapshots_E8/snapshots_E8_s24.h5, index 12, time 5.99
# Frame 60/100: snapshots_E8/snapshots_E8_s24.h5, index 32, time 6.09
# Frame 61/100: snapshots_E8/snapshots_E8_s25.h5, index 2, time 6.19
# Frame 62/100: snapshots_E8/snapshots_E8_s25.h5, index 22, time 6.29
# Frame 63/100: snapshots_E8/snapshots_E8_s25.h5, index 42, time 6.39
# Frame 64/100: snapshots_E8/snapshots_E8_s26.h5, index 12, time 6.49
# Frame 65/100: snapshots_E8/snapshots_E8_s26.h5, index 32, time 6.59
# Frame 66/100: snapshots_E8/snapshots_E8_s27.h5, index 2, time 6.68
# Frame 67/100: snapshots_E8/snapshots_E8_s27.h5, index 22, time 6.78
# Frame 68/100: snapshots_E8/snapshots_E8_s27.h5, index 42, time 6.87
# Frame 69/100: snapshots_E8/snapshots_E8_s28.h5, index 12, time 6.97
# Frame 70/100: snapshots_E8/snapshots_E8_s28.h5, index 32, time 7.06
# Frame 71/100: snapshots_E8/snapshots_E8_s29.h5, index 2, time 7.15
# Frame 72/100: snapshots_E8/snapshots_E8_s29.h5, index 22, time 7.26
# Frame 73/100: snapshots_E8/snapshots_E8_s29.h5, index 42, time 7.35
# Frame 74/100: snapshots_E8/snapshots_E8_s30.h5, index 12, time 7.45
# Frame 75/100: snapshots_E8/snapshots_E8_s30.h5, index 32, time 7.55
# Frame 76/100: snapshots_E8/snapshots_E8_s31.h5, index 3, time 7.65
# Frame 77/100: snapshots_E8/snapshots_E8_s31.h5, index 23, time 7.75
# Frame 78/100: snapshots_E8/snapshots_E8_s31.h5, index 43, time 7.85
# Frame 79/100: snapshots_E8/snapshots_E8_s32.h5, index 13, time 7.94
# Frame 80/100: snapshots_E8/snapshots_E8_s32.h5, index 33, time 8.05
# Frame 81/100: snapshots_E8/snapshots_E8_s33.h5, index 3, time 8.15
# Frame 82/100: snapshots_E8/snapshots_E8_s33.h5, index 23, time 8.25
# Frame 83/100: snapshots_E8/snapshots_E8_s33.h5, index 43, time 8.35
# Frame 84/100: snapshots_E8/snapshots_E8_s34.h5, index 13, time 8.44
# Frame 85/100: snapshots_E8/snapshots_E8_s34.h5, index 33, time 8.54
# Frame 86/100: snapshots_E8/snapshots_E8_s35.h5, index 3, time 8.64
# Frame 87/100: snapshots_E8/snapshots_E8_s35.h5, index 23, time 8.73
# Frame 88/100: snapshots_E8/snapshots_E8_s35.h5, index 43, time 8.83
# Frame 89/100: snapshots_E8/snapshots_E8_s36.h5, index 13, time 8.93
# Frame 90/100: snapshots_E8/snapshots_E8_s36.h5, index 33, time 9.02
# Frame 91/100: snapshots_E8/snapshots_E8_s37.h5, index 3, time 9.12
# Frame 92/100: snapshots_E8/snapshots_E8_s37.h5, index 23, time 9.21
# Frame 93/100: snapshots_E8/snapshots_E8_s37.h5, index 43, time 9.32
# Frame 94/100: snapshots_E8/snapshots_E8_s38.h5, index 13, time 9.42
# Frame 95/100: snapshots_E8/snapshots_E8_s38.h5, index 33, time 9.51
# Frame 96/100: snapshots_E8/snapshots_E8_s39.h5, index 3, time 9.61
# Frame 97/100: snapshots_E8/snapshots_E8_s39.h5, index 23, time 9.71
# Frame 98/100: snapshots_E8/snapshots_E8_s39.h5, index 43, time 9.80
# Frame 99/100: snapshots_E8/snapshots_E8_s40.h5, index 13, time 9.90
# Frame 100/100: snapshots_E8/snapshots_E8_s40.h5, index 34, time 10.00
# Saved animation to WC2_E8_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_E12",
    file_prefix="snapshots_E12_s",
    output_name="WC2_E12_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 15 snapshot files.
# Scanning snapshots_E12/snapshots_E12_s1.h5
# Scanning snapshots_E12/snapshots_E12_s2.h5
# Scanning snapshots_E12/snapshots_E12_s3.h5
# Scanning snapshots_E12/snapshots_E12_s4.h5
# Scanning snapshots_E12/snapshots_E12_s5.h5
# Scanning snapshots_E12/snapshots_E12_s6.h5
# Scanning snapshots_E12/snapshots_E12_s7.h5
# Scanning snapshots_E12/snapshots_E12_s8.h5
# Scanning snapshots_E12/snapshots_E12_s9.h5
# Scanning snapshots_E12/snapshots_E12_s10.h5
# Scanning snapshots_E12/snapshots_E12_s11.h5
# Scanning snapshots_E12/snapshots_E12_s12.h5
# Scanning snapshots_E12/snapshots_E12_s13.h5
# Scanning snapshots_E12/snapshots_E12_s14.h5
# Scanning snapshots_E12/snapshots_E12_s15.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00028958879713443953 1.6343951156148402
# Scanning color limits for C...
# C vmin/vmax: 0.0004851870620033666 1.0106656464085668
# Scanning color limits for w...
# w vmin/vmax: -101.06572203296298 101.06572203296298
# Frame 1/100: snapshots_E12/snapshots_E12_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_E12/snapshots_E12_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_E12/snapshots_E12_s1.h5, index 7, time 0.10
# Frame 3/100: snapshots_E12/snapshots_E12_s1.h5, index 14, time 0.14
# Frame 4/100: snapshots_E12/snapshots_E12_s1.h5, index 22, time 0.19
# Frame 5/100: snapshots_E12/snapshots_E12_s1.h5, index 29, time 0.23
# Frame 6/100: snapshots_E12/snapshots_E12_s1.h5, index 37, time 0.27
# Frame 7/100: snapshots_E12/snapshots_E12_s1.h5, index 44, time 0.30
# Frame 8/100: snapshots_E12/snapshots_E12_s2.h5, index 2, time 0.34
# Frame 9/100: snapshots_E12/snapshots_E12_s2.h5, index 9, time 0.38
# Frame 10/100: snapshots_E12/snapshots_E12_s2.h5, index 17, time 0.42
# Frame 11/100: snapshots_E12/snapshots_E12_s2.h5, index 24, time 0.45
# Frame 12/100: snapshots_E12/snapshots_E12_s2.h5, index 32, time 0.50
# Frame 13/100: snapshots_E12/snapshots_E12_s2.h5, index 39, time 0.53
# Frame 14/100: snapshots_E12/snapshots_E12_s2.h5, index 46, time 0.57
# Frame 15/100: snapshots_E12/snapshots_E12_s3.h5, index 4, time 0.60
# Frame 16/100: snapshots_E12/snapshots_E12_s3.h5, index 11, time 0.64
# Frame 17/100: snapshots_E12/snapshots_E12_s3.h5, index 19, time 0.68
# Frame 18/100: snapshots_E12/snapshots_E12_s3.h5, index 26, time 0.71
# Frame 19/100: snapshots_E12/snapshots_E12_s3.h5, index 34, time 0.74
# Frame 20/100: snapshots_E12/snapshots_E12_s3.h5, index 41, time 0.78
# Frame 21/100: snapshots_E12/snapshots_E12_s3.h5, index 49, time 0.83
# Frame 22/100: snapshots_E12/snapshots_E12_s4.h5, index 6, time 0.86
# Frame 23/100: snapshots_E12/snapshots_E12_s4.h5, index 14, time 0.90
# Frame 24/100: snapshots_E12/snapshots_E12_s4.h5, index 21, time 0.94
# Frame 25/100: snapshots_E12/snapshots_E12_s4.h5, index 28, time 0.98
# Frame 26/100: snapshots_E12/snapshots_E12_s4.h5, index 36, time 1.02
# Frame 27/100: snapshots_E12/snapshots_E12_s4.h5, index 43, time 1.06
# Frame 28/100: snapshots_E12/snapshots_E12_s5.h5, index 1, time 1.10
# Frame 29/100: snapshots_E12/snapshots_E12_s5.h5, index 8, time 1.14
# Frame 30/100: snapshots_E12/snapshots_E12_s5.h5, index 16, time 1.19
# Frame 31/100: snapshots_E12/snapshots_E12_s5.h5, index 23, time 1.23
# Frame 32/100: snapshots_E12/snapshots_E12_s5.h5, index 31, time 1.27
# Frame 33/100: snapshots_E12/snapshots_E12_s5.h5, index 38, time 1.30
# Frame 34/100: snapshots_E12/snapshots_E12_s5.h5, index 46, time 1.34
# Frame 35/100: snapshots_E12/snapshots_E12_s6.h5, index 3, time 1.38
# Frame 36/100: snapshots_E12/snapshots_E12_s6.h5, index 10, time 1.41
# Frame 37/100: snapshots_E12/snapshots_E12_s6.h5, index 18, time 1.46
# Frame 38/100: snapshots_E12/snapshots_E12_s6.h5, index 25, time 1.49
# Frame 39/100: snapshots_E12/snapshots_E12_s6.h5, index 33, time 1.53
# Frame 40/100: snapshots_E12/snapshots_E12_s6.h5, index 40, time 1.56
# Frame 41/100: snapshots_E12/snapshots_E12_s6.h5, index 48, time 1.60
# Frame 42/100: snapshots_E12/snapshots_E12_s7.h5, index 5, time 1.63
# Frame 43/100: snapshots_E12/snapshots_E12_s7.h5, index 13, time 1.68
# Frame 44/100: snapshots_E12/snapshots_E12_s7.h5, index 20, time 1.71
# Frame 45/100: snapshots_E12/snapshots_E12_s7.h5, index 28, time 1.75
# Frame 46/100: snapshots_E12/snapshots_E12_s7.h5, index 35, time 1.78
# Frame 47/100: snapshots_E12/snapshots_E12_s7.h5, index 42, time 1.82
# Frame 48/100: snapshots_E12/snapshots_E12_s8.h5, index 0, time 1.85
# Frame 49/100: snapshots_E12/snapshots_E12_s8.h5, index 7, time 1.89
# Frame 50/100: snapshots_E12/snapshots_E12_s8.h5, index 15, time 1.93
# Frame 51/100: snapshots_E12/snapshots_E12_s8.h5, index 22, time 1.96
# Frame 52/100: snapshots_E12/snapshots_E12_s8.h5, index 30, time 2.00
# Frame 53/100: snapshots_E12/snapshots_E12_s8.h5, index 37, time 2.04
# Frame 54/100: snapshots_E12/snapshots_E12_s8.h5, index 45, time 2.09
# Frame 55/100: snapshots_E12/snapshots_E12_s9.h5, index 2, time 2.12
# Frame 56/100: snapshots_E12/snapshots_E12_s9.h5, index 10, time 2.16
# Frame 57/100: snapshots_E12/snapshots_E12_s9.h5, index 17, time 2.20
# Frame 58/100: snapshots_E12/snapshots_E12_s9.h5, index 24, time 2.23
# Frame 59/100: snapshots_E12/snapshots_E12_s9.h5, index 32, time 2.28
# Frame 60/100: snapshots_E12/snapshots_E12_s9.h5, index 39, time 2.32
# Frame 61/100: snapshots_E12/snapshots_E12_s9.h5, index 47, time 2.35
# Frame 62/100: snapshots_E12/snapshots_E12_s10.h5, index 4, time 2.39
# Frame 63/100: snapshots_E12/snapshots_E12_s10.h5, index 12, time 2.43
# Frame 64/100: snapshots_E12/snapshots_E12_s10.h5, index 19, time 2.47
# Frame 65/100: snapshots_E12/snapshots_E12_s10.h5, index 27, time 2.51
# Frame 66/100: snapshots_E12/snapshots_E12_s10.h5, index 34, time 2.54
# Frame 67/100: snapshots_E12/snapshots_E12_s10.h5, index 42, time 2.58
# Frame 68/100: snapshots_E12/snapshots_E12_s10.h5, index 49, time 2.62
# Frame 69/100: snapshots_E12/snapshots_E12_s11.h5, index 6, time 2.65
# Frame 70/100: snapshots_E12/snapshots_E12_s11.h5, index 14, time 2.69
# Frame 71/100: snapshots_E12/snapshots_E12_s11.h5, index 21, time 2.73
# Frame 72/100: snapshots_E12/snapshots_E12_s11.h5, index 29, time 2.77
# Frame 73/100: snapshots_E12/snapshots_E12_s11.h5, index 36, time 2.81
# Frame 74/100: snapshots_E12/snapshots_E12_s11.h5, index 44, time 2.86
# Frame 75/100: snapshots_E12/snapshots_E12_s12.h5, index 1, time 2.90
# Frame 76/100: snapshots_E12/snapshots_E12_s12.h5, index 9, time 2.94
# Frame 77/100: snapshots_E12/snapshots_E12_s12.h5, index 16, time 2.97
# Frame 78/100: snapshots_E12/snapshots_E12_s12.h5, index 24, time 3.01
# Frame 79/100: snapshots_E12/snapshots_E12_s12.h5, index 31, time 3.04
# Frame 80/100: snapshots_E12/snapshots_E12_s12.h5, index 38, time 3.08
# Frame 81/100: snapshots_E12/snapshots_E12_s12.h5, index 46, time 3.12
# Frame 82/100: snapshots_E12/snapshots_E12_s13.h5, index 3, time 3.15
# Frame 83/100: snapshots_E12/snapshots_E12_s13.h5, index 11, time 3.19
# Frame 84/100: snapshots_E12/snapshots_E12_s13.h5, index 18, time 3.22
# Frame 85/100: snapshots_E12/snapshots_E12_s13.h5, index 26, time 3.25
# Frame 86/100: snapshots_E12/snapshots_E12_s13.h5, index 33, time 3.29
# Frame 87/100: snapshots_E12/snapshots_E12_s13.h5, index 41, time 3.32
# Frame 88/100: snapshots_E12/snapshots_E12_s13.h5, index 48, time 3.35
# Frame 89/100: snapshots_E12/snapshots_E12_s14.h5, index 6, time 3.39
# Frame 90/100: snapshots_E12/snapshots_E12_s14.h5, index 13, time 3.42
# Frame 91/100: snapshots_E12/snapshots_E12_s14.h5, index 20, time 3.46
# Frame 92/100: snapshots_E12/snapshots_E12_s14.h5, index 28, time 3.49
# Frame 93/100: snapshots_E12/snapshots_E12_s14.h5, index 35, time 3.53
# Frame 94/100: snapshots_E12/snapshots_E12_s14.h5, index 43, time 3.56
# Frame 95/100: snapshots_E12/snapshots_E12_s15.h5, index 0, time 3.60
# Frame 96/100: snapshots_E12/snapshots_E12_s15.h5, index 8, time 3.63
# Frame 97/100: snapshots_E12/snapshots_E12_s15.h5, index 15, time 3.67
# Frame 98/100: snapshots_E12/snapshots_E12_s15.h5, index 23, time 3.71
# Frame 99/100: snapshots_E12/snapshots_E12_s15.h5, index 30, time 3.74
# Frame 100/100: snapshots_E12/snapshots_E12_s15.h5, index 38, time 3.78
# Saved animation to WC2_E12_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_gamma5",
    file_prefix="snapshots_gamma5_s",
    output_name="WC2_gamma5_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=120,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 28 snapshot files.
# Scanning snapshots_gamma5/snapshots_gamma5_s1.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s2.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s3.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s4.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s5.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s6.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s7.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s8.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s9.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s10.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s11.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s12.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s13.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s14.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s15.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s16.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s17.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s18.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s19.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s20.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s21.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s22.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s23.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s24.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s25.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s26.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s27.h5
# Scanning snapshots_gamma5/snapshots_gamma5_s28.h5
# Using 120 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00018888761687499894 1.0952499169532415
# Scanning color limits for C...
# C vmin/vmax: 0.0005598932724241532 1.0009171475848742
# Scanning color limits for w...
# w vmin/vmax: -67.33637143228403 67.33637143228403
# Frame 1/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 0, time 0.00
# Frame 1/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 0, time 0.00
# Frame 2/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 11, time 0.14
# Frame 3/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 23, time 0.23
# Frame 4/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 34, time 0.32
# Frame 5/120: snapshots_gamma5/snapshots_gamma5_s1.h5, index 46, time 0.44
# Frame 6/120: snapshots_gamma5/snapshots_gamma5_s2.h5, index 7, time 0.52
# Frame 7/120: snapshots_gamma5/snapshots_gamma5_s2.h5, index 19, time 0.60
# Frame 8/120: snapshots_gamma5/snapshots_gamma5_s2.h5, index 30, time 0.68
# Frame 9/120: snapshots_gamma5/snapshots_gamma5_s2.h5, index 42, time 0.75
# Frame 10/120: snapshots_gamma5/snapshots_gamma5_s3.h5, index 4, time 0.84
# Frame 11/120: snapshots_gamma5/snapshots_gamma5_s3.h5, index 15, time 0.92
# Frame 12/120: snapshots_gamma5/snapshots_gamma5_s3.h5, index 27, time 1.00
# Frame 13/120: snapshots_gamma5/snapshots_gamma5_s3.h5, index 38, time 1.08
# Frame 14/120: snapshots_gamma5/snapshots_gamma5_s4.h5, index 0, time 1.16
# Frame 15/120: snapshots_gamma5/snapshots_gamma5_s4.h5, index 11, time 1.22
# Frame 16/120: snapshots_gamma5/snapshots_gamma5_s4.h5, index 23, time 1.30
# Frame 17/120: snapshots_gamma5/snapshots_gamma5_s4.h5, index 35, time 1.38
# Frame 18/120: snapshots_gamma5/snapshots_gamma5_s4.h5, index 46, time 1.46
# Frame 19/120: snapshots_gamma5/snapshots_gamma5_s5.h5, index 8, time 1.54
# Frame 20/120: snapshots_gamma5/snapshots_gamma5_s5.h5, index 19, time 1.61
# Frame 21/120: snapshots_gamma5/snapshots_gamma5_s5.h5, index 31, time 1.69
# Frame 22/120: snapshots_gamma5/snapshots_gamma5_s5.h5, index 42, time 1.76
# Frame 23/120: snapshots_gamma5/snapshots_gamma5_s6.h5, index 4, time 1.84
# Frame 24/120: snapshots_gamma5/snapshots_gamma5_s6.h5, index 15, time 1.90
# Frame 25/120: snapshots_gamma5/snapshots_gamma5_s6.h5, index 27, time 1.99
# Frame 26/120: snapshots_gamma5/snapshots_gamma5_s6.h5, index 39, time 2.09
# Frame 27/120: snapshots_gamma5/snapshots_gamma5_s7.h5, index 0, time 2.15
# Frame 28/120: snapshots_gamma5/snapshots_gamma5_s7.h5, index 12, time 2.23
# Frame 29/120: snapshots_gamma5/snapshots_gamma5_s7.h5, index 23, time 2.30
# Frame 30/120: snapshots_gamma5/snapshots_gamma5_s7.h5, index 35, time 2.38
# Frame 31/120: snapshots_gamma5/snapshots_gamma5_s7.h5, index 46, time 2.46
# Frame 32/120: snapshots_gamma5/snapshots_gamma5_s8.h5, index 8, time 2.54
# Frame 33/120: snapshots_gamma5/snapshots_gamma5_s8.h5, index 20, time 2.62
# Frame 34/120: snapshots_gamma5/snapshots_gamma5_s8.h5, index 31, time 2.70
# Frame 35/120: snapshots_gamma5/snapshots_gamma5_s8.h5, index 43, time 2.78
# Frame 36/120: snapshots_gamma5/snapshots_gamma5_s9.h5, index 4, time 2.85
# Frame 37/120: snapshots_gamma5/snapshots_gamma5_s9.h5, index 16, time 2.91
# Frame 38/120: snapshots_gamma5/snapshots_gamma5_s9.h5, index 27, time 2.98
# Frame 39/120: snapshots_gamma5/snapshots_gamma5_s9.h5, index 39, time 3.06
# Frame 40/120: snapshots_gamma5/snapshots_gamma5_s10.h5, index 0, time 3.13
# Frame 41/120: snapshots_gamma5/snapshots_gamma5_s10.h5, index 12, time 3.20
# Frame 42/120: snapshots_gamma5/snapshots_gamma5_s10.h5, index 24, time 3.28
# Frame 43/120: snapshots_gamma5/snapshots_gamma5_s10.h5, index 35, time 3.36
# Frame 44/120: snapshots_gamma5/snapshots_gamma5_s10.h5, index 47, time 3.44
# Frame 45/120: snapshots_gamma5/snapshots_gamma5_s11.h5, index 8, time 3.51
# Frame 46/120: snapshots_gamma5/snapshots_gamma5_s11.h5, index 20, time 3.59
# Frame 47/120: snapshots_gamma5/snapshots_gamma5_s11.h5, index 31, time 3.68
# Frame 48/120: snapshots_gamma5/snapshots_gamma5_s11.h5, index 43, time 3.76
# Frame 49/120: snapshots_gamma5/snapshots_gamma5_s12.h5, index 5, time 3.84
# Frame 50/120: snapshots_gamma5/snapshots_gamma5_s12.h5, index 16, time 3.92
# Frame 51/120: snapshots_gamma5/snapshots_gamma5_s12.h5, index 28, time 4.00
# Frame 52/120: snapshots_gamma5/snapshots_gamma5_s12.h5, index 39, time 4.08
# Frame 53/120: snapshots_gamma5/snapshots_gamma5_s13.h5, index 1, time 4.17
# Frame 54/120: snapshots_gamma5/snapshots_gamma5_s13.h5, index 12, time 4.25
# Frame 55/120: snapshots_gamma5/snapshots_gamma5_s13.h5, index 24, time 4.33
# Frame 56/120: snapshots_gamma5/snapshots_gamma5_s13.h5, index 35, time 4.41
# Frame 57/120: snapshots_gamma5/snapshots_gamma5_s13.h5, index 47, time 4.49
# Frame 58/120: snapshots_gamma5/snapshots_gamma5_s14.h5, index 9, time 4.57
# Frame 59/120: snapshots_gamma5/snapshots_gamma5_s14.h5, index 20, time 4.64
# Frame 60/120: snapshots_gamma5/snapshots_gamma5_s14.h5, index 32, time 4.72
# Frame 61/120: snapshots_gamma5/snapshots_gamma5_s14.h5, index 43, time 4.80
# Frame 62/120: snapshots_gamma5/snapshots_gamma5_s15.h5, index 5, time 4.88
# Frame 63/120: snapshots_gamma5/snapshots_gamma5_s15.h5, index 16, time 4.96
# Frame 64/120: snapshots_gamma5/snapshots_gamma5_s15.h5, index 28, time 5.04
# Frame 65/120: snapshots_gamma5/snapshots_gamma5_s15.h5, index 40, time 5.13
# Frame 66/120: snapshots_gamma5/snapshots_gamma5_s16.h5, index 1, time 5.21
# Frame 67/120: snapshots_gamma5/snapshots_gamma5_s16.h5, index 13, time 5.30
# Frame 68/120: snapshots_gamma5/snapshots_gamma5_s16.h5, index 24, time 5.39
# Frame 69/120: snapshots_gamma5/snapshots_gamma5_s16.h5, index 36, time 5.48
# Frame 70/120: snapshots_gamma5/snapshots_gamma5_s16.h5, index 47, time 5.55
# Frame 71/120: snapshots_gamma5/snapshots_gamma5_s17.h5, index 9, time 5.63
# Frame 72/120: snapshots_gamma5/snapshots_gamma5_s17.h5, index 20, time 5.70
# Frame 73/120: snapshots_gamma5/snapshots_gamma5_s17.h5, index 32, time 5.79
# Frame 74/120: snapshots_gamma5/snapshots_gamma5_s17.h5, index 44, time 5.86
# Frame 75/120: snapshots_gamma5/snapshots_gamma5_s18.h5, index 5, time 5.92
# Frame 76/120: snapshots_gamma5/snapshots_gamma5_s18.h5, index 17, time 5.99
# Frame 77/120: snapshots_gamma5/snapshots_gamma5_s18.h5, index 28, time 6.05
# Frame 78/120: snapshots_gamma5/snapshots_gamma5_s18.h5, index 40, time 6.12
# Frame 79/120: snapshots_gamma5/snapshots_gamma5_s19.h5, index 1, time 6.20
# Frame 80/120: snapshots_gamma5/snapshots_gamma5_s19.h5, index 13, time 6.29
# Frame 81/120: snapshots_gamma5/snapshots_gamma5_s19.h5, index 25, time 6.38
# Frame 82/120: snapshots_gamma5/snapshots_gamma5_s19.h5, index 36, time 6.45
# Frame 83/120: snapshots_gamma5/snapshots_gamma5_s19.h5, index 48, time 6.52
# Frame 84/120: snapshots_gamma5/snapshots_gamma5_s20.h5, index 9, time 6.58
# Frame 85/120: snapshots_gamma5/snapshots_gamma5_s20.h5, index 21, time 6.65
# Frame 86/120: snapshots_gamma5/snapshots_gamma5_s20.h5, index 32, time 6.72
# Frame 87/120: snapshots_gamma5/snapshots_gamma5_s20.h5, index 44, time 6.80
# Frame 88/120: snapshots_gamma5/snapshots_gamma5_s21.h5, index 5, time 6.86
# Frame 89/120: snapshots_gamma5/snapshots_gamma5_s21.h5, index 17, time 6.92
# Frame 90/120: snapshots_gamma5/snapshots_gamma5_s21.h5, index 29, time 6.99
# Frame 91/120: snapshots_gamma5/snapshots_gamma5_s21.h5, index 40, time 7.05
# Frame 92/120: snapshots_gamma5/snapshots_gamma5_s22.h5, index 2, time 7.13
# Frame 93/120: snapshots_gamma5/snapshots_gamma5_s22.h5, index 13, time 7.20
# Frame 94/120: snapshots_gamma5/snapshots_gamma5_s22.h5, index 25, time 7.27
# Frame 95/120: snapshots_gamma5/snapshots_gamma5_s22.h5, index 36, time 7.34
# Frame 96/120: snapshots_gamma5/snapshots_gamma5_s22.h5, index 48, time 7.42
# Frame 97/120: snapshots_gamma5/snapshots_gamma5_s23.h5, index 10, time 7.51
# Frame 98/120: snapshots_gamma5/snapshots_gamma5_s23.h5, index 21, time 7.59
# Frame 99/120: snapshots_gamma5/snapshots_gamma5_s23.h5, index 33, time 7.67
# Frame 100/120: snapshots_gamma5/snapshots_gamma5_s23.h5, index 44, time 7.74
# Frame 101/120: snapshots_gamma5/snapshots_gamma5_s24.h5, index 6, time 7.82
# Frame 102/120: snapshots_gamma5/snapshots_gamma5_s24.h5, index 17, time 7.90
# Frame 103/120: snapshots_gamma5/snapshots_gamma5_s24.h5, index 29, time 7.98
# Frame 104/120: snapshots_gamma5/snapshots_gamma5_s24.h5, index 40, time 8.06
# Frame 105/120: snapshots_gamma5/snapshots_gamma5_s25.h5, index 2, time 8.14
# Frame 106/120: snapshots_gamma5/snapshots_gamma5_s25.h5, index 14, time 8.23
# Frame 107/120: snapshots_gamma5/snapshots_gamma5_s25.h5, index 25, time 8.30
# Frame 108/120: snapshots_gamma5/snapshots_gamma5_s25.h5, index 37, time 8.39
# Frame 109/120: snapshots_gamma5/snapshots_gamma5_s25.h5, index 48, time 8.46
# Frame 110/120: snapshots_gamma5/snapshots_gamma5_s26.h5, index 10, time 8.52
# Frame 111/120: snapshots_gamma5/snapshots_gamma5_s26.h5, index 21, time 8.59
# Frame 112/120: snapshots_gamma5/snapshots_gamma5_s26.h5, index 33, time 8.66
# Frame 113/120: snapshots_gamma5/snapshots_gamma5_s26.h5, index 45, time 8.74
# Frame 114/120: snapshots_gamma5/snapshots_gamma5_s27.h5, index 6, time 8.81
# Frame 115/120: snapshots_gamma5/snapshots_gamma5_s27.h5, index 18, time 8.87
# Frame 116/120: snapshots_gamma5/snapshots_gamma5_s27.h5, index 29, time 8.93
# Frame 117/120: snapshots_gamma5/snapshots_gamma5_s27.h5, index 41, time 8.99
# Frame 118/120: snapshots_gamma5/snapshots_gamma5_s28.h5, index 2, time 9.06
# Frame 119/120: snapshots_gamma5/snapshots_gamma5_s28.h5, index 14, time 9.14
# Frame 120/120: snapshots_gamma5/snapshots_gamma5_s28.h5, index 26, time 9.21
# Saved animation to WC2_gamma5_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_CRa10k",
    file_prefix="snapshots_CRa10k_s",
    output_name="WC2_CRa10k_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, 0, None),
    vmaxs=(None, 1, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 16 snapshot files.
# Scanning snapshots_CRa10k/snapshots_CRa10k_s1.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s2.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s3.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s4.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s5.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s6.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s7.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s8.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s9.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s10.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s11.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s12.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s13.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s14.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s15.h5
# Scanning snapshots_CRa10k/snapshots_CRa10k_s16.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.0001325313729703075 1.0981787607084996
# C vmin/vmax: 0 1
# Scanning color limits for w...
# w vmin/vmax: -130.50033476229726 130.50033476229726
# Frame 1/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 8, time 0.11
# Frame 3/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 16, time 0.16
# Frame 4/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 24, time 0.21
# Frame 5/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 32, time 0.26
# Frame 6/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 40, time 0.31
# Frame 7/100: snapshots_CRa10k/snapshots_CRa10k_s1.h5, index 48, time 0.36
# Frame 8/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 6, time 0.41
# Frame 9/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 14, time 0.46
# Frame 10/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 22, time 0.51
# Frame 11/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 30, time 0.55
# Frame 12/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 38, time 0.59
# Frame 13/100: snapshots_CRa10k/snapshots_CRa10k_s2.h5, index 46, time 0.63
# Frame 14/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 4, time 0.66
# Frame 15/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 12, time 0.70
# Frame 16/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 20, time 0.74
# Frame 17/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 28, time 0.77
# Frame 18/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 37, time 0.82
# Frame 19/100: snapshots_CRa10k/snapshots_CRa10k_s3.h5, index 45, time 0.85
# Frame 20/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 3, time 0.89
# Frame 21/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 11, time 0.93
# Frame 22/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 19, time 0.97
# Frame 23/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 27, time 1.00
# Frame 24/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 35, time 1.04
# Frame 25/100: snapshots_CRa10k/snapshots_CRa10k_s4.h5, index 43, time 1.08
# Frame 26/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 1, time 1.11
# Frame 27/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 9, time 1.15
# Frame 28/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 17, time 1.19
# Frame 29/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 25, time 1.23
# Frame 30/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 33, time 1.26
# Frame 31/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 41, time 1.30
# Frame 32/100: snapshots_CRa10k/snapshots_CRa10k_s5.h5, index 49, time 1.34
# Frame 33/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 7, time 1.37
# Frame 34/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 16, time 1.42
# Frame 35/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 24, time 1.45
# Frame 36/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 32, time 1.49
# Frame 37/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 40, time 1.53
# Frame 38/100: snapshots_CRa10k/snapshots_CRa10k_s6.h5, index 48, time 1.56
# Frame 39/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 6, time 1.60
# Frame 40/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 14, time 1.64
# Frame 41/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 22, time 1.67
# Frame 42/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 30, time 1.71
# Frame 43/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 38, time 1.74
# Frame 44/100: snapshots_CRa10k/snapshots_CRa10k_s7.h5, index 46, time 1.78
# Frame 45/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 4, time 1.81
# Frame 46/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 12, time 1.85
# Frame 47/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 20, time 1.89
# Frame 48/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 28, time 1.93
# Frame 49/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 36, time 1.96
# Frame 50/100: snapshots_CRa10k/snapshots_CRa10k_s8.h5, index 44, time 2.00
# Frame 51/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 3, time 2.04
# Frame 52/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 11, time 2.07
# Frame 53/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 19, time 2.11
# Frame 54/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 27, time 2.15
# Frame 55/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 35, time 2.18
# Frame 56/100: snapshots_CRa10k/snapshots_CRa10k_s9.h5, index 43, time 2.22
# Frame 57/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 1, time 2.25
# Frame 58/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 9, time 2.29
# Frame 59/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 17, time 2.33
# Frame 60/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 25, time 2.36
# Frame 61/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 33, time 2.40
# Frame 62/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 41, time 2.43
# Frame 63/100: snapshots_CRa10k/snapshots_CRa10k_s10.h5, index 49, time 2.47
# Frame 64/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 7, time 2.51
# Frame 65/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 15, time 2.55
# Frame 66/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 23, time 2.59
# Frame 67/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 32, time 2.63
# Frame 68/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 40, time 2.66
# Frame 69/100: snapshots_CRa10k/snapshots_CRa10k_s11.h5, index 48, time 2.70
# Frame 70/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 6, time 2.74
# Frame 71/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 14, time 2.78
# Frame 72/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 22, time 2.81
# Frame 73/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 30, time 2.84
# Frame 74/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 38, time 2.88
# Frame 75/100: snapshots_CRa10k/snapshots_CRa10k_s12.h5, index 46, time 2.92
# Frame 76/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 4, time 2.95
# Frame 77/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 12, time 2.99
# Frame 78/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 20, time 3.03
# Frame 79/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 28, time 3.06
# Frame 80/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 36, time 3.10
# Frame 81/100: snapshots_CRa10k/snapshots_CRa10k_s13.h5, index 44, time 3.14
# Frame 82/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 2, time 3.18
# Frame 83/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 10, time 3.22
# Frame 84/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 19, time 3.26
# Frame 85/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 27, time 3.29
# Frame 86/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 35, time 3.33
# Frame 87/100: snapshots_CRa10k/snapshots_CRa10k_s14.h5, index 43, time 3.37
# Frame 88/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 1, time 3.40
# Frame 89/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 9, time 3.44
# Frame 90/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 17, time 3.48
# Frame 91/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 25, time 3.52
# Frame 92/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 33, time 3.55
# Frame 93/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 41, time 3.59
# Frame 94/100: snapshots_CRa10k/snapshots_CRa10k_s15.h5, index 49, time 3.62
# Frame 95/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 7, time 3.66
# Frame 96/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 15, time 3.70
# Frame 97/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 23, time 3.74
# Frame 98/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 31, time 3.77
# Frame 99/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 39, time 3.81
# Frame 100/100: snapshots_CRa10k/snapshots_CRa10k_s16.h5, index 48, time 3.85
# Saved animation to WC2_CRa10k_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_CRa25k",
    file_prefix="snapshots_CRa25k_s",
    output_name="WC2_CRa25k_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    #frame_cutoff=49,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 6 snapshot files.
# Scanning snapshots_CRa25k/snapshots_CRa25k_s1.h5
# Scanning snapshots_CRa25k/snapshots_CRa25k_s2.h5
# Scanning snapshots_CRa25k/snapshots_CRa25k_s3.h5
# Scanning snapshots_CRa25k/snapshots_CRa25k_s4.h5
# Scanning snapshots_CRa25k/snapshots_CRa25k_s5.h5
# Scanning snapshots_CRa25k/snapshots_CRa25k_s6.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.000204132777515289 1.0574122193814468
# Scanning color limits for C...
# C vmin/vmax: 0.0017254387399577545 1.0007681538817097
# Scanning color limits for w...
# w vmin/vmax: -55.04063185564283 55.04063185564283
# Frame 1/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 2, time 0.07
# Frame 3/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 5, time 0.09
# Frame 4/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 8, time 0.11
# Frame 5/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 11, time 0.14
# Frame 6/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 14, time 0.16
# Frame 7/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 17, time 0.18
# Frame 8/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 20, time 0.20
# Frame 9/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 23, time 0.23
# Frame 10/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 26, time 0.25
# Frame 11/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 29, time 0.27
# Frame 12/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 32, time 0.30
# Frame 13/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 35, time 0.32
# Frame 14/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 38, time 0.34
# Frame 15/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 41, time 0.37
# Frame 16/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 44, time 0.39
# Frame 17/100: snapshots_CRa25k/snapshots_CRa25k_s1.h5, index 47, time 0.41
# Frame 18/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 0, time 0.44
# Frame 19/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 3, time 0.46
# Frame 20/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 6, time 0.49
# Frame 21/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 9, time 0.51
# Frame 22/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 12, time 0.53
# Frame 23/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 15, time 0.56
# Frame 24/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 18, time 0.58
# Frame 25/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 21, time 0.60
# Frame 26/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 24, time 0.63
# Frame 27/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 27, time 0.65
# Frame 28/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 30, time 0.67
# Frame 29/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 33, time 0.70
# Frame 30/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 36, time 0.72
# Frame 31/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 39, time 0.74
# Frame 32/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 42, time 0.77
# Frame 33/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 45, time 0.79
# Frame 34/100: snapshots_CRa25k/snapshots_CRa25k_s2.h5, index 48, time 0.81
# Frame 35/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 1, time 0.84
# Frame 36/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 4, time 0.86
# Frame 37/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 7, time 0.88
# Frame 38/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 10, time 0.91
# Frame 39/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 13, time 0.93
# Frame 40/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 16, time 0.96
# Frame 41/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 19, time 0.98
# Frame 42/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 22, time 1.00
# Frame 43/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 25, time 1.02
# Frame 44/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 28, time 1.05
# Frame 45/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 31, time 1.07
# Frame 46/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 34, time 1.09
# Frame 47/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 37, time 1.12
# Frame 48/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 40, time 1.14
# Frame 49/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 43, time 1.16
# Frame 50/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 46, time 1.18
# Frame 51/100: snapshots_CRa25k/snapshots_CRa25k_s3.h5, index 48, time 1.20
# Frame 52/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 1, time 1.22
# Frame 53/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 4, time 1.24
# Frame 54/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 7, time 1.26
# Frame 55/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 10, time 1.28
# Frame 56/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 13, time 1.30
# Frame 57/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 16, time 1.32
# Frame 58/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 19, time 1.34
# Frame 59/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 22, time 1.36
# Frame 60/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 25, time 1.38
# Frame 61/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 28, time 1.40
# Frame 62/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 31, time 1.41
# Frame 63/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 34, time 1.43
# Frame 64/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 37, time 1.45
# Frame 65/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 40, time 1.46
# Frame 66/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 43, time 1.48
# Frame 67/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 46, time 1.50
# Frame 68/100: snapshots_CRa25k/snapshots_CRa25k_s4.h5, index 49, time 1.51
# Frame 69/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 2, time 1.53
# Frame 70/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 5, time 1.55
# Frame 71/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 8, time 1.57
# Frame 72/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 11, time 1.58
# Frame 73/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 14, time 1.60
# Frame 74/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 17, time 1.62
# Frame 75/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 20, time 1.63
# Frame 76/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 23, time 1.65
# Frame 77/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 26, time 1.67
# Frame 78/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 29, time 1.69
# Frame 79/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 32, time 1.70
# Frame 80/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 35, time 1.72
# Frame 81/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 38, time 1.74
# Frame 82/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 41, time 1.76
# Frame 83/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 44, time 1.77
# Frame 84/100: snapshots_CRa25k/snapshots_CRa25k_s5.h5, index 47, time 1.79
# Frame 85/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 0, time 1.81
# Frame 86/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 3, time 1.83
# Frame 87/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 6, time 1.84
# Frame 88/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 9, time 1.86
# Frame 89/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 12, time 1.88
# Frame 90/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 15, time 1.90
# Frame 91/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 18, time 1.91
# Frame 92/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 21, time 1.93
# Frame 93/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 24, time 1.95
# Frame 94/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 27, time 1.97
# Frame 95/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 30, time 1.98
# Frame 96/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 33, time 2.00
# Frame 97/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 36, time 2.02
# Frame 98/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 39, time 2.04
# Frame 99/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 42, time 2.05
# Frame 100/100: snapshots_CRa25k/snapshots_CRa25k_s6.h5, index 45, time 2.07
# Saved animation to WC2_CRa25k_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_CRa30k",
    file_prefix="snapshots_CRa30k_s",
    output_name="WC2_CRa30k_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=49,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 2 snapshot files.
# Scanning snapshots_CRa30k/snapshots_CRa30k_s1.h5
# Scanning snapshots_CRa30k/snapshots_CRa30k_s2.h5
# Requested nframes=100, but only 71 frames exist. Using all frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00024999350735303085 1.0039492867887532
# Scanning color limits for C...
# C vmin/vmax: 0.0023068922217529277 1.000024773168261
# Scanning color limits for w...
# w vmin/vmax: -48.21363307206866 48.21363307206866
# Frame 1/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 0, time 0.00
# Frame 1/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 0, time 0.00
# Frame 2/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 1, time 0.07
# Frame 3/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 2, time 0.07
# Frame 4/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 3, time 0.07
# Frame 5/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 4, time 0.08
# Frame 6/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 5, time 0.09
# Frame 7/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 6, time 0.10
# Frame 8/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 7, time 0.11
# Frame 9/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 8, time 0.12
# Frame 10/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 9, time 0.12
# Frame 11/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 10, time 0.13
# Frame 12/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 11, time 0.14
# Frame 13/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 12, time 0.14
# Frame 14/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 13, time 0.15
# Frame 15/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 14, time 0.16
# Frame 16/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 15, time 0.17
# Frame 17/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 16, time 0.17
# Frame 18/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 17, time 0.18
# Frame 19/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 18, time 0.19
# Frame 20/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 19, time 0.20
# Frame 21/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 20, time 0.21
# Frame 22/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 21, time 0.21
# Frame 23/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 22, time 0.22
# Frame 24/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 23, time 0.23
# Frame 25/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 24, time 0.24
# Frame 26/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 25, time 0.25
# Frame 27/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 26, time 0.25
# Frame 28/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 27, time 0.26
# Frame 29/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 28, time 0.27
# Frame 30/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 29, time 0.28
# Frame 31/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 30, time 0.29
# Frame 32/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 31, time 0.30
# Frame 33/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 32, time 0.30
# Frame 34/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 33, time 0.31
# Frame 35/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 34, time 0.32
# Frame 36/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 35, time 0.33
# Frame 37/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 36, time 0.34
# Frame 38/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 37, time 0.35
# Frame 39/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 38, time 0.36
# Frame 40/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 39, time 0.36
# Frame 41/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 40, time 0.37
# Frame 42/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 41, time 0.38
# Frame 43/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 42, time 0.39
# Frame 44/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 43, time 0.40
# Frame 45/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 44, time 0.41
# Frame 46/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 45, time 0.41
# Frame 47/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 46, time 0.42
# Frame 48/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 47, time 0.43
# Frame 49/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 48, time 0.44
# Frame 50/71: snapshots_CRa30k/snapshots_CRa30k_s1.h5, index 49, time 0.45
# Frame 51/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 0, time 0.46
# Frame 52/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 1, time 0.46
# Frame 53/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 2, time 0.47
# Frame 54/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 3, time 0.48
# Frame 55/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 4, time 0.49
# Frame 56/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 5, time 0.50
# Frame 57/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 6, time 0.51
# Frame 58/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 7, time 0.51
# Frame 59/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 8, time 0.52
# Frame 60/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 9, time 0.53
# Frame 61/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 10, time 0.54
# Frame 62/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 11, time 0.55
# Frame 63/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 12, time 0.56
# Frame 64/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 13, time 0.56
# Frame 65/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 14, time 0.57
# Frame 66/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 15, time 0.58
# Frame 67/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 16, time 0.59
# Frame 68/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 17, time 0.60
# Frame 69/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 18, time 0.61
# Frame 70/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 19, time 0.62
# Frame 71/71: snapshots_CRa30k/snapshots_CRa30k_s2.h5, index 20, time 0.62
# Saved animation to WC2_CRa30k_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_CRa40k",
    file_prefix="snapshots_CRa40k_s",
    output_name="WC2_CRa40k_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 17 snapshot files.
# Scanning snapshots_CRa40k/snapshots_CRa40k_s1.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s2.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s3.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s4.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s5.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s6.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s7.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s8.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s9.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s10.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s11.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s12.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s13.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s14.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s15.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s16.h5
# Scanning snapshots_CRa40k/snapshots_CRa40k_s17.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.0002750525173239861 1.0074645923931165
# Scanning color limits for C...
# C vmin/vmax: 0.002537271729962397 1.000005000300097
# Scanning color limits for w...
# w vmin/vmax: -40.913499721093636 40.913499721093636
# Frame 1/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 8, time 0.12
# Frame 3/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 16, time 0.18
# Frame 4/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 24, time 0.25
# Frame 5/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 32, time 0.32
# Frame 6/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 40, time 0.40
# Frame 7/100: snapshots_CRa40k/snapshots_CRa40k_s1.h5, index 48, time 0.47
# Frame 8/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 6, time 0.54
# Frame 9/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 14, time 0.62
# Frame 10/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 22, time 0.69
# Frame 11/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 30, time 0.77
# Frame 12/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 38, time 0.85
# Frame 13/100: snapshots_CRa40k/snapshots_CRa40k_s2.h5, index 46, time 0.92
# Frame 14/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 5, time 1.01
# Frame 15/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 13, time 1.08
# Frame 16/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 21, time 1.16
# Frame 17/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 29, time 1.23
# Frame 18/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 37, time 1.31
# Frame 19/100: snapshots_CRa40k/snapshots_CRa40k_s3.h5, index 45, time 1.38
# Frame 20/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 3, time 1.46
# Frame 21/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 11, time 1.53
# Frame 22/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 19, time 1.61
# Frame 23/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 27, time 1.69
# Frame 24/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 35, time 1.76
# Frame 25/100: snapshots_CRa40k/snapshots_CRa40k_s4.h5, index 43, time 1.84
# Frame 26/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 2, time 1.92
# Frame 27/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 10, time 2.00
# Frame 28/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 18, time 2.07
# Frame 29/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 26, time 2.15
# Frame 30/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 34, time 2.22
# Frame 31/100: snapshots_CRa40k/snapshots_CRa40k_s5.h5, index 42, time 2.30
# Frame 32/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 0, time 2.38
# Frame 33/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 8, time 2.45
# Frame 34/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 16, time 2.53
# Frame 35/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 24, time 2.60
# Frame 36/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 32, time 2.68
# Frame 37/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 40, time 2.75
# Frame 38/100: snapshots_CRa40k/snapshots_CRa40k_s6.h5, index 48, time 2.83
# Frame 39/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 7, time 2.91
# Frame 40/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 15, time 2.99
# Frame 41/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 23, time 3.06
# Frame 42/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 31, time 3.14
# Frame 43/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 39, time 3.22
# Frame 44/100: snapshots_CRa40k/snapshots_CRa40k_s7.h5, index 47, time 3.29
# Frame 45/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 5, time 3.37
# Frame 46/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 13, time 3.44
# Frame 47/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 21, time 3.52
# Frame 48/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 29, time 3.59
# Frame 49/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 37, time 3.67
# Frame 50/100: snapshots_CRa40k/snapshots_CRa40k_s8.h5, index 45, time 3.74
# Frame 51/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 4, time 3.83
# Frame 52/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 12, time 3.90
# Frame 53/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 20, time 3.98
# Frame 54/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 28, time 4.06
# Frame 55/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 36, time 4.13
# Frame 56/100: snapshots_CRa40k/snapshots_CRa40k_s9.h5, index 44, time 4.21
# Frame 57/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 2, time 4.28
# Frame 58/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 10, time 4.36
# Frame 59/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 18, time 4.43
# Frame 60/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 26, time 4.51
# Frame 61/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 34, time 4.58
# Frame 62/100: snapshots_CRa40k/snapshots_CRa40k_s10.h5, index 42, time 4.66
# Frame 63/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 1, time 4.74
# Frame 64/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 9, time 4.82
# Frame 65/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 17, time 4.90
# Frame 66/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 25, time 4.97
# Frame 67/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 33, time 5.05
# Frame 68/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 41, time 5.12
# Frame 69/100: snapshots_CRa40k/snapshots_CRa40k_s11.h5, index 49, time 5.20
# Frame 70/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 7, time 5.27
# Frame 71/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 15, time 5.35
# Frame 72/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 23, time 5.42
# Frame 73/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 31, time 5.50
# Frame 74/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 39, time 5.58
# Frame 75/100: snapshots_CRa40k/snapshots_CRa40k_s12.h5, index 47, time 5.65
# Frame 76/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 6, time 5.74
# Frame 77/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 14, time 5.81
# Frame 78/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 22, time 5.89
# Frame 79/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 30, time 5.96
# Frame 80/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 38, time 6.04
# Frame 81/100: snapshots_CRa40k/snapshots_CRa40k_s13.h5, index 46, time 6.11
# Frame 82/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 4, time 6.19
# Frame 83/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 12, time 6.26
# Frame 84/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 20, time 6.34
# Frame 85/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 28, time 6.42
# Frame 86/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 36, time 6.49
# Frame 87/100: snapshots_CRa40k/snapshots_CRa40k_s14.h5, index 44, time 6.57
# Frame 88/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 3, time 6.65
# Frame 89/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 11, time 6.73
# Frame 90/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 19, time 6.80
# Frame 91/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 27, time 6.88
# Frame 92/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 35, time 6.95
# Frame 93/100: snapshots_CRa40k/snapshots_CRa40k_s15.h5, index 43, time 7.03
# Frame 94/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 1, time 7.10
# Frame 95/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 9, time 7.18
# Frame 96/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 17, time 7.26
# Frame 97/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 25, time 7.33
# Frame 98/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 33, time 7.41
# Frame 99/100: snapshots_CRa40k/snapshots_CRa40k_s16.h5, index 41, time 7.48
# Frame 100/100: snapshots_CRa40k/snapshots_CRa40k_s17.h5, index 0, time 7.57
# Saved animation to WC2_CRa40k_T_C_w.gif

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots_RaT5k",
    file_prefix="snapshots_RaT5k_s",
    output_name="WC2_RaT5k_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=100,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 5 snapshot files.
# Scanning snapshots_RaT5k/snapshots_RaT5k_s1.h5
# Scanning snapshots_RaT5k/snapshots_RaT5k_s2.h5
# Scanning snapshots_RaT5k/snapshots_RaT5k_s3.h5
# Scanning snapshots_RaT5k/snapshots_RaT5k_s4.h5
# Scanning snapshots_RaT5k/snapshots_RaT5k_s5.h5
# Using 100 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00027404094424512954 1.0620874394262
# Scanning color limits for C...
# C vmin/vmax: 0.0028626625808148704 1.000000286974276
# Scanning color limits for w...
# w vmin/vmax: -25.780022216542804 25.780022216542804
# Frame 1/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 0, time 0.00
# Frame 1/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 0, time 0.00
# Frame 2/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 2, time 0.13
# Frame 3/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 4, time 0.15
# Frame 4/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 6, time 0.18
# Frame 5/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 8, time 0.21
# Frame 6/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 10, time 0.23
# Frame 7/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 12, time 0.26
# Frame 8/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 14, time 0.29
# Frame 9/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 16, time 0.32
# Frame 10/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 18, time 0.34
# Frame 11/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 20, time 0.37
# Frame 12/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 22, time 0.40
# Frame 13/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 24, time 0.43
# Frame 14/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 26, time 0.45
# Frame 15/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 28, time 0.48
# Frame 16/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 30, time 0.51
# Frame 17/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 32, time 0.54
# Frame 18/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 34, time 0.56
# Frame 19/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 36, time 0.59
# Frame 20/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 38, time 0.62
# Frame 21/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 40, time 0.65
# Frame 22/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 42, time 0.67
# Frame 23/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 44, time 0.70
# Frame 24/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 46, time 0.73
# Frame 25/100: snapshots_RaT5k/snapshots_RaT5k_s1.h5, index 48, time 0.76
# Frame 26/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 0, time 0.79
# Frame 27/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 2, time 0.81
# Frame 28/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 4, time 0.84
# Frame 29/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 6, time 0.87
# Frame 30/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 8, time 0.90
# Frame 31/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 10, time 0.92
# Frame 32/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 12, time 0.95
# Frame 33/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 14, time 0.98
# Frame 34/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 16, time 1.01
# Frame 35/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 18, time 1.03
# Frame 36/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 20, time 1.06
# Frame 37/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 22, time 1.09
# Frame 38/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 24, time 1.12
# Frame 39/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 26, time 1.14
# Frame 40/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 28, time 1.17
# Frame 41/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 30, time 1.20
# Frame 42/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 32, time 1.23
# Frame 43/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 34, time 1.26
# Frame 44/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 36, time 1.28
# Frame 45/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 38, time 1.31
# Frame 46/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 40, time 1.34
# Frame 47/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 42, time 1.37
# Frame 48/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 44, time 1.39
# Frame 49/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 46, time 1.42
# Frame 50/100: snapshots_RaT5k/snapshots_RaT5k_s2.h5, index 48, time 1.45
# Frame 51/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 1, time 1.49
# Frame 52/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 3, time 1.52
# Frame 53/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 5, time 1.55
# Frame 54/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 7, time 1.57
# Frame 55/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 9, time 1.60
# Frame 56/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 11, time 1.63
# Frame 57/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 13, time 1.66
# Frame 58/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 15, time 1.68
# Frame 59/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 17, time 1.71
# Frame 60/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 19, time 1.74
# Frame 61/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 21, time 1.77
# Frame 62/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 23, time 1.79
# Frame 63/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 25, time 1.82
# Frame 64/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 27, time 1.85
# Frame 65/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 29, time 1.88
# Frame 66/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 31, time 1.90
# Frame 67/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 33, time 1.93
# Frame 68/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 35, time 1.96
# Frame 69/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 37, time 1.99
# Frame 70/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 39, time 2.02
# Frame 71/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 41, time 2.04
# Frame 72/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 43, time 2.07
# Frame 73/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 45, time 2.10
# Frame 74/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 47, time 2.13
# Frame 75/100: snapshots_RaT5k/snapshots_RaT5k_s3.h5, index 49, time 2.15
# Frame 76/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 1, time 2.18
# Frame 77/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 3, time 2.21
# Frame 78/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 5, time 2.24
# Frame 79/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 7, time 2.26
# Frame 80/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 9, time 2.29
# Frame 81/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 11, time 2.32
# Frame 82/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 13, time 2.35
# Frame 83/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 15, time 2.37
# Frame 84/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 17, time 2.40
# Frame 85/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 19, time 2.43
# Frame 86/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 21, time 2.46
# Frame 87/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 23, time 2.49
# Frame 88/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 25, time 2.51
# Frame 89/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 27, time 2.54
# Frame 90/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 29, time 2.57
# Frame 91/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 31, time 2.60
# Frame 92/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 33, time 2.62
# Frame 93/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 35, time 2.65
# Frame 94/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 37, time 2.68
# Frame 95/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 39, time 2.71
# Frame 96/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 41, time 2.73
# Frame 97/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 43, time 2.76
# Frame 98/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 45, time 2.79
# Frame 99/100: snapshots_RaT5k/snapshots_RaT5k_s4.h5, index 47, time 2.82
# Frame 100/100: snapshots_RaT5k/snapshots_RaT5k_s5.h5, index 0, time 2.86
# Saved animation to WC2_RaT5k_T_C_w.gif
