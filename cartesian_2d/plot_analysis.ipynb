# %%
import pathlib
import subprocess
import h5py
import numpy as np
import matplotlib.pyplot as plt
import re
import glob
import h5py
import matplotlib.animation as animation

import scipy.special as spl
import scipy.integrate
import mpmath as mpm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.colors as mcolors
import matplotlib.cm as cm

fontsize_title = 22
fontsize_axis = 18
fontsize_tick = 18
fontsize_legend = 16
fontsize_cbar = 18

plt.rcParams.update({
    "font.size": fontsize_tick,
    "axes.titlesize": fontsize_title,
    "axes.labelsize": fontsize_axis,
    "xtick.labelsize": fontsize_tick,
    "ytick.labelsize": fontsize_tick,
    "legend.fontsize": fontsize_legend,
    "figure.titlesize": fontsize_title,
})

# %%
import os

os.getcwd()
# Out:
# '/net/fs06/d0/dabdulah/GFD_PROJECT/crust_convection/cartesian_2d'

# %%
def make_2D_three_panel_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="three_panel_T_C_w.gif",

    tasks=("T", "C", "w"),
    titles=("T", "C", "w"),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    cmaps=("RdBu_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),
    scale_from_last_half=True,

    nframes=None,        # desired number of frames; None uses all available frames
    frame_cutoff=None,   # old option; kept for compatibility
):
    """
    Makes a 3-panel 2D animation for x-z fields.

    Assumes each task has shape:
        (time, x, z)

    Panels:
        left   = tasks[0]
        middle = tasks[1]
        right  = tasks[2]

    Each panel has x,z axes and its own colorbar.

    nframes:
        If None, use all frames.
        If smaller than available frames, subsample evenly.
        If larger than available frames, use all frames.
    """

    import os
    import h5py
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.animation as animation
    import matplotlib.cm as cm
    import matplotlib.colors as mcolors

    def get_coord(dset, dim_index):
        keys = list(dset.dims[dim_index].keys())
        if len(keys) == 0:
            raise ValueError(f"No coordinate scale found for dimension {dim_index}")
        return np.asarray(dset.dims[dim_index][keys[0]])

    def find_snapshot_files(snapshot_dir="snapshots", file_prefix="snapshots_s"):
        files = []
        i = 1
        while True:
            fname = os.path.join(snapshot_dir, f"{file_prefix}{i}.h5")
            if os.path.exists(fname):
                files.append(fname)
                i += 1
            else:
                break

        if len(files) == 0:
            raise FileNotFoundError(f"No files found like {snapshot_dir}/{file_prefix}X.h5")

        return files

    # ----------------------------
    # Colormaps
    # ----------------------------
    cmap_list = []

    for task, cmap in zip(tasks, cmaps):
        if cmap is None and task == "C":
            cmap_obj = mcolors.LinearSegmentedColormap.from_list(
                "brown_to_red",
                [
                    (0.00, "black"),
                    (0.25, "saddlebrown"),
                    (1.00, "lightcoral"),
                ]
            )
        elif cmap is None:
            cmap_obj = cm.get_cmap("RdBu_r")
        else:
            cmap_obj = cm.get_cmap(cmap)

        cmap_list.append(cmap_obj)

    # ----------------------------
    # Find files and collect frames
    # ----------------------------
    files = find_snapshot_files(snapshot_dir, file_prefix)
    print(f"Found {len(files)} snapshot files.")

    frames = []

    for fname in files:
        print(f"Scanning {fname}")
        with h5py.File(fname, mode="r") as file:
            dset = file["tasks"][tasks[0]]
            t = np.asarray(dset.dims[0]["sim_time"])
            nt = dset.shape[0]

            for it in range(nt):
                frames.append((fname, it, t[it]))

    frames = sorted(frames, key=lambda item: item[2])

    # ----------------------------
    # Subsample frames if requested
    # ----------------------------
    if nframes is not None:
        nframes = int(nframes)

        if nframes <= 0:
            raise ValueError("nframes must be positive")

        if nframes < len(frames):
            inds = np.linspace(0, len(frames) - 1, nframes).astype(int)
            frames = [frames[i] for i in inds]
            print(f"Using {len(frames)} evenly subsampled frames.")
        else:
            print(f"Requested nframes={nframes}, but only {len(frames)} frames exist. Using all frames.")

    # ----------------------------
    # Coordinates
    # ----------------------------
    first_fname, first_it, first_time = frames[0]

    with h5py.File(first_fname, mode="r") as file:
        dset = file["tasks"][tasks[0]]
        x = get_coord(dset, 1)
        z = get_coord(dset, 2)

    x0, x1 = x.min(), x.max()
    z0, z1 = z.min(), z.max()

    X, Z = np.meshgrid(x, z, indexing="ij")

    print("x min/max:", x0, x1)
    print("z min/max:", z0, z1)

    # ----------------------------
    # Color limits
    # ----------------------------
    def scan_task_limits(task, user_vmin, user_vmax):
        if user_vmin is not None and user_vmax is not None:
            return user_vmin, user_vmax

        vals = []
        scan_frames = frames[len(frames)//2:] if scale_from_last_half else frames

        print(f"Scanning color limits for {task}...")

        for fname, it, sim_time in scan_frames:
            with h5py.File(fname, mode="r") as file:
                A = np.asarray(file["tasks"][task][it, :, :])
                vals.append(np.nanmin(A))
                vals.append(np.nanmax(A))

        data_min = np.nanmin(vals)
        data_max = np.nanmax(vals)

        if user_vmin is None:
            user_vmin = data_min
        if user_vmax is None:
            user_vmax = data_max

        return user_vmin, user_vmax

    norms = []
    for task, vmin, vmax in zip(tasks, vmins, vmaxs):
        vmin, vmax = scan_task_limits(task, vmin, vmax)

        if task == "w":
            vmax_abs = max(abs(vmin), abs(vmax))
            vmin = -vmax_abs
            vmax = vmax_abs

        print(f"{task} vmin/vmax:", vmin, vmax)
        norms.append(mcolors.Normalize(vmin=vmin, vmax=vmax))

    # ----------------------------
    # Figure setup
    # ----------------------------
    fig, axes = plt.subplots(1, 3, figsize=figsize)

    fig.subplots_adjust(
        left=0.06,
        right=0.92,
        bottom=0.12,
        top=0.86,
        wspace=0.35,
    )

    ims = []

    with h5py.File(first_fname, mode="r") as file:
        for ax, task, title, cmap, norm in zip(axes, tasks, titles, cmap_list, norms):
            A = np.asarray(file["tasks"][task][first_it, :, :])

            im = ax.pcolormesh(
                X, Z, A,
                shading="auto",
                cmap=cmap,
                norm=norm,
            )

            ax.set_title(title)
            ax.set_xlabel("x")
            ax.set_ylabel("z")
            ax.set_xlim(x0, x1)
            ax.set_ylim(z0, z1)

            fig.colorbar(im, ax=ax)

            ims.append(im)

    fig.suptitle(f"time = {first_time:.2f}")

    # ----------------------------
    # Animation update
    # ----------------------------
    def update(frame_number):
        fname, it, sim_time = frames[frame_number]

        with h5py.File(fname, mode="r") as file:
            for im, task in zip(ims, tasks):
                A = np.asarray(file["tasks"][task][it, :, :])
                im.set_array(A.ravel())

        fig.suptitle(f"time = {sim_time:.2f}")

        print(
            f"Frame {frame_number + 1}/{frame_cutoff if frame_cutoff is not None else len(frames)}: "
            f"{fname}, index {it}, time {sim_time:.2f}"
        )

        return ims

    if frame_cutoff is None:
        frame_cutoff = len(frames)
    else:
        frame_cutoff = min(frame_cutoff, len(frames))

    ani = animation.FuncAnimation(
        fig,
        update,
        frames=frame_cutoff,
        interval=1000 / fps,
        blit=False,
    )

    ani.save(output_name, writer="pillow", fps=fps, dpi=dpi)
    print(f"Saved animation to {output_name}")

# %%
make_2D_three_panel_animation(
    snapshot_dir="snapshots",
    file_prefix="snapshots_s",
    output_name="Keaton_T_C_w.gif",

    tasks=("T", "C", "vorticity"),
    titles=("T", "C", "vorticity"),

    cmaps=("Spectral_r", None, "RdBu_r"),
    vmins=(None, None, None),
    vmaxs=(None, None, None),

    fps=4,
    dpi=150,
    figsize=(15, 4.5),

    nframes=150,
    frame_cutoff=None,
)
# Out:
# <ipython-input-3-c65f71a18b67>:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap_obj = cm.get_cmap(cmap)
# Found 5 snapshot files.
# Scanning snapshots/snapshots_s1.h5
# Scanning snapshots/snapshots_s2.h5
# Scanning snapshots/snapshots_s3.h5
# Scanning snapshots/snapshots_s4.h5
# Scanning snapshots/snapshots_s5.h5
# Using 150 evenly subsampled frames.
# x min/max: 0.0 3.984375
# z min/max: 0.00015059065189787502 0.9998494093481021
# Scanning color limits for T...
# T vmin/vmax: 0.00010292490891341631 0.9999770806801738
# Scanning color limits for C...
# C vmin/vmax: -0.0001602121480095216 1.000458880639177
# Scanning color limits for vorticity...
# vorticity vmin/vmax: -321.79120438736174 331.4466960507719
# Frame 1/150: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 1/150: snapshots/snapshots_s1.h5, index 0, time 0.00
# Frame 2/150: snapshots/snapshots_s1.h5, index 1, time 0.06
# Frame 3/150: snapshots/snapshots_s1.h5, index 2, time 0.07
# Frame 4/150: snapshots/snapshots_s1.h5, index 4, time 0.08
# Frame 5/150: snapshots/snapshots_s1.h5, index 5, time 0.09
# Frame 6/150: snapshots/snapshots_s1.h5, index 7, time 0.11
# Frame 7/150: snapshots/snapshots_s1.h5, index 8, time 0.12
# Frame 8/150: snapshots/snapshots_s1.h5, index 10, time 0.13
# Frame 9/150: snapshots/snapshots_s1.h5, index 11, time 0.14
# Frame 10/150: snapshots/snapshots_s1.h5, index 12, time 0.15
# Frame 11/150: snapshots/snapshots_s1.h5, index 14, time 0.16
# Frame 12/150: snapshots/snapshots_s1.h5, index 15, time 0.17
# Frame 13/150: snapshots/snapshots_s1.h5, index 17, time 0.18
# Frame 14/150: snapshots/snapshots_s1.h5, index 18, time 0.19
# Frame 15/150: snapshots/snapshots_s1.h5, index 20, time 0.20
# Frame 16/150: snapshots/snapshots_s1.h5, index 21, time 0.21
# Frame 17/150: snapshots/snapshots_s1.h5, index 22, time 0.22
# Frame 18/150: snapshots/snapshots_s1.h5, index 24, time 0.23
# Frame 19/150: snapshots/snapshots_s1.h5, index 25, time 0.24
# Frame 20/150: snapshots/snapshots_s1.h5, index 27, time 0.26
# Frame 21/150: snapshots/snapshots_s1.h5, index 28, time 0.27
# Frame 22/150: snapshots/snapshots_s1.h5, index 30, time 0.30
# Frame 23/150: snapshots/snapshots_s1.h5, index 31, time 0.31
# Frame 24/150: snapshots/snapshots_s1.h5, index 32, time 0.32
# Frame 25/150: snapshots/snapshots_s1.h5, index 34, time 0.34
# Frame 26/150: snapshots/snapshots_s1.h5, index 35, time 0.35
# Frame 27/150: snapshots/snapshots_s1.h5, index 37, time 0.36
# Frame 28/150: snapshots/snapshots_s1.h5, index 38, time 0.36
# Frame 29/150: snapshots/snapshots_s1.h5, index 40, time 0.38
# Frame 30/150: snapshots/snapshots_s1.h5, index 41, time 0.38
# Frame 31/150: snapshots/snapshots_s1.h5, index 42, time 0.39
# Frame 32/150: snapshots/snapshots_s1.h5, index 44, time 0.41
# Frame 33/150: snapshots/snapshots_s1.h5, index 45, time 0.41
# Frame 34/150: snapshots/snapshots_s1.h5, index 47, time 0.42
# Frame 35/150: snapshots/snapshots_s1.h5, index 48, time 0.43
# Frame 36/150: snapshots/snapshots_s2.h5, index 0, time 0.44
# Frame 37/150: snapshots/snapshots_s2.h5, index 1, time 0.45
# Frame 38/150: snapshots/snapshots_s2.h5, index 2, time 0.45
# Frame 39/150: snapshots/snapshots_s2.h5, index 4, time 0.47
# Frame 40/150: snapshots/snapshots_s2.h5, index 5, time 0.47
# Frame 41/150: snapshots/snapshots_s2.h5, index 7, time 0.49
# Frame 42/150: snapshots/snapshots_s2.h5, index 8, time 0.49
# Frame 43/150: snapshots/snapshots_s2.h5, index 10, time 0.50
# Frame 44/150: snapshots/snapshots_s2.h5, index 11, time 0.51
# Frame 45/150: snapshots/snapshots_s2.h5, index 12, time 0.51
# Frame 46/150: snapshots/snapshots_s2.h5, index 14, time 0.52
# Frame 47/150: snapshots/snapshots_s2.h5, index 15, time 0.53
# Frame 48/150: snapshots/snapshots_s2.h5, index 17, time 0.55
# Frame 49/150: snapshots/snapshots_s2.h5, index 18, time 0.55
# Frame 50/150: snapshots/snapshots_s2.h5, index 20, time 0.57
# Frame 51/150: snapshots/snapshots_s2.h5, index 21, time 0.58
# Frame 52/150: snapshots/snapshots_s2.h5, index 22, time 0.59
# Frame 53/150: snapshots/snapshots_s2.h5, index 24, time 0.60
# Frame 54/150: snapshots/snapshots_s2.h5, index 25, time 0.61
# Frame 55/150: snapshots/snapshots_s2.h5, index 27, time 0.62
# Frame 56/150: snapshots/snapshots_s2.h5, index 28, time 0.63
# Frame 57/150: snapshots/snapshots_s2.h5, index 30, time 0.64
# Frame 58/150: snapshots/snapshots_s2.h5, index 31, time 0.65
# Frame 59/150: snapshots/snapshots_s2.h5, index 32, time 0.66
# Frame 60/150: snapshots/snapshots_s2.h5, index 34, time 0.67
# Frame 61/150: snapshots/snapshots_s2.h5, index 35, time 0.68
# Frame 62/150: snapshots/snapshots_s2.h5, index 37, time 0.69
# Frame 63/150: snapshots/snapshots_s2.h5, index 38, time 0.70
# Frame 64/150: snapshots/snapshots_s2.h5, index 40, time 0.71
# Frame 65/150: snapshots/snapshots_s2.h5, index 41, time 0.72
# Frame 66/150: snapshots/snapshots_s2.h5, index 42, time 0.72
# Frame 67/150: snapshots/snapshots_s2.h5, index 44, time 0.74
# Frame 68/150: snapshots/snapshots_s2.h5, index 45, time 0.74
# Frame 69/150: snapshots/snapshots_s2.h5, index 47, time 0.76
# Frame 70/150: snapshots/snapshots_s2.h5, index 48, time 0.77
# Frame 71/150: snapshots/snapshots_s3.h5, index 0, time 0.79
# Frame 72/150: snapshots/snapshots_s3.h5, index 1, time 0.80
# Frame 73/150: snapshots/snapshots_s3.h5, index 2, time 0.81
# Frame 74/150: snapshots/snapshots_s3.h5, index 4, time 0.82
# Frame 75/150: snapshots/snapshots_s3.h5, index 5, time 0.83
# Frame 76/150: snapshots/snapshots_s3.h5, index 7, time 0.85
# Frame 77/150: snapshots/snapshots_s3.h5, index 8, time 0.86
# Frame 78/150: snapshots/snapshots_s3.h5, index 10, time 0.88
# Frame 79/150: snapshots/snapshots_s3.h5, index 11, time 0.89
# Frame 80/150: snapshots/snapshots_s3.h5, index 12, time 0.91
# Frame 81/150: snapshots/snapshots_s3.h5, index 14, time 0.93
# Frame 82/150: snapshots/snapshots_s3.h5, index 15, time 0.95
# Frame 83/150: snapshots/snapshots_s3.h5, index 17, time 0.97
# Frame 84/150: snapshots/snapshots_s3.h5, index 18, time 0.98
# Frame 85/150: snapshots/snapshots_s3.h5, index 20, time 1.00
# Frame 86/150: snapshots/snapshots_s3.h5, index 21, time 1.01
# Frame 87/150: snapshots/snapshots_s3.h5, index 22, time 1.02
# Frame 88/150: snapshots/snapshots_s3.h5, index 24, time 1.04
# Frame 89/150: snapshots/snapshots_s3.h5, index 25, time 1.05
# Frame 90/150: snapshots/snapshots_s3.h5, index 27, time 1.07
# Frame 91/150: snapshots/snapshots_s3.h5, index 28, time 1.08
# Frame 92/150: snapshots/snapshots_s3.h5, index 30, time 1.09
# Frame 93/150: snapshots/snapshots_s3.h5, index 31, time 1.10
# Frame 94/150: snapshots/snapshots_s3.h5, index 32, time 1.11
# Frame 95/150: snapshots/snapshots_s3.h5, index 34, time 1.14
# Frame 96/150: snapshots/snapshots_s3.h5, index 35, time 1.15
# Frame 97/150: snapshots/snapshots_s3.h5, index 37, time 1.17
# Frame 98/150: snapshots/snapshots_s3.h5, index 38, time 1.17
# Frame 99/150: snapshots/snapshots_s3.h5, index 40, time 1.20
# Frame 100/150: snapshots/snapshots_s3.h5, index 41, time 1.21
# Frame 101/150: snapshots/snapshots_s3.h5, index 42, time 1.22
# Frame 102/150: snapshots/snapshots_s3.h5, index 44, time 1.24
# Frame 103/150: snapshots/snapshots_s3.h5, index 45, time 1.25
# Frame 104/150: snapshots/snapshots_s3.h5, index 47, time 1.27
# Frame 105/150: snapshots/snapshots_s3.h5, index 48, time 1.28
# Frame 106/150: snapshots/snapshots_s4.h5, index 0, time 1.30
# Frame 107/150: snapshots/snapshots_s4.h5, index 1, time 1.31
# Frame 108/150: snapshots/snapshots_s4.h5, index 2, time 1.32
# Frame 109/150: snapshots/snapshots_s4.h5, index 4, time 1.34
# Frame 110/150: snapshots/snapshots_s4.h5, index 5, time 1.35
# Frame 111/150: snapshots/snapshots_s4.h5, index 7, time 1.37
# Frame 112/150: snapshots/snapshots_s4.h5, index 8, time 1.38
# Frame 113/150: snapshots/snapshots_s4.h5, index 10, time 1.40
# Frame 114/150: snapshots/snapshots_s4.h5, index 11, time 1.41
# Frame 115/150: snapshots/snapshots_s4.h5, index 12, time 1.42
# Frame 116/150: snapshots/snapshots_s4.h5, index 14, time 1.44
# Frame 117/150: snapshots/snapshots_s4.h5, index 15, time 1.45
# Frame 118/150: snapshots/snapshots_s4.h5, index 17, time 1.47
# Frame 119/150: snapshots/snapshots_s4.h5, index 18, time 1.48
# Frame 120/150: snapshots/snapshots_s4.h5, index 20, time 1.50
# Frame 121/150: snapshots/snapshots_s4.h5, index 21, time 1.51
# Frame 122/150: snapshots/snapshots_s4.h5, index 22, time 1.52
# Frame 123/150: snapshots/snapshots_s4.h5, index 24, time 1.54
# Frame 124/150: snapshots/snapshots_s4.h5, index 25, time 1.55
# Frame 125/150: snapshots/snapshots_s4.h5, index 27, time 1.57
# Frame 126/150: snapshots/snapshots_s4.h5, index 28, time 1.58
# Frame 127/150: snapshots/snapshots_s4.h5, index 30, time 1.60
# Frame 128/150: snapshots/snapshots_s4.h5, index 31, time 1.61
# Frame 129/150: snapshots/snapshots_s4.h5, index 32, time 1.62
# Frame 130/150: snapshots/snapshots_s4.h5, index 34, time 1.64
# Frame 131/150: snapshots/snapshots_s4.h5, index 35, time 1.65
# Frame 132/150: snapshots/snapshots_s4.h5, index 37, time 1.67
# Frame 133/150: snapshots/snapshots_s4.h5, index 38, time 1.68
# Frame 134/150: snapshots/snapshots_s4.h5, index 40, time 1.70
# Frame 135/150: snapshots/snapshots_s4.h5, index 41, time 1.72
# Frame 136/150: snapshots/snapshots_s4.h5, index 42, time 1.73
# Frame 137/150: snapshots/snapshots_s4.h5, index 44, time 1.75
# Frame 138/150: snapshots/snapshots_s4.h5, index 45, time 1.76
# Frame 139/150: snapshots/snapshots_s4.h5, index 47, time 1.78
# Frame 140/150: snapshots/snapshots_s4.h5, index 48, time 1.79
# Frame 141/150: snapshots/snapshots_s5.h5, index 0, time 1.81
# Frame 142/150: snapshots/snapshots_s5.h5, index 1, time 1.82
# Frame 143/150: snapshots/snapshots_s5.h5, index 2, time 1.83
# Frame 144/150: snapshots/snapshots_s5.h5, index 4, time 1.86
# Frame 145/150: snapshots/snapshots_s5.h5, index 5, time 1.87
# Frame 146/150: snapshots/snapshots_s5.h5, index 7, time 1.90
# Frame 147/150: snapshots/snapshots_s5.h5, index 8, time 1.92
# Frame 148/150: snapshots/snapshots_s5.h5, index 10, time 1.95
# Frame 149/150: snapshots/snapshots_s5.h5, index 11, time 1.97
# Frame 150/150: snapshots/snapshots_s5.h5, index 13, time 2.00
# Saved animation to Keaton_T_C_w.gif
